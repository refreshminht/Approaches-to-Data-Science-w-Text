# %% [markdown]
# # Word Embedding Models: word2vec #

# %% [markdown]
# ![oprah vector](http://lklein.com/wp-content/uploads/2021/10/oprah-everyone-3.png)
#
# ### Everything gets a vector! ###
#
# We've already been exploring vectors involving words: consider scikit-learn's `CountVectorizer()`, for example, which we used to create the document-term matrix for our tf-idf calculations. That looked at words in relation to the documents in which they appeared.
#
# Today, however, we're going to look at words in relation to all other words in a corpus. The vectors that describe these types of relations are called, appropriately enough, *word vectors*. (And sometimes also *word embeddings*).
#
# ### What is a word vector? ###
#
# A *word vector* or *word embedding* is a numerical representation of a word within a corpus, based on co-occurence with other words. Linguists have found that much of the meaning of a word can be derived from looking at the context in which it appears. (In linguistics, this is known as the theory of *distributional semantics*).

# %% [markdown]
# ### What is Word2Vec? ###
#
# Word2vec is one popular approach to representing words in this numerical format. Conveniently, word2vec is implemented in gensim, which we used last class for topic modeling, so we can use that library again.
#
# Word2Vec is a *neural-network* or *deep learning* based approach of generating word vectors.
#
# There are many resources out there that will go into the heavy details of deep learning in general or deep learning for NLP such as Yoav Goldberg's Neural Network Methods in Natural Language Processing (Morgan & Claypool Publishers, 2017). Today, you'll get a high level overview -- just enough for you to understand what w2v is doing.
#
# ### A Picture for Reference ###
#
# Before we get into the details of neural networks and deep learning, let's take a quick look at an image that may help anchor some of the more heady concepts we're about to discuss. This shows us the word pairs for a tiny corpus, consisting of a single sentence, "The quick brown fox jumps over the lazy dog.”
#
# The words pairs from this sentence will constitute our training data: what we will use to generate our word vectors. I’ve used a small window size of 2 just for the example. Most of the time the window size will be slightly longer, like 5. In any case, the word highlighted in blue is the input word.
#
# ![skip-grams](http://mccormickml.com/assets/word2vec/training_data.png)
#
# The neural network is going to learn the statistics from the number of times each pairing shows up. So, for example, the network is probably going to get many more training samples of (“brown”, “fox”) than it is of (“brown”, “unicorn”). When the training is finished, if you give it the word “brown” as input, then it will output a much higher probability for “fox” or “bear” than it will for “unicorn”.
#
# But how are these probabilities generated, and what is a neural network anyway? Let's take a minute to talk through these ideas.

# %% [markdown]
# ### What is a neural network? ###
#
# Here's great explainer adapted from Jer Thorp's recent book, [Living in Data](https://www.jerthorp.com/)
#
# "A neural network is a mathematical model that traces its roots back to the 1940s, when logicians and neuroscientists and cyberneticians were trying to explain how the human brain learns. Taking a page from how actual neurons cells work, neural net pioneers conceived of a system of nodes, each a kind of simplified neuron. These notes hold a number, called an activation potential, above which a node will "fire," sending a signal to one or more other nodes; or, if there is no node to talk to, spitting out a result. Stitched together into collections (networks), these nodes showed the ability to recognize pattern; that is, to take a specific set of numeric inputs and to turn it, consistently, into an expected result."
#
# "Imagine a group of thirteen children in a classroom, sitting in three neat rows of four, with one sitting alone in the back row. Each child can be given either a coookie or a nap. A cookie increases the kid's energy level by one; a nap reduces it by one. If a child's energy goes above a level ten, they have a tantrum, exhausting their excitement but also passing some of it on to any kids they may be connected to. Neural networks tend to be "feed-forward" meaning that the signal can only go in one direection from node to node. In our classroom, we can take this to mean that kids can pass energy back only to those sitting behind them."
#
# "If we feed a plate of cookies to the kids in the front row, we can expect a wave of hysterics to pass from the front to the back of the class, ending with our lonely back-row student in tears. If every child in the front row got the same amount of sugar, and if they all had the same tolerance for it, this wave would be uniform, starting and ending with crying kids. Neural networks function the way they do, though, because the nodes aren't uniform; they are weighted. This meanas eveyr kid in our class has a different tolerance for cookies, a different level at which they'll break into a conniption. The wave of tears won't flow evenly from front to back, and the signal that we pass into the front won't be the same as the onen that comes out the back."
#
# "Asuming the kids in the class are randomly weighted, each with a unique combination of patience and metabolism, feeding different numbers of cookies to the four kids in the front row would result in times when the back-row student loses their temper and times when they don't. Importantly, feeding the same pattern of cookies to the front of the class will always result in the same outcome in the back. This means that the classroom acts together as a pattern-recognition machine. Anything we might be able to translate into 'cookie language," a set of four numbers, can be fed into the machine to get a tantrum-based yes or no."
#
# If the teacher wanted to make sure they got a specific reation from a specific piece of cookie code, they could reseat or replace the students, feeding the cookies to the front until the teacher saw the answer they wanted from the back. The teacher might train the class to recognize their birth year--2015--or the first four notes in "Baby Shark," or a binary representation for the number twelve. In a school assembly, with many more students, this same system could be arranged to recognize bigger sets of numbers, digitized words, or pixelated faces. More than that, a large network might be trained to recognize signals that are similar: faces that are smiling or words that rhyme with "cheese." A crucial point here is that the kids in the network don't need to know anything about the signal or the desired output. They just eat cookies, cry, nap, and compute."
#
# Of course, we're not training a kids-and-cookies neural network. We're training a computational one with a far greater number of nodes.
#
# The important takeaway here, aside from how neural networks go from input to output, is that neural networks are not algorithms in themselves. They just go from start to finish. In order to make use of the input and output, they are most usually paired with algorithms that *train* the network, improving its performance over multiple iterations.
#
# Which brings us back to the word2vec algorithm and how it trains the neural network at its core.

# %% [markdown]
# ### Training the neural network ###
#
# Here, we’re going to train our neural network to do something more complicated than predict whether a kid at the back of the room will cry or not. Our task is this: given a specific word in the middle of a sentence (the input word--like "brown," as in the image above), look at the words nearby and pick one at random. The network is going to tell us the probability for every word in our vocabulary of being the “nearby word” that we chose.
#
# Let's look at our image again:
#
# ![skip-grams](http://mccormickml.com/assets/word2vec/training_data.png)
#
# So "nearby" is actually defined by the "window size" parameter to the algorithm. A typical window size might be 5, meaning 5 words behind and 5 words ahead (10 in total). But in the image the window size is 2.
#
# We train the neural network to do this by feeding these word pairs, and he neural network is going to learn the statistics from the number of times each pairing shows up.
#
# **NOTE:** I've described something called the skim-gram methods of generating word vectors. THere's also another popular method called CBOW (continuous bag of words). The main difference is that while skip gram learns vectors by predicting the context words that come before and after our given word $w$, CBOW predicts the center word $w$ given context words.

# %% [markdown]
# ### One more wrinkle / bonus  ###
#
# One last wrinkle in the word2vec process is that, in the end, we’re not actually interested in the predictions generated by the model. What we're interested in is the weights of the nodes of the network itself. These are the actual "word vectors" that we want to work with.
#
# We can access them fairly easily because word2vec has only a single hidden (or "projection") layer, as displayed in the image below.
#
# ![neural network](http://lklein.com/wp-content/uploads/2019/10/mikolov.png)
#
# Conveniently, all you need is one hidden layer for a neural network to be classified as a "deep" network. So we're doing deep learning! Fancy!

# %% [markdown]
# # Let's try it out!

# %% [markdown]
# ## Import gensim, nltk tokenizers, glob, and Path

# %%
import gensim # remember this from last class? 

# and some other stuff
from nltk.tokenize import sent_tokenize
from nltk.tokenize.treebank import TreebankWordTokenizer
import nltk
nltk.download('punkt')
import glob
from pathlib import Path
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.

# %% [markdown]
# ## Load in our corpus

# %%
# For downloading large files from Google Drive
# https://github.com/wkentaro/gdown
import gdown

# then download the zip file
gdown.download('https://drive.google.com/uc?export=download&id=1SUWUVswaY_RDLhzFruQIDJe-i6I3gznC', quiet=False) 

# unzip it 
# !unzip wheel-clean.zip
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1SUWUVswaY_RDLhzFruQIDJe-i6I3gznC
# To: /content/wheel-clean.zip
# 100%|██████████| 9.36M/9.36M [00:00<00:00, 127MB/s]
# Archive:  wheel-clean.zip
# replace wheel-clean/2017-09-06-White-Supremacist-Symbol-Tarnishes-Old-DeKalb-Courthouse.txt? [y]es, [n]o, [A]ll, [N]one, [r]ename:

# %% [markdown]
# ### Process the docs
#
# As a first step, we'll need to create a list of all the files in the `wheel-clean` directory (folder), with each file stored as a single string.

# %%
# for file i/o
import os

base_dir = "wheel-clean/" 

all_docs = [] # our list which will store the text of each doc; empty for now

docs = os.listdir(base_dir) # get a list of all the files in the directory

for doc in docs: # iterate through the docs
    if not doc.startswith('.'): # get only the .txt files
        with open(base_dir + doc, "r", encoding="utf-8") as file: # force unicode conversion to keep PCs happy
            text = file.read() # read in the file as a single text string
            all_docs.append(text) # append it to the all_docs list

# lastly, just check the length of all_docs to see if it's 4008
len(all_docs)
# Out:
# 4008

# %% [markdown]
# Next, we need to get each of the docs in our `all_docs` list into the format required by gensim's implementation of word2vec.
#
# We know from the gensim documentation (and also common sense) that the input to `word2vec` is sentences. So let's define a function that a takes a list of texts (e.g. our `all_docs` list) and converts it into sentences for gensim word2vec to use. The function will lower-case text and tokenize by sentence and word. It will also print out a count of the sentences in each doc, so that we get some sort of status indicator that it's parsing the sentences correctly.

# %%
# need our handy nltk tokenizer 
tokenizer = TreebankWordTokenizer()

# and we'll get titles
directory = base_dir # as defined above
files = glob.glob(f"{directory}/*.txt") # different way of getting the list of filenames from above, but same thing
wheel_titles = [Path(file).stem for file in files] # the Path library lets you pull out the name of a file, minus the file extension

# and the function
def make_sentences(list_txt):
    all_txt = []
    counter = 0
    for txt in list_txt:
        lower_txt = txt.lower()
        sentences = sent_tokenize(lower_txt)
        sentences = [tokenizer.tokenize(sent) for sent in sentences]
        all_txt += sentences
        print(wheel_titles[counter]) # let's print the title of the article
        print("Sentences: " + str(len(sentences)))  # let's check how many sentences there are per article
        counter += 1
    return all_txt

# %%
# now let's run it
sentences = make_sentences(all_docs)
# Out:
# Streaming output truncated to the last 5000 lines.
# 2018-05-21-White-Hall-to-Undergo-Renovations
# Sentences: 9
# 2017-02-14-Trethewey-To-Deliver-Commencement-Speech
# Sentences: 18
# 2015-04-20-Police-Report-4-21-15
# Sentences: 20
# 2015-04-13-Brief-WellStar-Emory-Agree-on-Merger
# Sentences: 2
# 2018-09-19-Ex-EPD-Officer-Allegedly-Impersonates-Police
# Sentences: 4
# 2018-02-28-On-Fire-Where-Even-is-Norway-
# Sentences: 18
# 2017-01-17-Emory-Hospitals-Fined-for-Injuries
# Sentences: 8
# 2015-10-09-Is-Electronic-Dance-Music-the-21st-century-version-of-Rock-n-Roll-
# Sentences: 27
# 2018-04-25-John-Kim-Teacher-Blogger-Jedi-Master
# Sentences: 36
# 2019-02-13-Women-s-Basketball-Extends-Winning-Streak-to-Seven
# Sentences: 22
# 2017-10-03-Atlanta-Mayoral-Candidates-Discuss-Annexation-AffordableHousing-at-Forum
# Sentences: 37
# 2018-02-27-Behind-the-Movement-Emory-Professors-Talk-MeToo
# Sentences: 38
# 2015-09-30-Poetry-Slam-Features-Ideas-Worth-Spreading-
# Sentences: 24
# 2019-03-20-Letter-to-the-Editor-United-Methodist-Church-Doesn-t-RepresentGlenn-Memorial
# Sentences: 13
# 2015-09-17-Which-Lives-Matter-
# Sentences: 48
# 2018-11-28-Two-Minute-Drill-With-Sydney-Leimbach
# Sentences: 36
# 2018-01-24-The-Best-Films-of-2017
# Sentences: 59
# 2016-11-15-Crime-Report-11-15-16
# Sentences: 21
# 2016-03-23-Police-Report-3-23-16
# Sentences: 16
# 2015-04-20-Atlanta-Pen-Show-A-Pensive-Experience
# Sentences: 26
# 2019-03-27-Emory-Dark-Arts-Showcase-Provides-Platform-For-Mental-IllnessDiscussion
# Sentences: 15
# 2019-02-27-Women-s-Tennis-Dominates-Centre-College
# Sentences: 14
# 2015-09-02-Orientation-Week-Events-Change-Tradition-Remains
# Sentences: 24
# 2018-04-04--Ready-Player-One-A-Nostalgic-Thrill
# Sentences: 34
# 2019-04-08-Men-s-Golf-Finishes-Second-at-Wynlakes
# Sentences: 14
# 2016-06-25-Emory-Influence-Stays-with-Andrew-Wilson-Olympic-Trials-Begin
# Sentences: 53
# 2014-10-23-NBA-Preview-Worst-of-the-Worst
# Sentences: 32
# 2018-11-05--The-Moors-Shines-With-Character-Depth
# Sentences: 26
# 2018-12-22-Zemeckis-Carell-Cultivate-Fantasy-in-Welcome-to-Marwen-
# Sentences: 59
# 2019-03-27-Dynasty-Continues-As-Women-s-Swim-and-Dive-Wins-10th-StraightNCAA-Title
# Sentences: 14
# 2018-04-18-Who-Will-Headline-the-NFL-2018-Draft-Oh-Knows
# Sentences: 37
# 2015-10-07-Elite-Schools-to-Roll-Out-Common-App-Alternative
# Sentences: 18
# 2019-02-27-Softball-Drops-Season-Opener
# Sentences: 15
# 2015-09-29-Troyetsky-s-Pick-Ems-Week-4
# Sentences: 30
# 2015-09-04-So-You-Think-You-Can-Dance-
# Sentences: 22
# 2016-02-17-Women-s-Tennis-begins-Season-with-a-pair-of-wins
# Sentences: 38
# 2016-02-13--Where-to-Invade-Next-Fosters-Dialogue-About-America-s-State-ofLiving
# Sentences: 39
# 2017-09-05-Students-Aid-Harvey-Relief-Efforts
# Sentences: 19
# 2018-01-31-Pajama-Party
# Sentences: 1
# 2016-07-18-Rising-Junior-Responds-to-Recent-Violence
# Sentences: 33
# 2017-09-20--Mochi-Do-About-Nothing-Wagaya-Comes-to-Emory-Village
# Sentences: 13
# 2014-11-18-Emory-Community-Should-Question-Israel
# Sentences: 32
# 2015-03-03-Basketball-Wins-UAA-Conference
# Sentences: 19
# 2016-02-10-Foege-to-Speak-at-Emory-Commencement
# Sentences: 15
# 2017-11-01--Lucky-is-a-Lovely-Swan-Song-for-an-Acting-Legend
# Sentences: 24
# 2018-09-19-Honor-Council-Report-9-19-18
# Sentences: 6
# 2016-04-03-The-Missing-Piece-in-the-Wake-of-the-Trump-Chalkings
# Sentences: 31
# 2015-11-10-College-Football-Week-10-Recap
# Sentences: 30
# 2016-03-22-Emory-Beats-Covenant-in-Three-Game-Series-2-1
# Sentences: 20
# 2015-04-16-Community-Responds-to-EHC-WellStar-Merger
# Sentences: 8
# 2017-02-22-Pitchers-Shine-for-the-Eagles
# Sentences: 34
# 2018-02-06-News-Roundup-2-6-18
# Sentences: 16
# 2015-11-04-Sexual-Assault-Climate-Survey-Futile-Without-Action
# Sentences: 21
# 2018-03-07-Crime-Report-3-7-18
# Sentences: 27
# 2015-04-02-Tennis-Captures-Fourth-Straight-Win
# Sentences: 21
# 2014-11-25-Eagles-Win-Season-s-First-Diving-Invitational
# Sentences: 12
# 2015-12-07-Quilt-on-the-Quad-Commemorates-Victims-of-AIDS
# Sentences: 12
# 2015-12-01--Undertale-Takes-Next-Necessary-Steps-for-Gaming-to-Become-Art
# Sentences: 31
# 2017-03-02-Do-si-Do-s-and-Don-ts
# Sentences: 31
# 2015-11-04-The-Search-to-Replace-Wagner-Begins
# Sentences: 15
# 2018-09-05-Student-Government-Leaders-Consider-Modifying-SAF-Split
# Sentences: 20
# 2014-11-25-Crime-Report-11-25-14
# Sentences: 23
# 2015-03-24-Five-Webcomics-You-Need-to-Check-Out
# Sentences: 29
# 2019-03-06-Comedian-Hari-Kondabolu-Enthralls-Center-Stage
# Sentences: 19
# 2015-02-23--Vagina-Monologues-Effective-Not-Ideal
# Sentences: 25
# 2016-12-05-Men-s-Swimming-and-Diving-Reaches-for-First-NCAA-ChampionshipTitle
# Sentences: 25
# 2014-11-13-More-Than-74-Students-Infected-with-Gastroenteritis
# Sentences: 14
# 2019-04-03-No-1-Ranked-Tennis-Cruises-to-Victory
# Sentences: 16
# 2014-11-25--Horrible-Bosses-2-Anything-But-Horrible
# Sentences: 28
# 2016-03-30-Women-s-Tennis-Convincingly-Wins-Fab-5-Tournament
# Sentences: 18
# 2018-10-17-Yarbrough-Jack-Of-All-Trades
# Sentences: 21
# 2016-02-28-Saba-s-Chickpea-Tomato-Soup-An-Interview-and-a-Knock-Off-Recipe
# Sentences: 35
# 2017-09-06-Change-the-Name-John-Emory-s-Shameful-Ties-to-Slavery
# Sentences: 18
# 2019-04-05-Students-Outraged-Over-Mock-Eviction-Notices
# Sentences: 30
# 2019-01-24-Looking-Back-at-2018-s-Top-10-Films
# Sentences: 40
# 2017-09-19-DUC-ling-Decorates-With-Ducks
# Sentences: 28
# 2016-08-31-Women-Men-Cross-Country-Ready-to-Start-Season
# Sentences: 18
# 2018-10-29-After-the-Tree-of-Life-Shooting-It-s-Time-to-Speak-Out
# Sentences: 18
# 2016-10-05-Retro-Rewind-Phantasm-1979-
# Sentences: 32
# 2015-03-24-Women-s-Swim-and-Dive-Wins-NCAA-D-III-Championships
# Sentences: 22
# 2015-04-02-GlobeMed-Engages-Students-in-Global-Issues
# Sentences: 11
# 2018-02-05-Banning-Joint-Candidacy-An-Ineffective-Change
# Sentences: 10
# 2018-04-11-EPC-Opposes-Sigma-Chi-s-Exclusionary-Derbys-Day-Apparel
# Sentences: 19
# 2014-11-21-Sustainability-Security-Vital-to-Future-of-Food
# Sentences: 39
# 2016-09-08-DJ-R3hab-Smash-Mouth-to-Perform-at-Homecoming
# Sentences: 13
# 2017-11-28-Burglar-Loots-Clairmont-Apartment
# Sentences: 7
# 2017-02-21-Oscars-Allow-for-Escapism-Despite-Predictability
# Sentences: 27
# 2014-10-02-Honor-Council-10-3-14
# Sentences: 22
# 2016-01-19-In-the-Ring-with-Melissa-Querrey
# Sentences: 68
# 2017-03-14-Emory-Healthcare-Partners-with-Atlanta-Braves
# Sentences: 6
# 2019-09-16--Ad-Astra-a-Stellar-Cinematic-Achievement
# Sentences: 26
# 2018-02-28-Men-s-Tennis-Claims-ITA-Championship-Throne
# Sentences: 38
# 2017-02-01-Title-IX-Must-Prioritize-Survivors
# Sentences: 18
# 2018-04-14-Hawks-Humbled-Ready-for-Rebuild
# Sentences: 28
# 2019-03-27--Love-Death-Robots-Oscillates-From-Brilliance-to-Banality
# Sentences: 24
# 2015-04-03-What-are-the-Liberal-Arts-Anyways-
# Sentences: 25
# 2019-01-28-University-Closes-Tuesday-Due-to-Forecasted-Inclement-Weather
# Sentences: 4
# 2016-12-03-Emory-Vows-to-Abide-by-Law-in-Protecting-UndocumentedStudents
# Sentences: 12
# 2017-11-14-On-Fire-We-ve-Got-School-Spirit-Yes-We-Do-
# Sentences: 17
# 2017-03-29-Albatross-Brightens-Tough-Tourney
# Sentences: 24
# 2018-04-17-GSGA-Renews-Charters-for-Graduate-wide-Organizations
# Sentences: 7
# 2015-11-02--Freeheld-Tells-Important-Story-But-Lacks-Liveliness
# Sentences: 42
# 2019-02-13-Ga-Constitutional-Carry-Proposal-Reckless
# Sentences: 11
# 2017-11-29-Dee-Rees-Mints-a-New-American-Classic-with-Mudbound-
# Sentences: 27
# 2017-09-20-Music-Midtown-s-Soulful-Performances-Make-Memories
# Sentences: 39
# 2014-11-20-Offense-Propels-Eagles-to-Victory-in-Season-Opener
# Sentences: 14
# 2016-04-09-Sherman-Alexie-Talks-Writing-Boldly-Reflects-on-Grief
# Sentences: 32
# 2019-09-18-Reading-of-Homer-s-Iliad-Transports-Listeners-to-Ancient-Greece
# Sentences: 20
# 2018-11-13--The-Darkest-Star-an-Addictive-Start-to-Spin-Off-Series
# Sentences: 27
# 2014-11-07-Going-Walden-in-Decatur
# Sentences: 26
# 2014-11-04-From-the-Archives-Shock-Treatment-Electrifies
# Sentences: 17
# 2014-11-18-Emory-Research-Receives-521-8-Million-in-2014
# Sentences: 4
# 2017-11-29-Greta-Gerwig-Soars-with-Lady-Bird-
# Sentences: 30
# 2016-04-27-Emory-Goes-2-1-in-Season-s-Final-Weekend
# Sentences: 17
# 2015-02-23-College-Night-at-the-High-Museum-Showcased-Students-Art
# Sentences: 22
# 2016-04-13-Caroline-Schmidt-Awarded-Beinecke-Scholarship
# Sentences: 18
# 2015-09-09-New-Athletic-Director-Ready-to-Fill-Big-Shoes
# Sentences: 24
# 2016-03-14--That-Dragon-Cancer-Grief-And-Faith-Through-Gaming
# Sentences: 39
# 2017-01-18-On-Fighting-Fake-News
# Sentences: 12
# 2015-10-21-College-Football-Recap-Week-7
# Sentences: 32
# 2016-04-13-Naomi-Maisel-Wins-McMullan-Award
# Sentences: 10
# 2017-02-08-Over-Easy-Folk-Art-The-Quest-for-French-Toast-Continues
# Sentences: 26
# 2017-03-01--Call-of-Duty-Needs-to-Step-Back
# Sentences: 21
# 2014-11-11--Motion-Will-Make-You-Move
# Sentences: 8
# 2015-09-14-Dark-Horse-Why-BoJack-Horseman-is-Changing-Animated-Comedy
# Sentences: 32
# 2015-04-23-Oxford-Hosts-Sexual-Assault-Awareness-Week-Consent-Campaign
# Sentences: 9
# 2015-04-09-Reverend-Discusses-Church-s-Role-in-Ferguson
# Sentences: 13
# 2015-07-28-New-Service-Provider-Brings-Many-Dining-Changes
# Sentences: 25
# 2014-12-02-ATO-and-TEDx-Emory-s-Salon-Brings-Social-Activism-Health-andFeminism-to-Eagle-Row
# Sentences: 12
# 2017-04-12-The-Senate-s-Impending-Nuclear-Winter
# Sentences: 35
# 2018-02-27-FACE-Announces-New-Bhojanic-Hours-DUC-ling-Sandwich-Station
# Sentences: 13
# 2015-09-30-Bring-Back-the-Peanuts-
# Sentences: 20
# 2018-02-21-Wheel-Wins-Six-GCPA-Journalism-Awards
# Sentences: 14
# 2019-04-11-BSA-Activities-Finances-Halted-Over-Anonymous-Complaints
# Sentences: 17
# 2017-03-22-Swimming-Sweeps-NCAAs
# Sentences: 21
# 2015-02-26-Medium-Rare-Top-Atlanta-Neighborhoods-for-Food
# Sentences: 17
# 2015-03-31-Dooley-s-Week-2015-The-Highlights
# Sentences: 1
# 2018-12-25-Barry-Jenkins-Talks-Makings-From-Beale-Street-After-WinningOscar
# Sentences: 57
# 2018-10-16-Honor-Council-Report-10-17-18
# Sentences: 13
# 2019-09-10-Crime-Report-9-11-19
# Sentences: 17
# 2016-10-15-Daft-Punk-s-Enigmatic-Rise
# Sentences: 23
# 2017-01-25-Delta-Tau-Delta-Sigma-Phi-Epsilon-to-Share-House-at-15-Eagle-Row
# Sentences: 12
# 2015-12-09-Today-s-Student-Activists-Illuminate-Path-to-Progress
# Sentences: 45
# 2015-10-26-First-Themed-Student-Art-Gallery-Proves-Success
# Sentences: 18
# 2018-10-31-Voter-Suppression-Kemp-Revives-a-Racist-Past
# Sentences: 13
# 2017-10-18-Atlanta-City-Council-Holds-on-Annexation-Vote-ApprovesIntergovernmental-Agreements
# Sentences: 7
# 2015-11-12-Beyond-the-Blockbuster-A-Q-A-with-Andy-Ditzler-Curator-of-theFilm-Love-Series
# Sentences: 48
# 2014-10-07-MARBL-Acquires-Flannery-O-Connor-s-Archive
# Sentences: 9
# 2015-03-19-Our-Opinion-Enriching-Minds-Not-Resumes
# Sentences: 19
# 2016-04-04-The-Past-and-Future-of-R-Rated-Superhero-Films
# Sentences: 37
# 2018-10-31-Midterm-Elections-Vote-for-the-Earth
# Sentences: 22
# 2016-03-29-DJ-Khaled-to-Perform-at-Dooley-s-Week-Concert
# Sentences: 7
# 2018-11-28-Turkey-Day-at-the-D-White-House-Ma-Hosts-Thanksgiving-Dinner
# Sentences: 30
# 2018-11-08-Women-s-Soccer-Secures-NCAA-Berth
# Sentences: 17
# 2018-11-07-Three-College-Council-Members-Resign-CC-to-Hold-StandardsHearings
# Sentences: 21
# 2018-03-28-Lil-Yachty-to-Headline-Dooley-s-Ball-2018
# Sentences: 15
# 2019-03-27-Eagles-Secure-Two-Important-West-Coast-Victories
# Sentences: 21
# 2018-06-28-In-Damsel-the-West-is-No-Country-for-Thirsty-Men
# Sentences: 39
# 2015-04-06--Kimmy-Schmidt-Hilarious-Engaging
# Sentences: 11
# 2016-04-11-Hawks-defeat-Celtics-to-hold-onto-No-3-seed
# Sentences: 23
# 2018-11-08-Fox-Kings-Rout-Hawks
# Sentences: 28
# 2016-01-16--Hamilton-Hip-Hop-Musical-Illuminates-Narrative-Storytelling
# Sentences: 39
# 2014-10-02-Poets-Writers-Remember-Heaney
# Sentences: 9
# 2017-02-22-Former-Grad-Student-Joins-Environmental-Council
# Sentences: 10
# 2019-03-29-AEPi-House-Trashed-After-Notice-to-Vacate
# Sentences: 7
# 2014-10-30-School-Spirit-Found-in-Small-Moments
# Sentences: 51
# 2017-04-01-You-ve-Got-Kale-ATL-Grocery-Guide
# Sentences: 36
# 2019-04-24-Junior-Crafts-Vibrant-Affordable-Needlepoint-Art
# Sentences: 28
# 2018-12-19--White-Christmas-is-Merry-Bright-and-a-Little-Too-White
# Sentences: 27
# 2018-02-21-Young-Squad-Lacks-Consistency-Reclaims-Home-Court
# Sentences: 39
# 2016-09-28-Golf-Star-Talks-Career-Expectations-Idols
# Sentences: 24
# 2015-11-26-Two-Emory-Students-Robbed-at-Gunpoint-Near-Campus
# Sentences: 7
# 2018-09-19-Bird-Scooters-Flock-to-Campus
# Sentences: 32
# 2016-03-02-Rosenstock-advances-to-NCAA-Championships
# Sentences: 7
# 2015-04-02-Faculty-Staff-Win-Emory-Awards-of-Distinction
# Sentences: 8
# 2015-04-06-Jones-Wins-2015-McMullan-Award
# Sentences: 10
# 2014-10-30-Kid-Dean-Debuts-New-Video
# Sentences: 11
# 2016-12-01-Former-American-Studies-Professor-Dies
# Sentences: 24
# 2017-09-27-True-Food-Kitchen-A-Classic-Option-for-the-Healthy-Student
# Sentences: 24
# 2016-04-20-Employee-Council-Town-Hall-Creates-Dialogue-Between-Faculty-Staff-and-Administrators
# Sentences: 21
# 2017-01-25-NHL-Power-Rankings-Metropolitan-Division-Reigns-Supreme
# Sentences: 45
# 2015-03-31-Lamar-s-To-Pimp-A-Butterfly-A-Modern-Classic
# Sentences: 26
# 2018-11-27-Kusama-s-Infinity-Mirrors-a-Vibrant-Respite-From-Reality
# Sentences: 28
# 2019-09-25-Callahan-s-Corner-The-Year-of-the-Backup
# Sentences: 16
# 2018-09-11-University-Announces-New-Strategic-Framework
# Sentences: 13
# 2019-09-25-Students-Participate-in-National-Climate-Strike
# Sentences: 13
# 2017-11-01-Tennis-Coach-Faces-Backlash-Over-Puerto-Rican-Themed-Costumes
# Sentences: 48
# 2016-11-02-Uncertainty-Looms-as-Men-Prepare-for-Final-Stretch
# Sentences: 27
# 2014-11-20-Books-We-Love-The-Ghost-Bride-is-a-Gripping-Ghostly-Mystery
# Sentences: 19
# 2017-02-08-Indoor-Season-Continues-with-Buccaneer-Invitational
# Sentences: 28
# 2017-10-24-Fox-News-Viewers-More-Likely-to-Vote-for-Republicans-Study-Finds
# Sentences: 15
# 2015-03-24-Team-Continues-Winning-Streak
# Sentences: 17
# 2016-06-29-Wagner-Honored-with-Ethics-Chair-and-Quadrangle-Naming-GivenEmeritus-Status
# Sentences: 21
# 2015-12-05-Reviving-a-Television-Show-W-Bob-and-David-
# Sentences: 34
# 2018-10-17-Late-Goals-Cost-Eagles-Big-Time
# Sentences: 30
# 2017-03-07-Hardaway-Hawks-Unable-to-Overcome-Cavaliers-NBA-Record-25Three-Pointers
# Sentences: 36
# 2015-09-16-Our-Opinion-Secret-Society-Should-Have-No-Role-in-New-Greek-LifeTask-Force
# Sentences: 17
# 2017-11-15-Dongwoo-Kim-Finds-Meaning-in-Magic
# Sentences: 47
# 2017-09-20-Rekindle-the-HOPE-Scholarship
# Sentences: 26
# 2017-04-19-Benefit-of-the-Sprout-Green-Sprout-Review
# Sentences: 27
# 2015-09-22-SGA-Discusses-SafeRide-Changes
# Sentences: 7
# 2015-03-03-Active-Minds-Tackle-Ed-the-Eating-Disorder-in-Annual-Musical
# Sentences: 28
# 2015-04-06-Baseball-Takes-Three-Against-Huntingdon
# Sentences: 32
# 2017-03-29-Revisiting-Big-Cuts-for-Big-Bird
# Sentences: 15
# 2017-03-29-The-Failure-of-Governance-at-Emory
# Sentences: 25
# 2016-01-22-The-Most-Anticipated-Films-of-2016
# Sentences: 28
# 2015-10-21-Latino-Student-Organization-Celebrates-Hispanic-Heritage-Month
# Sentences: 14
# 2015-02-24-Police-Report-2-24-15
# Sentences: 15
# 2019-09-11-Emory-Hosts-Forum-on-U-S-Measles-Outbreak
# Sentences: 22
# 2016-09-04-Police-Report-08-31-2016
# Sentences: 32
# 2017-04-19-News-Roundup-4-19-17
# Sentences: 5
# 2015-04-20-SGA-Lacks-Quorum-Discusses-Library-Services-Rape-Kits
# Sentences: 9
# 2018-07-22-In-The-King-America-Can-t-Help-Falling-Apart
# Sentences: 33
# 2015-04-16-Students-Engage-in-Social-Enterprise
# Sentences: 20
# 2016-11-14--Before-the-Flood-Lifts-Curtain-on-Climate-Change
# Sentences: 16
# 2018-04-03-Andrew-Young-Talks-Politics-Spirituality
# Sentences: 34
# 2017-09-19-Protests-Erupt-After-Tech-Police-Kill-Pride-Leader
# Sentences: 23
# 2016-10-08-NFL-Week-5
# Sentences: 15
# 2018-11-28-Emory-Sports-Report-Nov-28-2018
# Sentences: 33
# 2014-11-11-Crime-Report-11-11-14
# Sentences: 16
# 2016-03-29-Intellectual-Courage-Requires-Humility
# Sentences: 15
# 2016-04-16-Pete-Holmes-Butters-Up-the-Crowd
# Sentences: 18
# 2017-01-18-SGA-Sends-Split-Bill-to-University-wide-Referendum
# Sentences: 6
# 2018-04-22-Gramatik-Graces-Tabernacle-with-New-Brand-of-EDM
# Sentences: 29
# 2018-09-29-Bruner-Named-Senior-VP-of-Research
# Sentences: 8
# 2017-11-08-In-Atlanta-Mayoral-Race-Bottoms-Rises-to-the-Top
# Sentences: 18
# 2017-09-27-Gyllenhaal-and-Maslany-Help-Stronger-Stand-Out
# Sentences: 25
# 2018-09-10-Emory-Stays-No-21-in-U-S-News-Ranking
# Sentences: 24
# 2015-03-23-SGA-Organizations-Must-Justify-Use-of-Funds
# Sentences: 1
# 2016-10-05-Women-s-Soccer-Takes-Down-UChicago-in-Conference-Opener
# Sentences: 18
# 2015-09-11-Proud-To-Be-a-Part-of-Emory-Pride
# Sentences: 33
# 2018-12-05-Young-Collins-Excel-in-Loss
# Sentences: 21
# 2018-12-05-The-Curious-Case-of-Markelle-Fultz
# Sentences: 49
# 2016-02-22-Women-Cruise-To-Aces-for-Cure-Wins
# Sentences: 11
# 2018-09-19-Ebrik-Spills-the-Beans-at-Carlos
# Sentences: 20
# 2017-02-22--Logan-Is-a-Bittersweet-End-to-the-Wolverine-Trilogy
# Sentences: 25
# 2017-01-16-Our-Interview-with-NAACP-President-CEO-Cornell-Brooks
# Sentences: 27
# 2017-10-24-Post-Post-Malone-A-Concert-Review
# Sentences: 19
# 2019-04-01-SGA-Finalizes-32-Percent-Cut-to-Media-Council
# Sentences: 19
# 2016-04-14-DJ-Khaled-Blesses-Emory-Students
# Sentences: 23
# 2015-12-02-Women-s-Basketball-Team-Moves-to-4-1-on-the-Season
# Sentences: 21
# 2017-09-06-ParkGrounds-Boasts-Coffee-Dogs-Smiles
# Sentences: 15
# 2017-09-19-Two-College-Council-Senior-Legislators-Resign
# Sentences: 6
# 2016-02-03-Police-Report-2-03-16
# Sentences: 21
# 2018-03-07-KA-to-Replace-MLAO-on-Eagle-Row
# Sentences: 11
# 2014-10-05-Swastikas-Drawn-on-AEPi-Walls
# Sentences: 14
# 2017-02-08-Eagles-Fail-to-Produce-on-Road-Trip
# Sentences: 36
# 2018-04-11-Between-Midnight-and-Dawn-Behind-the-Security-Desk
# Sentences: 38
# 2017-09-06-Eagles-Survive-Challenging-Road-Trip
# Sentences: 25
# 2019-01-30-Convocation-Hall-Opens-After-20-Million-Renovations
# Sentences: 16
# 2017-11-15--Luzia-A-Walking-Dream-of-Mexico-Lives-Up-to-its-Name
# Sentences: 34
# 2017-03-29-Pioneering-Civil-Rights-Reporter-Emory-Alumnus-Dies
# Sentences: 34
# 2014-10-15-Religious-Celebration-Springs-Memories
# Sentences: 22
# 2017-09-06-Emory-Doctors-Aid-Refugees
# Sentences: 30
# 2016-03-30-Softball-Goes-Undefeated-Over-the-Weekend
# Sentences: 27
# 2018-04-03-News-Roundup-4-4-18
# Sentences: 25
# 2015-05-07-BSA-Media-Groups-ZBT-to-Occupy-Eagle-Row-Themed-Houses
# Sentences: 6
# 2017-10-02-Emory-Works-to-Eradicate-Ebola-Epidemic
# Sentences: 26
# 2019-09-25-Doolino-Knows-Best-Monikers-and-Muscles
# Sentences: 21
# 2019-04-09--Penguins-a-Heartwarming-Tale-in-a-Subzero-World
# Sentences: 18
# 2017-04-19-A-Journey-Toward-Self-Realization
# Sentences: 14
# 2014-10-07--Gone-Girl-Honors-Book-Loses-Sparkle
# Sentences: 23
# 2017-10-25-Georgia-Association-of-Sleep-Professionals-Conference
# Sentences: 2
# 2018-03-28-Emory-Community-
# Sentences: 41
# 2019-09-18-SGA-Confirms-VP-of-Alumni-Relations-Waits-to-Create-Arts-andSustainability-Committees
# Sentences: 5
# 2019-04-17-Trump-s-Block-of-Major-League-Baseball-Cuba-Deal-Only-HurtsPlayers
# Sentences: 21
# 2017-11-14-SGA-Spends-2-241-22-on-Wonderful-Wednesday-After-DarkParaphernalia
# Sentences: 8
# 2015-12-12-A-Case-for-Understanding
# Sentences: 31
# 2016-01-06-Looks-Aren-t-Everything-Macbeth-and-In-the-Heart-of-the-Sea-
# Sentences: 45
# 2015-03-27-Firms-Compete-to-Design-New-Campus-Life-Center
# Sentences: 11
# 2018-04-09-Wheel-Staff-Selected-as-Finalists-for-SPJ-Awards
# Sentences: 3
# 2018-01-30-News-Roundup-1-31-18
# Sentences: 34
# 2014-11-21-Origins-of-Food-Overlooked-in-Society
# Sentences: 37
# 2014-10-03-Beej-What-the-First-Quarter-Tells-Us
# Sentences: 39
# 2018-02-21-CLC-Worker-Constructs-Life-of-Art-Purpose
# Sentences: 30
# 2015-08-31-Student-Digital-Life-Adds-New-Technology-and-Services
# Sentences: 49
# 2015-03-27-Our-Opinion-Diversity-Accountability-and-Feedback-at-SPC
# Sentences: 15
# 2019-01-30-Democrats-Must-Unite-to-Beat-Republicans-in-2020
# Sentences: 25
# 2015-04-07-Netanyahu-s-Re-election-Not-Reason-to-Cut-Ties-With-Israel
# Sentences: 38
# 2019-01-30-Bourdain-Screening-Highlights-Food-Waste
# Sentences: 24
# 2019-02-27-Crime-Report-2-27-2019
# Sentences: 38
# 2018-04-04--Unsane-is-Horror-for-the-MeToo-Generation
# Sentences: 33
# 2017-04-19-Learning-Through-Adversity-Hard-Times-Good-People
# Sentences: 19
# 2016-04-13-Women-Split-D-1-Road-Trip-to-South-Carolina
# Sentences: 14
# 2018-09-28-The-Wheel-Takes-TIFF-Day-Three-9-13-
# Sentences: 59
# 2015-04-07-Police-Report-4-07-15
# Sentences: 9
# 2015-02-24-Eagles-Dominate-at-Last-Meet-Before-NCAA-Championships
# Sentences: 30
# 2016-02-09-Super-Bowl-50-The-Commercials-Graded
# Sentences: 24
# 2019-09-04-Best-in-Show-Cultivates-Cross-Cultural-Pride
# Sentences: 24
# 2019-04-03-Quezada-Selected-as-2019-College-Orator
# Sentences: 6
# 2015-03-02-Emory-Women-of-Color-Stun-in-For-Colored-Girls-
# Sentences: 24
# 2014-10-21-The-Best-Possible-Formulaic-Love-Story
# Sentences: 30
# 2018-02-21-Entrepreneurial-Alumnus-an-Adequate-Choice
# Sentences: 10
# 2017-04-05-Research-Cuts-Deserve-More-Attention
# Sentences: 28
# 2018-10-02-Tayari-Jones-Pearl-Cleage-Discuss-Writing-Community
# Sentences: 30
# 2016-03-30-Kendrick-Lamar-Continues-to-Transform-Hip-Hop-With-untitledunmastered-
# Sentences: 36
# 2014-10-24-Beej-Week-of-Road-Warriors
# Sentences: 33
# 2016-03-21-The-Best-Batman-Film-is-One-You-Have-Probably-Never-Seen
# Sentences: 35
# 2017-03-30-Doolino-Knows-Best-Turning-to-Mush-rooms-
# Sentences: 32
# 2016-05-23-Foals-A-Delicate-Balance-of-Thunder-Edge-and-Serenity
# Sentences: 21
# 2017-11-15-Cross-Country-Teams-Advance-to-Nationals
# Sentences: 27
# 2019-03-27-Peele-Successfully-Critiques-U-S-in-Us-
# Sentences: 29
# 2015-09-02-The-Barkley-Forum-Debates
# Sentences: 58
# 2018-02-13-BeltLine-Visionary-Named-2018-Class-Day-Speaker
# Sentences: 7
# 2017-11-15-Hoodie-Allen-Brings-Raw-Skill-to-Atlanta-on-Hype-Tour
# Sentences: 30
# 2017-04-18-Crime-Report-4-19-17
# Sentences: 31
# 2018-02-21-NRA-Funding-Stymies-Legislation
# Sentences: 20
# 2017-09-20-Tri-Delta-Members-Offered-Ultimatum-Nationals-Declines-toExplain-Details
# Sentences: 7
# 2017-10-25-Hamilton-Bests-Vettel-at-U-S-Grand-Prix
# Sentences: 17
# 2017-11-01-Hundred-Word-Rant-On-Duc-ling-Hours
# Sentences: 3
# 2015-10-27-Emory-to-Potentially-Replace-Blackboard-Tests-New-System
# Sentences: 9
# 2019-02-11-Andrew-Young-to-Deliver-Commencement-Keynote
# Sentences: 9
# 2015-12-14--Krampus-is-Non-traditional-Christmas-Fun-for-the-Naughty-Kids
# Sentences: 32
# 2016-03-20-Hawks-top-Rockets-and-lengthen-win-streak-to-five
# Sentences: 14
# 2018-11-25-Eagles-are-Volleyball-Champs
# Sentences: 44
# 2016-04-13-Committee-Completes-First-Presidential-Interviews
# Sentences: 14
# 2017-02-22-Trump-is-One-Expensive-Hypocrite
# Sentences: 28
# 2018-07-02-SCOTUS-Travel-Ban-Ruling-Harms-Emory-s-Intellectual-Diversity
# Sentences: 25
# 2017-04-19-Professor-Discusses-Disability-At-Emory-and-Abroad
# Sentences: 29
# 2017-03-01-Emory-s-War-on-Greek-Life
# Sentences: 25
# 2016-06-17-Samberg-s-Popstar-Falls-Flat
# Sentences: 25
# 2016-09-04-Forman-Moves-to-Tulane-Elliott-Zola-Join-Administration
# Sentences: 30
# 2017-09-13-Eagles-Ace-Competition-in-4-0-Weekend
# Sentences: 19
# 2018-03-28--Love-Simon-Stars-Spill-All
# Sentences: 34
# 2015-11-21-Paris-Social-Media-and-Us
# Sentences: 25
# 2018-10-30--Mid90s-a-Down-to-Earth-Skater-Dramedy
# Sentences: 32
# 2016-01-19-Men-s-Team-Splits-Road-Trip-vs-NYU-Brandeis
# Sentences: 21
# 2017-02-10-SGA-Casts-Informal-Votes-on-Proposed-Gov-Structure
# Sentences: 20
# 2019-02-15-Dooley-s-Players-Reimagine-Pillowman-
# Sentences: 35
# 2015-10-05-Former-U-S-Poet-Laureate-Charles-Wright-Gives-Reading
# Sentences: 33
# 2015-04-20-Emory-Competes-Against-D-1-teams
# Sentences: 11
# 2018-02-28-NHL-Deadline-Deals-Bolster-Stanley-Cup-Race
# Sentences: 19
# 2016-09-07-On-the-Necessitation-of-a-New-Editorial-Board
# Sentences: 11
# 2017-10-25-The-Need-for-Positivity-in-Millennial-Politics
# Sentences: 41
# 2017-11-02-Sleeping-With-Sirens-Bring-the-Energy-at-the-Masquerade
# Sentences: 22
# 2017-03-23-SGA-VP-Candidate-Lifts-Verbatim-Portions-of-Singh-s-2016-Platform
# Sentences: 21
# 2016-02-14-My-Favorite-Film-Romances-Since-I-ve-Been-Alive-
# Sentences: 38
# 2018-04-18--Black-Ops-4-A-Final-Hope
# Sentences: 25
# 2018-12-05-Crime-Report-12-5-18
# Sentences: 29
# 2015-11-14-Paris-Attack-Afterthoughts
# Sentences: 25
# 2016-10-25--Borrowed-Time-Represents-Pixar-Animators-Dismal-Side
# Sentences: 19
# 2019-09-18-Women-s-Golf-Makes-Its-Debut
# Sentences: 12
# 2018-02-06-Crime-Report-2-7-18
# Sentences: 30
# 2014-10-06-Yik-Yak-Wit-Destroys-Discourse
# Sentences: 35
# 2017-01-29-The-UN-Resolution-Anti-Israel-and-Anti-Semitic
# Sentences: 28
# 2019-04-10--European-Masterworks-Stun-at-the-High
# Sentences: 15
# 2019-08-04-Unequal-Play-and-Unequal-Pay-An-Analysis-of-the-US-Women-sNational-Team-s-Controversial-Lawsuit
# Sentences: 48
# 2018-12-04-Emory-Student-Health-Services-Nurse-Undergoing-SANE-Training
# Sentences: 16
# 2018-06-02--Filmworker-Pays-Tribute-to-a-Life-Behind-the-Camera
# Sentences: 24
# 2016-03-26-Speech-Not-Silencing-Will-Defeat-Donald-Trump
# Sentences: 47
# 2015-04-10-Do-Something-Crazy-Not-a-Keg-Stand
# Sentences: 17
# 2016-05-05-BRIEF-Student-Hit-By-Car-DUC-Drops-Inspection-Points
# Sentences: 8
# 2019-02-26--Apex-Legends-Sets-the-New-Standard
# Sentences: 26
# 2016-03-29-Free-Spaces-Not-Safe-Spaces
# Sentences: 31
# 2014-11-07-Professor-Kim-Enriches-Psychology-Department
# Sentences: 24
# 2015-03-30-Emory-Ranks-First-in-NIH-Fellowship-Recipients
# Sentences: 10
# 2017-03-29-After-20-15-Loss-Series-Concludes-in-Tie
# Sentences: 12
# 2015-04-24-Emory-Was-Sweet-Bitter
# Sentences: 21
# 2017-09-12-Trump-s-DACA-Decision-Met-with-Lawsuits-Criticism
# Sentences: 34
# 2017-11-01-University-Neglects-to-Explain-EEMS-Hiatus
# Sentences: 10
# 2015-09-25-Hol-Up-Kendrick-Lamar-s-To-Pimp-A-Butterfly-Is-More-Than-Alright-
# Sentences: 24
# 2015-03-20-Women-Travel-to-Calif-For-Spring-Break-Games
# Sentences: 11
# 2016-02-04-New-Art-Club-Seeks-to-Serve-Previously-Underserved-Communities
# Sentences: 13
# 2017-01-31-Crime-Report-2-1-17
# Sentences: 22
# 2017-09-21-SGA-Confirms-Reps-Updates-Elections-Code
# Sentences: 11
# 2014-10-02-Atlanta-Food-Truck-Park-Brings-Enriching-Epicurian-Experience
# Sentences: 12
# 2014-11-07-Nosebleeds-Early-Game-Anxiety
# Sentences: 54
# 2018-02-07-SGA-Tables-Elections-Code-Bill-Vote
# Sentences: 29
# 2019-04-24-Toll-Brothers-Requests-Hold-on-Proposed-Housing-Development
# Sentences: 6
# 2016-02-16-If-we-re-going-to-talk-abortion-this-election-year-
# Sentences: 30
# 2015-04-06-Track-Competes-at-VertKlasse-Meet
# Sentences: 18
# 2017-10-03-Vegas-Massacre-Stuns-Emory
# Sentences: 25
# 2019-09-18-Emory-Study-Examines-For-Profit-Dialysis-Centers
# Sentences: 6
# 2016-01-26--The-5th-Wave-Author-Rick-Yancey-Discusses-Film-Adaptation-Inspiration
# Sentences: 46
# 2017-04-11-Crime-Report-4-12-17
# Sentences: 22
# 2017-10-18--American-Made-is-Just-Plane-Fun
# Sentences: 27
# 2017-01-17-Doolino-Knows-Best-Time-to-Get-Into-the-Greek-Life
# Sentences: 24
# 2016-02-18-Biopic-Race-Has-Difficulty-Keeping-Up
# Sentences: 21
# 2016-03-02-Emory-nearly-misses-at-UAA-Championships
# Sentences: 29
# 2014-11-20-Diwali-Dazzles-With-Dancing-and-Dining
# Sentences: 18
# 2015-09-14--Fantastic-Four-What-Happened-
# Sentences: 35
# 2015-03-30-Emory-Graduate-Students-Recipients-of-Emerging-Artist-Awards
# Sentences: 16
# 2016-11-02-The-Experience-After-Emory-Sally-Mundell
# Sentences: 29
# 2017-10-03-Report-Reveals-Decreased-Campus-Drug-Liquor-Law-Violations
# Sentences: 5
# 2018-12-05-Eagles-Set-Records-Trounce-Trinity
# Sentences: 23
# 2016-09-13-Trethewey-Awarded-25-000-Poetry-Fellowship
# Sentences: 14
# 2017-09-15-Carter-Give-Trump-Some-Credit-for-DACA-Decision
# Sentences: 20
# 2019-02-19-Enku-Gelaye-Talks-Path-to-Emory-Greek-Life-s-Benefits
# Sentences: 6
# 2019-02-27-Comedy-Show-Succeeds-in-Seamless-Fashion
# Sentences: 23
# 2016-03-31-International-Festival-and-Emory-World-Cup-Bridges-StudentCommunities
# Sentences: 14
# 2017-10-03-Dining-Takes-Feedback-on-Duc-ling-at-FACE-Meeting
# Sentences: 11
# 2017-02-01-News-Roundup-2-1-17
# Sentences: 11
# 2017-03-22-GSGA-s-Troubling-Obstruction-of-Free-Press
# Sentences: 12
# 2015-09-22-Ricardo-Guti-rrez-Mouat-63-Engaged-and-Dedicated
# Sentences: 15
# 2017-10-18-Doolino-Knows-Best-Falling-Apart
# Sentences: 29
# 2019-09-18-New-Point-Ramen-Joint-Doesn-t-Disappoint
# Sentences: 16
# 2016-03-26-Rep-Congressman-Talks-Trump-Conservatism-on-Campus
# Sentences: 23
# 2016-10-06-Sports-Medicine-Complex-Projected-to-be-NBA-Hot-Spot
# Sentences: 12
# 2018-04-10-Crime-Report-4-11-18
# Sentences: 37
# 2015-12-13-Emory-Reflects-On-Black-Students-Demands-Racial-Climate
# Sentences: 103
# 2014-11-21-FREED-Act-Aims-at-Eating-Disorders
# Sentences: 22
# 2019-05-12-Goodwin-Farley-Completes-Bachelor-s-Degree-With-Full-Time-Joband-Personal-Tragedy
# Sentences: 40
# 2016-11-16-Emory-Team-Wins-Bronze-for-DNA-Research
# Sentences: 13
# 2015-11-09-Runners-struggle-at-UAA-Championships
# Sentences: 20
# 2015-04-20-Men-s-Story-Project-Questions-Gender-Roles
# Sentences: 7
# 2019-02-21-After-Reckless-Decisions-SGA-Must-Impeach-Ma
# Sentences: 26
# 2016-04-29-Beyond-Wagon-Wheel-A-Conversation-With-Ketch-Secor-of-OldCrow-Medicine-Show
# Sentences: 96
# 2019-04-17-SGA-Confirms-Incoming-Executive-Board
# Sentences: 14
# 2018-12-05-Men-Women-Finish-in-Top-Three
# Sentences: 22
# 2016-01-15--The-Hateful-Eight-Burns-With-Tension-Psychological-Warfare
# Sentences: 44
# 2016-11-10-Swimming-and-Diving-Team-Combines-Love-of-Sport-withVolunteering
# Sentences: 25
# 2019-09-18-Two-Law-Professors-Accused-of-Using-the-N-Word-in-Class
# Sentences: 21
# 2015-09-06--Sense8-Connects-Science-Fiction-Human-Experience
# Sentences: 19
# 2015-02-26-Delta-Tau-Delta-Gains-Many-New-Members
# Sentences: 13
# 2016-02-10--Disgraced-Seeks-To-Raise-The-Discourse-But-Discourse-At-An-AllTime-Low
# Sentences: 57
# 2017-01-19-Eagles-take-on-Arena-Pro-Swim-Series-and-Birmingham-Southern
# Sentences: 15
# 2016-10-05-UChicago-Shuts-Emory-Out
# Sentences: 14
# 2018-09-19-Crime-Report-9-19-18
# Sentences: 38
# 2018-09-18--Mandy-is-Nothing-More-Than-Eye-Candy
# Sentences: 31
# 2018-09-29-Men-s-Golf-Takes-First-Third-in-Season-Start
# Sentences: 20
# 2015-11-09-Troyetsky-Week-9
# Sentences: 32
# 2015-09-29-Men-s-Soccer-Trumps-Sewannee
# Sentences: 7
# 2015-10-17-Volleyball-Team-Extends-Win-Streak-to-10
# Sentences: 12
# 2019-02-05--Vulgar-History-Endures-Actress-Absence
# Sentences: 22
# 2014-11-14-On-Fire-11-14-14
# Sentences: 20
# 2018-03-07-A-New-Chapter-for-A-Wrinkle-in-Time-
# Sentences: 31
# 2015-03-30-J-Cole-The-Knocks-Draw-Thousands
# Sentences: 9
# 2015-11-11-Doolino-Knows-Best-Views-Vibes-and-Vacation
# Sentences: 33
# 2014-10-30-Community-Sustainability-Efforts-Awarded
# Sentences: 17
# 2017-09-26-SGA-Funds-Oxford-Shuttles-to-Homecoming-Concert
# Sentences: 14
# 2018-10-03-RACE-Office-Searching-for-New-Director-After-Abrupt-Departures
# Sentences: 17
# 2016-01-19-Strong-Individual-Performances-Define-ETSU-Meet
# Sentences: 17
# 2019-09-18-College-Council-Votes-to-Adopt-the-Emory-Student-Bill-of-Rights
# Sentences: 14
# 2014-11-04-Photo-Essay-11-4-14
# Sentences: 1
# 2015-04-16-News-Roundup-4-23-15
# Sentences: 12
# 2014-11-07-Reading-Celebrates-Samuel-Beckett
# Sentences: 27
# 2015-05-18-Get-Up-Close-and-Personal-with-Disney-s-Inside-Out-
# Sentences: 18
# 2018-12-05-News-Roundup-12-5-18
# Sentences: 24
# 2015-09-23-A-Dent-In-The-Armor
# Sentences: 11
# 2019-06-11-Emory-Based-Group-Receives-180-Million-Grant-from-GatesFoundation
# Sentences: 5
# 2016-04-06-Office-of-Admissions-Releases-Results-for-Class-of-2020
# Sentences: 24
# 2015-04-23-Gift-to-Fund-John-Lewis-Emory-Law-Scholar
# Sentences: 12
# 2018-04-16-Whole-Foods-CEO-Sparks-Conversation-on-Meat-Consumption
# Sentences: 27
# 2018-12-24-Edward-Jenner-Wood-III-Sarah-Beth-Brown-Join-Board-of-Trustees
# Sentences: 6
# 2016-09-08-2016-The-Year-We-Were-Stuck
# Sentences: 35
# 2018-03-06-A-Historic-Oscars-Ceremony-Plays-It-Safe
# Sentences: 25
# 2016-10-20-Season-Three-of-The-Flash-is-Dark-Rushed
# Sentences: 20
# 2018-09-27-The-Wheel-Takes-TIFF-Day-Two-9-12-
# Sentences: 44
# 2016-03-01-2016-University-Election-Results-Announced
# Sentences: 12
# 2016-09-21-Over-Easy-Superica
# Sentences: 16
# 2019-08-02--Big-Little-Lies-Season-2-a-Sophomore-Slump
# Sentences: 25
# 2016-03-16-Emory-Graduate-Programs-Maintain-Top-Rankings
# Sentences: 12
# 2018-09-18-Disney-s-Aladdin-at-the-Fox-Theater-Grants-All-of-Your-Wishes
# Sentences: 26
# 2015-03-27-Nosebleeds-NCAA-Tournament-Predictions
# Sentences: 46
# 2016-04-08--The-Catch-Adds-a-New-Dimension-to-Love-Hate-Relationships
# Sentences: 30
# 2017-04-12-Sweep-Breaks-Six-Game-Slump
# Sentences: 31
# 2018-10-16-Barinholtz-Banters-on-Politics-Directorial-Debut
# Sentences: 66
# 2016-01-29-Jukebox-the-Ghost-is-Undeniably-Unapologetic
# Sentences: 15
# 2019-08-19-Traverse-City-Film-Festival-Shines-with-Thought-provokingDocumentaries
# Sentences: 30
# 2017-10-25-Men-s-Soccer-Rebounds-Bounces-Berry-4-0
# Sentences: 23
# 2017-09-27-VA-Emergency-Exposes-Need-for-Crisis-Training
# Sentences: 20
# 2015-01-08-Athletic-Director-Tim-Downes-Announces-Resignation
# Sentences: 15
# 2019-02-22--How-to-Train-Your-Dragon-The-Hidden-World-is-Stunning-butToothless
# Sentences: 33
# 2016-09-07-Dressing-for-the-Fickle-Atlanta-Fall
# Sentences: 19
# 2018-10-31-Professor-Travels-to-Jordan-to-Treat-Refugees
# Sentences: 32
# 2014-10-21-Editorial-Cartoon-10-21-2014
# Sentences: 2
# 2014-11-14-Jeni-s-Ice-Cream-Joins-Downtown-Decatur
# Sentences: 36
# 2017-09-12-Crime-Report-9-13-17
# Sentences: 35
# 2018-06-13-Household-Horror-Show-Hereditary-is-a-Measured-Marvel
# Sentences: 29
# 2019-03-30-AJR-to-Headline-Dooley-s-Ball-2019
# Sentences: 8
# 2015-10-19-Club-Spotlight-Democracy-Matters
# Sentences: 27
# 2017-10-18-Thrift-or-Treat-Costume-Shopping-at-Secondhand-ATL-Spots
# Sentences: 22
# 2015-03-24-SPC-Four-Months-Forty-Members-One-Week
# Sentences: 40
# 2018-10-17-Gassel-Resurrects-College-Republicans
# Sentences: 30
# 2016-07-08-Vigil-Honors-Lives-of-Emory-Dhaka-Victims
# Sentences: 16
# 2019-08-24--Good-Boys-Much-More-than-a-Good-Time
# Sentences: 24
# 2017-02-08-Men-Let-Two-Road-Games-Slip-Away
# Sentences: 27
# 2018-03-05-Marthers-Named-Interim-Vice-President-of-Campus-Life
# Sentences: 20
# 2017-09-21-Institutional-Support-Needed-for-Women-in-STEM
# Sentences: 26
# 2017-02-15-Emory-Files-Joint-Amicus-Brief-Against-Immigration-Order
# Sentences: 15
# 2018-11-14-Mock-Trial-Hosts-Peach-Bowl-Invitational
# Sentences: 29
# 2019-04-02-College-Admissions-Must-Counter-Income-Inequality
# Sentences: 31
# 2017-11-15-From-Teen-Hacker-to-Devoted-Academic-Ymir-Vigfusson-BringsCoding-to-the-Classroom
# Sentences: 29
# 2016-02-23-Summer-Abroad-Italy
# Sentences: 18
# 2014-11-07-Men-s-and-Women-s-Season-Preview
# Sentences: 20
# 2017-08-29-Plain-White-T-s-to-Headline-Homecoming-Concert
# Sentences: 14
# 2019-09-25-Atlanta-Beltline-Lantern-Parade-Captivates-Thousands
# Sentences: 24
# 2017-03-31-Vanessa-Carlton-Stole-My-Heart-What-Do-I-Do-Now-
# Sentences: 27
# 2017-11-14-From-Movie-Nights-to-Practices-Women-s-Water-Polo-Bonds
# Sentences: 49
# 2018-02-13-GSGA-Designates-Emory-s-Graduate-Christian-Fellowship-as-GWO
# Sentences: 5
# 2018-03-07-Koinonia-Coffee-Pops-Up-Then-Settles-Down
# Sentences: 22
# 2018-04-18-Ma-Rescinds-Threat-of-Legal-Action-Against-Wheel
# Sentences: 16
# 2015-08-30-President-Carter-s-Legacy-at-Emory-and-Beyond
# Sentences: 17
# 2015-08-27-The-Academic-Breaking-Point
# Sentences: 25
# 2017-02-01-The-Sound-of-Emory-An-Insight-into-WMRE
# Sentences: 31
# 2018-09-26-Blackout-What-Call-of-Duty-Needs
# Sentences: 37
# 2014-10-21-Personhood-Not-Just-for-People
# Sentences: 25
# 2017-10-04-Buford-Chinese-Joint-I-Liu-minates
# Sentences: 19
# 2018-07-10--Ant-Man-and-the-Wasp-A-Small-But-Mighty-Sequel
# Sentences: 30
# 2018-04-11--A-Quiet-Place-Silent-but-Deadly
# Sentences: 34
# 2016-03-28-Emory-UNICEF-and-HOPE-Collaborate-to-Give-Back
# Sentences: 36
# 2019-04-24-Atlanta-Film-Festival-Showcases-Impactful-Emotional-Films
# Sentences: 62
# 2017-03-29-SNL-Actress-Fuses-Race-Humor
# Sentences: 22
# 2019-02-05--Miss-Bala-Bores-With-Nonsensical-Mess
# Sentences: 23
# 2017-02-07-Sterk-Joins-Univ-Presidents-Against-Trump-Exec-Order
# Sentences: 21
# 2018-10-10-Great-Times-Await-at-Bad-Times-at-the-El-Royale-
# Sentences: 29
# 2016-01-26-Holy-Grails-of-Truth-Don-t-Exist
# Sentences: 29
# 2018-04-18-Buddy-Comedy-Blindspotting-Tackles-Racism
# Sentences: 27
# 2018-11-25--The-Front-Runner-Engaging-but-has-Unfulfilled-Potential
# Sentences: 24
# 2017-11-08-Life-of-Pai-From-Accountant-to-Academic
# Sentences: 36
# 2016-03-11--Zootopia-is-Ambitious-Beautiful-And-A-Little-Too-Muddled
# Sentences: 29
# 2018-04-17-Conservative-leaning-News-Under-Sinclair-Has-PoliticalRamifications-Study-Says
# Sentences: 25
# 2015-09-30-No-Headline-Available
# Sentences: 11
# 2016-09-28-System-Increases-Online-Security-for-Emory-Accounts
# Sentences: 22
# 2015-09-01-Nationwide-Homeless-Crackdown-Uncalled-For
# Sentences: 32
# 2018-10-13--Hal-Gives-an-Unsung-Hollywood-Hero-His-Due
# Sentences: 38
# 2015-11-10-No-Clinton-Airlines-Are-NOT-Leaving-Consumers-Out-To-Dry
# Sentences: 42
# 2015-09-20-Crime-Report-9-25-15
# Sentences: 16
# 2018-10-17-SGA-s-Audit-of-the-Student-Activities-Fee-is-too-Short-to-be-Effective
# Sentences: 6
# 2018-09-05-Ma-Leaves-Campaign-Promises-Behind
# Sentences: 11
# 2019-09-11-CAPS-to-Hire-5-Additional-Mental-Health-Counselors
# Sentences: 13
# 2018-03-07-Eagles-Pound-Pomona-Pitzer-for-Second-Straight-ITA-Title
# Sentences: 32
# 2016-01-28-Bowie-s-Parting-Gift-Is-Monumental-Heartbreaking
# Sentences: 17
# 2015-02-23-EPD-ResLife-Partner-for-Coffee-with-a-Cop-
# Sentences: 6
# 2018-04-04-SGA-Bills-Clarify-Elections-Processes-Allows-for-No-Confidence-Vote
# Sentences: 42
# 2015-04-23-Honor-Council-4-24-15
# Sentences: 9
# 2016-03-15-Emory-Hospital-Admits-Lassa-Fever-Patient
# Sentences: 15
# 2014-10-25-Eagles-Close-Out-Fall-Season-Strongly
# Sentences: 8
# 2018-10-16-Crime-Report-10-17-18
# Sentences: 33
# 2017-03-01-Safety-Alliance-Stalls-Condominium-Development-Near-Emory
# Sentences: 11
# 2017-04-05-Emory-Takes-Next-Step-Toward-Annexation
# Sentences: 17
# 2016-12-01--Gilmore-Girls-Leaves-You-Wanting-Still-More
# Sentences: 33
# 2017-04-03-Rap-God-Be-Praised-The-Resurrection-of-Freddie-Gibbs
# Sentences: 22
# 2017-02-20--The-Great-Wall-Makes-a-Modest-Attempt-at-Blockbuster-HighFantasy
# Sentences: 21
# 2014-11-25-Emory-Creates-Water-Recycling-Facility-First-Hydroponic-Systemin-the-Nation
# Sentences: 12
# 2019-02-27-Additional-Swimmers-Qualify-for-NCAAs
# Sentences: 8
# 2017-01-19-Eagles-qualify-for-nationals-at-Miami-Invitational-defeat-FloridaSouthern
# Sentences: 20
# 2017-03-01-Bevan-Kaniut-and-Sweeney-Finish-Strong
# Sentences: 25
# 2017-11-12-FedEx-Goizueta-Announce-1-Million-Partnership-for-MSBAProgram
# Sentences: 21
# 2015-02-20-Two-Minute-Drill-with-McKenna-Newsum-Schoenberg
# Sentences: 11
# 2017-09-19-Eagles-Bounce-Back-After-Tough-Overtime-Defeat
# Sentences: 20
# 2016-02-28--GreensboroNow-Continuing-the-Struggle-against-Segregation-inGeorgia
# Sentences: 34
# 2018-04-06-Desiigner-to-Open-2018-Dooley-s-Ball
# Sentences: 7
# 2015-03-27-How-Fed-Policy-Became-Running-Water-And-Why-the-MarketNeeds-a-Permanent-Water-Main-Break
# Sentences: 31
# 2017-04-19-Executive-Agency-Budgets-May-be-Cut-About-12-Percent
# Sentences: 18
# 2019-02-20-CC-Passes-Three-Bills-in-Violation-of-Constitution
# Sentences: 17
# 2018-04-25--Natural-Shocks-Play-Tackles-Gun-Violence
# Sentences: 22
# 2018-10-03-Bakery-Plants-Roots-at-Ponce
# Sentences: 22
# 2018-09-05-Women-Shut-Out-Loggers-Lutes
# Sentences: 24
# 2018-10-06-Students-Faculty-Protest-Kavanaugh-in-Women-s-Rights-Rally
# Sentences: 29
# 2019-03-27-An-Odd-State-of-the-Union-The-Disparity-Between-US-Men-s-andWomen-s-Soccer
# Sentences: 32
# 2018-02-13-Rose-Library-Director-to-Depart-in-March
# Sentences: 30
# 2014-10-21-Pinter-Fest-Asks-Audiences-To-Pause-
# Sentences: 13
# 2015-03-27-Police-Report-3-27-15
# Sentences: 17
# 2016-02-16-Men-Open-Season-with-a-Win
# Sentences: 25
# 2019-03-20-GSGA-Extends-Declaration-Deadline-Amid-Lack-of-Candidates
# Sentences: 5
# 2018-03-30-Ma-Neibart-Head-to-Run-Off-for-SGA-President
# Sentences: 21
# 2017-01-25-News-Roundup-1-25-17
# Sentences: 19
# 2017-02-08-Inequality-in-the-United-States
# Sentences: 35
# 2019-09-18-Emory-s-Legacy-Admissions-Policy-Belongs-in-the-Past
# Sentences: 15
# 2018-09-04-Fire-Causes-Evacuation-in-Woodruff-Residential-Center
# Sentences: 1
# 2018-12-01-News-Roundup-11-28-18
# Sentences: 34
# 2016-02-16-Emory-Pi-Phi-Welcomes-New-Members
# Sentences: 20
# 2015-12-01-Doolino-Knows-Best-Tis-the-Season
# Sentences: 34
# 2016-12-08-The-Fray-is-Restorative-but-Breaks-No-New-Ground
# Sentences: 21
# 2016-04-06-The-Small-Necessary-Step
# Sentences: 25
# 2014-10-24-Sartorial-Spotlight-Fashion-on-the-Run
# Sentences: 14
# 2019-03-20-Eagles-Win-Jekyll-Island-Invitational
# Sentences: 29
# 2016-09-08--The-Wild-Life-is-Bland-Matinee-Fare
# Sentences: 24
# 2017-01-30--I-See-You-is-an-Awkward-Step-Forward
# Sentences: 22
# 2017-04-19-Visiting-Professor-Tells-Migrant-Stories
# Sentences: 32
# 2018-02-05--Bye-Bye-Bye-to-a-Timberlake-Comeback
# Sentences: 13
# 2018-09-26-News-Roundup-9-26-18
# Sentences: 20
# 2019-03-20-Eagles-Dominate-Over-Break
# Sentences: 28
# 2015-11-11-Students-Protest-Racism-on-Clifton-Road-List-Demands-forAdministration
# Sentences: 23
# 2019-04-11--Mayhem-is-Coming-with-Borderlands-3-Reveal
# Sentences: 13
# 2015-09-09-5-6-7-8-A-Whirl-into-the-World-of-Emory-s-Dance-Auditions
# Sentences: 36
# 2015-04-07-Iran-Deal-A-
# Sentences: 25
# 2017-04-12-Ty-Dolla-Sign-Replaces-Migos-Headlines-Dooley-s-Ball
# Sentences: 13
# 2017-11-01-Emory-Ensemble-the-Wind-Beneath-Swoop-s-Wings
# Sentences: 23
# 2017-06-06-Emory-Student-Dies-After-Fall-From-Second-Story-Balcony
# Sentences: 6
# 2018-09-19-Khalid-Kendrick-Fall-Out-Boy-Light-Up-Piedmont
# Sentences: 65
# 2015-11-11-Does-The-Future-Freak-You-Out-
# Sentences: 51
# 2019-04-17--Game-of-Thrones-Reflects-Our-Modern-Broken-World
# Sentences: 25
# 2016-11-10-The-Need-for-Originalist-Justices
# Sentences: 26
# 2017-11-29-University-to-Acquire-Single-Particle-Electron-CryomicroscopyTechnology
# Sentences: 20
# 2015-04-10-Why-India-Needs-Feminism
# Sentences: 22
# 2017-10-18-Atlanta-Hawks-The-Prey-of-the-NBA
# Sentences: 13
# 2019-04-10-Muslim-Ritual-Purification-Room-Desecrated-in-Rollins-Building
# Sentences: 11
# 2016-06-02-Unbreakable-Kimmy-Schmidt-Season-Two-Evolves-Into-a-NetflixShow
# Sentences: 27
# 2015-10-17-Troyetsky-s-Pick-Ems-Week-6
# Sentences: 29
# 2018-12-05-SGA-Rejects-Bill-to-Change-Student-Activity-Fee-Split
# Sentences: 29
# 2015-09-07-Emory-s-Ben-Carson-Chicken-Has-Come-Home-to-Roost
# Sentences: 16
# 2017-02-22-Why-a-Sanctuary-Campus-Matters-Georgia-s-Past-and-Present-andour-Nation-s-Future
# Sentences: 16
# 2018-02-21-North-Korea-s-Empty-Olympic-Diplomacy-Liberal-Media-GlossesOver-Regime-Atrocities
# Sentences: 14
# 2018-01-31-For-EPs-Brevity-is-a-Subtle-Bliss
# Sentences: 25
# 2015-12-10-Troyetsky-To-be-or-not-to-be-consistent-
# Sentences: 27
# 2016-03-03--Remember-Undercuts-Its-Conflicting-Goals
# Sentences: 24
# 2016-02-03-With-Economy-Back-on-Track-Foreign-Policy-is-the-New-Priority
# Sentences: 38
# 2019-09-25-Stop-Harassing-Kids-to-Score-Political-Points
# Sentences: 8
# 2017-03-31-Emory-Allies-With-30-Universities-Against-Revised-ImmigrationOrder
# Sentences: 10
# 2016-02-03-Songs-that-Endure-Remembering-the-Eagles-Glenn-Frey
# Sentences: 22
# 2018-10-03-Emory-Shouldn-t-Succumb-to-Grade-Inflation
# Sentences: 15
# 2014-11-25-Social-Life-During-the-Social-Freeze
# Sentences: 15
# 2016-05-15-Key-and-Peele-Talk-Blackness-Creative-Freedom
# Sentences: 100
# 2015-09-15-Campus-Reacts-to-President-Wagner-s-Departure
# Sentences: 34
# 2019-03-06-Eagles-Mount-Comeback-Against-Berry
# Sentences: 25
# 2019-02-13--Now-I-Really-Want-To-Go-to-Alabama-Jin-Young-Choi-Bikes-toBorder-After-Unexpected-Revelation
# Sentences: 57
# 2019-04-17-Nobel-Laureate-Talks-National-Debt-at-Annual-Lecture
# Sentences: 24
# 2017-10-18-Eagles-Topple-No-1-UChicago-End-Maroons-28-Game-UndefeatedStreak
# Sentences: 32
# 2017-04-09--Holden-On-Reaches-Beyond-the-Screen
# Sentences: 21
# 2018-10-24-Friedman-Cox-Finish-First-for-Emory
# Sentences: 22
# 2014-10-23-National-Level-Brothers-Unite-at-Emory
# Sentences: 12
# 2015-02-23-British-Poet-Laureate-Gives-Reading-on-Love-Feminism
# Sentences: 6
# 2016-09-07-Emory-Conducts-Research-on-Man-s-Best-Friend
# Sentences: 37
# 2019-04-03-Can-Trae-Young-Win-Rookie-of-the-Year-
# Sentences: 25
# 2016-04-11-An-Interview-with-the-Cast-of-Everybody-Wants-Some-
# Sentences: 41
# 2019-03-27-Conan-Gray-Brightens-Terminal-West-Bedroom-Pop-Prince-TakesATL
# Sentences: 25
# 2014-11-18-Women-End-Season-After-First-Round-of-Nationals
# Sentences: 5
# 2019-04-24-News-Roundup-4-24-19
# Sentences: 11
# 2018-09-26-Student-Board-Proposes-College-Recess-
# Sentences: 19
# 2017-11-29-Ithaca-Wins-Final-Three-Sets-to-Spoil-Eagles-NCAA-Run-inQuarterfinals
# Sentences: 16
# 2017-01-25-Our-Unqualified-Grizzly-Phobic-Secretary-of-Education
# Sentences: 28
# 2017-09-13-On-Luv-Is-Rage-2-Lil-Uzi-Vert-Delves-Deeper
# Sentences: 34
# 2017-04-04-Crime-Report-4-5-17
# Sentences: 21
# 2017-10-11-Jon-Bellion-Showcases-Skills-at-the-Coca-Cola-Roxy
# Sentences: 21
# 2018-02-26-Meatless-Burger-Meets-Impossible-Standards
# Sentences: 20
# 2016-04-26-Professor-Spotlight-Goizueta-Business-School-Welcomes-UshaRackliffe
# Sentences: 50
# 2018-10-03-The-Almanac-of-Atlanta-s-Best-Acai-Bowls
# Sentences: 31
# 2019-01-23-Emory-Increase-Support-for-Lower-Income-Students
# Sentences: 26
# 2015-04-20-No-1-Eagles-Dominate-Johns-Hopkins
# Sentences: 15
# 2017-02-08-How-Donald-Trump-Can-Unite-Not-Divide-America
# Sentences: 33
# 2015-08-27-Beware-The-Academic-Breaking-Point
# Sentences: 25
# 2016-03-16-Emory-Baseball-Nearly-Misses-UAA-Championship
# Sentences: 42
# 2018-10-10-Man-Trying-to-Steal-Food-Truck-Opens-Fire-at-Emory-Hospital-NoOne-Injured
# Sentences: 3
# 2015-12-10-Indoor-Track-Opens-Season-at-Birmingham-Southern
# Sentences: 8
# 2014-11-05-Professors-Study-Marriage-Economics
# Sentences: 3
# 2014-11-25--Naruto-Ends-After-700th-Chapter
# Sentences: 38
# 2014-10-02-O-T-Push-Secures-Coach-Travis-100th-Win
# Sentences: 13
# 2017-01-18-Win-Streak-Comes-To-Sudden-Halt-Against-Rochester
# Sentences: 28
# 2018-04-24--Spyro-2-Ripto-s-Rage-A-Platform-Innovation
# Sentences: 32
# 2015-02-26-CC-SGA-Candidates-Face-Off-in-Wheel-Debates
# Sentences: 14
# 2019-01-30-SGA-Declines-to-Advance-Impeachment-Process
# Sentences: 25
# 2015-02-20-Beej-Knows-Best-Who-Is-Getting-Franchised
# Sentences: 10
# 2018-10-03--Colette-is-Beautiful-Breaks-Barriers
# Sentences: 20
# 2015-10-23-The-Generation-Separation-Phenomenon-Why-Does-It-Exist-
# Sentences: 31
# 2016-05-08-Senior-Reflections-Shalvi-Shah
# Sentences: 12
# 2019-03-06-Emory-Leaders-Condemn-United-Methodist-Church-s-Anti-LGBTQDecision
# Sentences: 21
# 2019-01-29-Crime-Report-1-30-19
# Sentences: 25
# 2016-01-19-Rethink-Add-Drop-Swap
# Sentences: 21
# 2018-10-16-Twenty-One-Pilots-Take-Off-on-Trench-
# Sentences: 29
# 2015-04-03--Emory-Probz-Don-t-Have-Dooley-
# Sentences: 1
# 2018-05-29-With-Solo-the-Cup-is-Half-Empty
# Sentences: 34
# 2014-10-07-Squad-Ties-No-1-Wash-U
# Sentences: 6
# 2018-11-06-Vince-Staples-FM-Feels-Rushed-Unfinished
# Sentences: 42
# 2017-11-08-3-2-OT-Victory-Propels-Men-s-Soccer-to-NCAA-Bid
# Sentences: 17
# 2014-12-05-The-Wheel-s-Declassified-Finals-Survival-Guide
# Sentences: 12
# 2017-03-17-Baseball-Loses-Second-Game-Still-Takes-Series-Win
# Sentences: 31
# 2016-04-20-Women-s-Tennis-Finish-Road-Trip-2-1
# Sentences: 49
# 2015-04-23-Dear-Doolina-The-Last-Hoorah
# Sentences: 21
# 2019-02-27-Emory-Hits-Hard-Against-Washington-Lee
# Sentences: 24
# 2018-03-07-Metalcore-Moshpits-and-Melee-at-the-Masquerade
# Sentences: 47
# 2017-09-08--Every-Country-s-Sun-is-Mogwai-s-Most-Mogwai-Album-Yet
# Sentences: 17
# 2018-11-13--Overlord-is-Insane-and-Wild-Entertainment
# Sentences: 24
# 2015-03-03-University-Must-Confront-Its-Racist-History
# Sentences: 48
# 2017-04-19-Hernandez-Discusses-Upbringing-Baseball-and-Plans
# Sentences: 36
# 2017-01-17-Revamped-WoodREC-Falters-on-Ray-sed-Hopes
# Sentences: 30
# 2018-10-24-The-Experience-After-Emory-Rei-Wang-Talks-Fairy-Godmother-Job
# Sentences: 29
# 2018-12-05-Letter-to-the-Editor-EUSHS-Is-Not-Offering-Rape-Kits
# Sentences: 10
# 2018-04-24-Ossoff-Talks-Journalism-Political-Participation
# Sentences: 24
# 2015-06-12-WellStar-Calls-Off-Merger-with-Emory-Healthcare
# Sentences: 7
# 2017-03-22-Ban-Wrongfully-Struck-Down
# Sentences: 20
# 2016-09-22-Rose-Library-Opens-African-American-Art-Exhibit
# Sentences: 8
# 2018-10-24--The-Guilty-is-Pulse-Pounding-but-Predictable
# Sentences: 36
# 2015-11-25-Troyetsky-Panthers-Lions-to-Win-on-Thanksgiving
# Sentences: 18
# 2016-02-25-Student-Government-Candidates-Clash-at-Emory-Wheel-Debates
# Sentences: 54
# 2017-09-27--Midnight-Pillow-is-Cool-but-Sometimes-Cluttered
# Sentences: 26
# 2017-08-30-Chicken-Joint-Smokes-Competition-Colonnade-Dishes-Out-QualityFried-Chicken
# Sentences: 22
# 2015-11-11-Jackie-Cruz-Gets-Personal-at-Culture-Shock
# Sentences: 22
# 2015-10-07-Police-Report-10-7-15
# Sentences: 25
# 2018-09-26-Oxford-to-Construct-New-Campus-Life-Center
# Sentences: 20
# 2018-11-28-The-Halal-Guys-Unveils-Second-ATL-Spot
# Sentences: 24
# 2017-03-22-Emory-Professor-Scans-Animals-Brains
# Sentences: 10
# 2015-04-09-Police-Report-4-10-15
# Sentences: 13
# 2018-01-31-The-Drive-Thru-Taco-Bell-s-Nacho-Fries-Disappoint
# Sentences: 10
# 2016-02-09--Pride-and-Prejudice-and-Zombies-Is-Lifeless-And-Brainless
# Sentences: 35
# 2018-10-23--School-of-Rock-Rocks-the-Fox
# Sentences: 31
# 2016-11-06-Volleyball-Wins-7th-UAA-Title-Advances-to-NCAA-Tournament
# Sentences: 10
# 2019-04-03-Belibi-Becomes-Second-Woman-to-Win-Mcdonald-s-All-AmericanDunk-Contest
# Sentences: 22
# 2018-11-14-Gonzalez-Rico-Represents-Emory-Division-III-at-ITA
# Sentences: 16
# 2014-11-20-Dear-Doolina-Words-of-Wisdom
# Sentences: 24
# 2018-11-05-John-Lewis-Implores-Students-to-Turn-Out-on-Tuesday
# Sentences: 36
# 2016-03-29-An-Ex-Editor-s-Take-on-Trump-Chalk-and-the-Media
# Sentences: 14
# ...
# Sentences: 19
# 2019-04-18-Emory-College-s-First-Black-Student-Paves-Way-for-Future-Students
# Sentences: 34
# 2018-12-05-Track-and-Field-Begins-With-Icebreaker
# Sentences: 17
# 2015-11-16-ERHA-Hosts-First-Annual-Conference
# Sentences: 29
# 2018-09-04-Emory-Study-Toddlers-Respond-to-Perceived-Evaluation-at-24Months
# Sentences: 20
# 2017-11-11-Swimming-Diving-Finds-Rhythm-at-Emory-Invitational
# Sentences: 27
# 2019-04-11-Round-Table-Professors-Discuss-Georgia-s-Heartbeat-Bill-
# Sentences: 28
# 2014-11-20-Emory-Tech-Break-Ground-on-New-Joint-Library
# Sentences: 5
# 2016-01-26-Men-Take-Two-at-Home-Weekend
# Sentences: 12
# 2018-01-23-News-Roundup-1-24-18
# Sentences: 26
# 2015-03-26-French-Major-Concentration-Pends-Approval
# Sentences: 8
# 2015-09-08-Controversial-Call-dooms-Men-s-Soccer-Team
# Sentences: 22
# 2017-10-25-Laney-Organizers-Opt-to-Form-Voluntary-Membership-Union
# Sentences: 12
# 2015-10-27-Emory-Model-United-Nations-Shows-No-Mercy-at-Security-CouncilSimulations-at-Yale
# Sentences: 6
# 2016-09-28-Volleyball-Extends-Win-Streak-to-Seven-Games
# Sentences: 17
# 2017-09-20--Mother-A-Mystifying-Masterpiece
# Sentences: 30
# 2016-03-30-Emory-to-Host-Shakespeare-s-First-Folio
# Sentences: 23
# 2018-04-10-SGA-and-GSGA-Induct-Newly-Elected-Members
# Sentences: 19
# 2015-04-16-News-Roundup-4-17-15
# Sentences: 13
# 2018-11-28-ATL-United-Named-Most-Valuable-MLS-Franchise
# Sentences: 24
# 2015-10-29--The-Big-Bang-Theory-Will-Long-Awaited-Relationships-Last-
# Sentences: 34
# 2019-04-02-Crime-Report-4-3-2019
# Sentences: 32
# 2019-04-24-Bryant-Celebrates-Her-Twentieth-Year-As-Coach
# Sentences: 21
# 2016-01-19-Hawks-Top-Magic-on-MLK-Day
# Sentences: 23
# 2017-10-25-Administration-s-Response-to-Hurricanes-Harvey-Maria-Unequal
# Sentences: 15
# 2017-11-08-Prof-Leaves-WiFi-at-the-Office-John-Wegner-Discusses-Impact-ofTechnology-on-Student-Life
# Sentences: 36
# 2015-04-23-Looking-Back-Looking-Forward
# Sentences: 20
# 2014-11-18-On-Fire-11-18-14
# Sentences: 13
# 2018-11-28-Stop-Talking-About-Trump-s-Absurd-Commentary
# Sentences: 18
# 2014-11-21-Light-Wins-NCAA-Top-10-Award
# Sentences: 12
# 2014-12-05-Public-Largely-Ignores-Chronic-Disease
# Sentences: 30
# 2015-11-10-100-Senior-Honorary-Class-of-2016-Nominations-to-Close-Friday
# Sentences: 11
# 2018-04-04-Zero-Waste-Abandoning-the-Trashy-Life
# Sentences: 42
# 2015-11-10-Men-s-and-Women-s-Team-Crush-Rochester
# Sentences: 10
# 2015-10-05-Men-s-Soccer-moves-to-5-3-1
# Sentences: 16
# 2017-10-25-Doolino-Knows-Best-Stop-Drop-Enroll
# Sentences: 27
# 2015-04-09-Former-Emory-Professor-Peter-Dowell-Dies-at-78
# Sentences: 7
# 2016-04-06-Dooleywood-Takes-the-Stage
# Sentences: 28
# 2019-03-18-Stacey-Abrams-to-Speak-at-2019-Class-Day
# Sentences: 5
# 2019-03-24-Palmer-Kidd-Vie-for-SGA-Presidency
# Sentences: 21
# 2016-12-27--Courtenay-s-Cabaret-Home-for-the-Holidays-is-Pleasant-Friendly
# Sentences: 10
# 2018-04-17-Just-One-Meeting-In-SGA-Violates-Bylaws-Finance-Code
# Sentences: 14
# 2015-11-10-Malek-Jandali-s-Musical-Universe-Songs-for-Peace
# Sentences: 46
# 2018-09-18-Jennifer-King-Selected-as-Rose-Library-Director
# Sentences: 7
# 2018-10-31-Carter-to-Kemp-Step-Down-as-Ga-Secretary-of-State
# Sentences: 13
# 2017-04-07-TEDx-Conjures-Magic-in-the-Air
# Sentences: 28
# 2017-07-10-Horror-Stars-Talk-History-at-Famous-Monsters-Convention
# Sentences: 32
# 2018-08-18-Crystal-Moselle-Brings-Documentary-Realism-to-Skate-Kitchen-
# Sentences: 33
# 2018-02-07-Short-Notice-Gifts-for-Long-term-Relationships
# Sentences: 19
# 2015-02-23-DC-Comics-Long-Past-Prime-Difficult-to-Follow
# Sentences: 30
# 2015-09-16-Professor-Spotlight-Mark-Risjord
# Sentences: 47
# 2019-04-10-Sorry-Nats-Fans-Harper-Is-Ours-Now
# Sentences: 35
# 2016-09-27-SGA-Takes-Workforce-Survey-Discusses-Term-University-Wide-Student-Experience-Fund
# Sentences: 8
# 2018-04-25-On-Fire-Blame-It-On-the-Boogie
# Sentences: 21
# 2015-10-27-The-Emory-Bayit-More-Than-a-Place-to-Live
# Sentences: 14
# 2017-03-29-Track-and-Field-Depth-Shines-at-Home
# Sentences: 15
# 2017-02-22-Regular-Season-Closes-at-Royal-Open
# Sentences: 14
# 2016-01-30--One-Punch-Man-Smashes-Conventional-Anime-Cliches
# Sentences: 33
# 2016-02-10--Dear-White-America-Author-Discusses-Race-Moral-Bankruptcy
# Sentences: 26
# 2018-02-27-GSGA-Executive-VP-Proposes-1-000-Salaries-for-Executive-Members
# Sentences: 28
# 2018-08-02-A-Custody-Battle-Turns-Brutal-in-Xavier-Legrand-s-DisturbingDebut
# Sentences: 41
# 2018-02-28-Pike-to-Leave-Eagle-Row-DTD-Gets-Own-House-Sammy-Beta-JoinRow
# Sentences: 24
# 2017-11-15-Clinton-Looks-Toward-2018-Midterm-Elections
# Sentences: 25
# 2018-10-03-Lil-Wayne-Returns-Triumphantly-with-The-Carter-V-
# Sentences: 26
# 2016-03-15-Rose-Library-Obtains-Abolitionist-Text
# Sentences: 14
# 2014-11-18-Racial-Stereotypes-Examined-in-New-Seminar
# Sentences: 4
# 2014-11-04-SGA-Funds-Campus-Walmart-Shuttles
# Sentences: 5
# 2016-10-05-Golf-Bounces-Back-at-Oglethorpe-Fall-Invitational
# Sentences: 17
# 2016-04-13-Police-Report-4-13-16
# Sentences: 24
# 2019-04-24-Atlanta-United-Season-Long-Failures-Continue-with-Loss-to-F-C-Dallas
# Sentences: 29
# 2016-02-03-Education-Is-a-Right-Not-an-Obstacle
# Sentences: 30
# 2015-02-26-Sex-Week-Arouses-Student-Interest-in-Sex-Positivity
# Sentences: 7
# 2018-01-13--The-Last-Jedi-Reinvents-Star-Wars-Universe
# Sentences: 26
# 2016-10-04-A-Glimpse-Into-Trans-Life-at-Oxford-College
# Sentences: 51
# 2018-10-14--Fortnite-Season-Six-Brings-Epic-Change
# Sentences: 35
# 2015-09-09-Dekalb-s-New-Marijuana-Policy-May-Affect-Emory
# Sentences: 14
# 2017-09-20-Fantastic-Bars-and-Where-to-Find-Them-Atlanta-s-Secret-Bars
# Sentences: 37
# 2015-03-24-Police-Report-3-24-15
# Sentences: 18
# 2014-11-25-Neurodiversity-Stigmatized-in-Appearance
# Sentences: 50
# 2018-04-11-MemEmory-Facilitates-School-Spirit
# Sentences: 51
# 2018-02-28-Emory-Acquires-Harper-Lee-Letters
# Sentences: 25
# 2016-09-14--Atlanta-Brings-Issues-to-Light
# Sentences: 31
# 2014-10-28-Young-and-Joy-Concert-Eclectically-Indie
# Sentences: 21
# 2015-09-18-Sexual-Assault-Is-Not-Inevitable
# Sentences: 23
# 2019-03-06--Latino-is-a-Vague-Colonialist-Relic
# Sentences: 31
# 2015-11-04-Yerkes-to-Donate-Chimpanzees-to-Unaccredited-Park-in-England
# Sentences: 12
# 2017-02-14-Crime-Report-2-14-17
# Sentences: 20
# 2018-10-31-SGA-President-Dwight-Ma-Fires-Chief-of-Staff
# Sentences: 17
# 2017-09-26-Letter-to-the-Editor-Equality-in-STEM-a-Work-in-Progress-Prof-Says
# Sentences: 12
# 2018-01-21-SGA-Overrules-CC-Grants-ECSA-Charter
# Sentences: 38
# 2018-01-23-New-Year-New-Head-Coach-New-Streak
# Sentences: 35
# 2015-01-05-BOO-YOW-A-Tribute-to-Stuart-Scott
# Sentences: 24
# 2015-08-29-Back-to-School-With-the-Nosebleeds
# Sentences: 39
# 2017-02-15-Bill-Could-Mark-Noncitizen-Licenses
# Sentences: 25
# 2016-11-30-A-Guide-To-the-Most-Brew-tiful-Cafes
# Sentences: 9
# 2017-11-08-Creating-Coco-A-Talk-with-Pixar-s-Gini-Santos
# Sentences: 50
# 2015-02-23-Students-Lead-Black-Activism-Conference
# Sentences: 20
# 2018-02-21-A-Fine-Final-Fantasy-for-Your-Phone
# Sentences: 22
# 2015-12-02-Film-Production-Companies-Seek-Emory-s-Campus
# Sentences: 14
# 2016-01-24-The-Oscar-Nominees-Always-What-You-Expect-Never-What-YouHope
# Sentences: 30
# 2018-11-07-Club-Audit-Rushed-Unreliable
# Sentences: 10
# 2017-09-20-Wheel-Lacks-Black-Student-Voices-The-Need-for-Diversity-in-theNewsroom
# Sentences: 31
# 2017-04-12-Trump-The-Impromptu-Commander-in-Chief
# Sentences: 27
# 2016-09-15-Hong-Kong-Youth-Vote-Paradigm
# Sentences: 29
# 2016-03-16-Softball-Team-wins-UAA-Championship
# Sentences: 25
# 2017-06-19-Emory-College-Republicans-Secede-from-Georgia-Association
# Sentences: 16
# 2015-04-09-Nourish-International-Works-to-End-Poverty
# Sentences: 22
# 2018-10-31-Rams-Saints-Frontrunners-in-the-NFC
# Sentences: 17
# 2018-04-21-Over-Easy-Across-the-Atlantic
# Sentences: 37
# 2015-03-24-Global-Airline-Competition-Needs-to-Be-Preserved
# Sentences: 25
# 2018-04-04--Fortnite-Battle-Royale-a-Storm-of-Enjoyment
# Sentences: 23
# 2017-09-10-Sotomayor-s-Emory-Visit-Cancelled-Due-to-Severe-Weather
# Sentences: 3
# 2015-04-17-What-Daredevil-Teaches-Us-About-Ourselves
# Sentences: 23
# 2017-09-18-Following-Emory-Schools-Develop-Quantitative-Analysis-Programs
# Sentences: 15
# 2016-01-20-Emory-and-Georgia-Tech-to-Open-Shared-Library-Initiative
# Sentences: 25
# 2015-12-12-Sleeping-Ambulance-Driver-Causes-Emory-Bus-Crash
# Sentences: 8
# 2015-02-20-Proposed-Engineering-Degree-Not-Eminent-
# Sentences: 7
# 2019-04-09-You-ll-Want-to-Be-Buried-in-This-Pet-Sematary-
# Sentences: 19
# 2017-09-13-Patriots-Hunt-ed-Chiefs-Spoil-Defending-Champs-Homecoming
# Sentences: 14
# 2015-03-18-How-to-Avoid-The-Second-Semester-Slump
# Sentences: 29
# 2014-11-14-Nosebleeds-What-We-Buy-and-Sell-This-Week
# Sentences: 36
# 2015-09-22-Facts-Matter
# Sentences: 59
# 2018-04-18-Emory-Students-Selected-for-Truman-and-Goldwater-Scholarships
# Sentences: 44
# 2015-02-27-Emory-Students-for-Justice-in-Palestine-Respond-to-Vandalism-Address-Concerns
# Sentences: 17
# 2014-10-30-This-Week-at-Emory-10-31-14
# Sentences: 2
# 2016-10-04-This-Week-s-Best-New-Music
# Sentences: 23
# 2019-02-20-President-Sterk-Earned-1-1-Million-in-2016
# Sentences: 9
# 2017-10-09-Defending-National-Champions-Halt-Women-s-Soccer
# Sentences: 24
# 2018-03-20-Elections-Board-Allows-Undeclared-SGA-Presidential-Candidate-toRun
# Sentences: 16
# 2018-09-05-Eagles-Surpass-Generals-in-Sonny-Carter-Thriller
# Sentences: 44
# 2017-12-27-Hawks-Push-Past-Mavericks-After-Second-Half-Surge
# Sentences: 27
# 2018-12-05-Emory-Wind-Ensemble-Symphony-Orchestra-Exhibit-IncrediblePrecision
# Sentences: 31
# 2016-10-25-Doolino-Knows-Best-Home-is-Where-the-Heart-is
# Sentences: 26
# 2015-04-23-Provost-Conducts-College-Self-Study
# Sentences: 11
# 2015-11-25--Master-of-None-is-authenticity-at-its-best
# Sentences: 32
# 2015-05-08-Designer-Kenneth-Cole-Draws-Laughs-at-2015-Class-Day
# Sentences: 11
# 2015-04-09-McTyeire-Fun-for-Freshmen-
# Sentences: 22
# 2017-01-25-Immigration-in-the-Modern-American-Myth
# Sentences: 30
# 2018-12-05-Rose-Library-Holds-Clues-to-Univ-Presidents-Prof-Parties
# Sentences: 41
# 2019-02-13-Swimmers-Prep-For-UAA-Championships
# Sentences: 11
# 2017-08-16-Sterk-College-Republicans-Group-Decry-Charlottesville-Violence
# Sentences: 13
# 2017-09-12-The-Left-s-Prejudice-Against-Trump-Supporters
# Sentences: 33
# 2016-02-17-Decadence-Arrogance-Abound-in-Future-s-EVOL-
# Sentences: 22
# 2017-04-11-Kloss-Named-First-Chief-of-Staff
# Sentences: 16
# 2016-03-02-Baseball-sweeps-weekend-against-Huntingdon
# Sentences: 10
# 2019-04-24-Before-It-Opens-A-Look-Inside-the-Emory-Student-Center
# Sentences: 24
# 2014-10-07-On-Fire-10-7-14
# Sentences: 25
# 2017-01-25-Crime-Report-1-25-17
# Sentences: 30
# 2015-02-20-UMass-Incident-Result-of-Iran-Sanctions
# Sentences: 11
# 2015-02-26-On-Fire-2-27-15
# Sentences: 52
# 2019-09-11-Eagles-Stay-Perfect
# Sentences: 19
# 2014-11-07-Beej-Knows-Black-Tuesday-Approaches
# Sentences: 38
# 2018-03-26-Nineties-Nostalgia-Cyberpunk-Scrunchies
# Sentences: 21
# 2017-10-18-Cellphone-Privacy-Laws-Big-Brother-s-in-Your-Pocket
# Sentences: 36
# 2019-02-10-Crossword-2-6-18
# Sentences: 74
# 2016-08-31-Red-State-Test-Scores-Reflect-Broader-GOP-Trends
# Sentences: 28
# 2018-09-28-Marie-Lu-s-Wildcard-is-a-Dazzling-Finale
# Sentences: 23
# 2017-11-01-Northern-Foes-Eliminate-Eagles-UAA-Title-Hopes
# Sentences: 30
# 2014-11-24-Men-and-Women-Compete-at-Nationals
# Sentences: 17
# 2018-08-18-Sundance-Winner-Cameron-Post-Takes-Conversion-Therapy-to-Task
# Sentences: 40
# 2017-10-25-Unaided-by-RSGA-Presidential-Debate-Proceeds
# Sentences: 43
# 2017-03-01-Emory-Renal-Doctor-to-Lead-American-Physiological-Society
# Sentences: 12
# 2017-11-01-Falcons-Find-Footing-Escape-Jets-25-20
# Sentences: 15
# 2014-11-11--Interstellar-Shoots-For-Moon-Lands-Among-Stars
# Sentences: 39
# 2017-02-24--Holy-Potatoes-We-re-In-Space-Entertains-But-Fails-at-Innovation
# Sentences: 22
# 2018-10-03-Federal-Power-Keeps-States-in-Line
# Sentences: 21
# 2015-04-09-Emory-Hosts-Inaugural-Sexual-Assault-Awareness-Week
# Sentences: 22
# 2018-02-27-Honor-Council-Report-2-28-2018
# Sentences: 13
# 2017-10-25-Woman-Drops-Medical-Malpractice-Lawsuit-Against-Emory
# Sentences: 3
# 2018-03-15-Emory-Community-Members-Join-National-Walkouts-for-StricterGun-Control
# Sentences: 26
# 2018-04-24-SPC-Cancels-Events-After-Miscommunication-With-Campus-Life
# Sentences: 55
# 2015-02-20-Nosebleeds-Field-Trip-Edition
# Sentences: 28
# 2019-09-25-University-Must-Clarify-Appropriate-Uses-of-Racially-ChargedTerms
# Sentences: 14
# 2018-07-30-Your-Review-of-the-Marvelous-M-I-6-Should-You-Choose-to-Accept-It
# Sentences: 25
# 2017-01-25-An-Endorsement-of-SGA-s-Referendum
# Sentences: 24
# 2019-09-25-Beauty-Influencer-Amasses-63-000-Fans
# Sentences: 40
# 2019-02-27-Emory-Advances-to-NCAA-Tournament
# Sentences: 13
# 2015-10-15--Fallout-4-More-Apocalypse-More-Freedom
# Sentences: 27
# 2015-02-27-Why-You-Should-Care-About-Net-Neutrality
# Sentences: 9
# 2015-11-26-Wall-of-Love-Allows-Students-to-Express-Solidarity
# Sentences: 21
# 2015-04-07-Our-Opinion-Laudable-Move-to-Provide-Aid-to-Undocumented
# Sentences: 14
# 2018-02-06-Sotomayor-Calls-for-More-Diversity-on-the-Bench
# Sentences: 30
# 2018-11-05-Sure-Sure-Brings-Eccentricity-to-Atlanta
# Sentences: 22
# 2018-04-25-Buddha-Day
# Sentences: 2
# 2019-09-11-Emory-Fails-to-Defend-Their-Home-Field
# Sentences: 19
# 2017-03-29-Master-the-Lines-You-ll-be-Fine-A-Student-s-Manual-to-RidingMARTA
# Sentences: 26
# 2018-01-30-Cleveland-Becomes-Marginally-Less-Sucky-On-Fire
# Sentences: 16
# 2017-10-18-Solving-the-Mass-Shooter-Problem
# Sentences: 36
# 2019-04-03-CS-Department-Changes-Major-Requirements-After-Split-with-MathDepartment
# Sentences: 12
# 2015-07-28-Summer-Update-Housing-Changes-False-Weather-Alert-ProfessorArrested-on-Child-Pornography-Charges-and-More
# Sentences: 20
# 2016-11-10-Season-s-End-Comes-Suddenly-for-Men-s-Soccer
# Sentences: 26
# 2016-04-06-Baseball-Beats-Maryville-Twice
# Sentences: 28
# 2018-05-03-The-2018-FIFA-World-Cup-Your-Group-Stage-Forecast
# Sentences: 69
# 2018-11-28-Grad-Students-Propose-Increasing-Health-Sciences-Library-Hours
# Sentences: 25
# 2019-09-25-Eagles-Blank-Third-Straight-Opponent
# Sentences: 23
# 2017-08-29-A-Time-to-Stop-The-Emoji-Movie
# Sentences: 23
# 2018-05-02-Muth-Urban-Economics-Pioneer-and-Former-Emory-EconomicsChair-Dies-at-90
# Sentences: 20
# 2018-01-23-Faculty-Addressing-Black-Students-at-Emory-Demand-for-DiversityGER
# Sentences: 18
# 2016-12-01-Crime-Report-11-27-16
# Sentences: 22
# 2017-03-01-The-Snowball-Effect-Why-Nagasu-Should-Compete-at-Worlds-butWon-t
# Sentences: 27
# 2016-10-18-Crime-Report-10-19-16
# Sentences: 40
# 2016-09-13-SGA-Welcomes-New-Members-Discusses-Low-Attendance
# Sentences: 9
# 2016-10-05-Ricketts-Brings-Experience-Wisdom
# Sentences: 25
# 2018-09-05-Keep-the-Government-Out-of-the-Kitchen
# Sentences: 24
# 2016-09-30-Distefano-Delivers-Racy-Performance-in-Harland
# Sentences: 31
# 2015-04-09-Two-Officials-To-Leave-Div-of-Campus-Life
# Sentences: 16
# 2018-02-07-Foles-Flies-Eagles-to-First-Super-Bowl-Title
# Sentences: 45
# 2017-09-27-A-Serene-Spot-to-Spill-Out
# Sentences: 14
# 2019-09-04-Art-to-Consume-Before-College-Ends
# Sentences: 30
# 2014-10-21-Justice-Ginsburg-Remains-by-Right
# Sentences: 28
# 2015-11-09-Demi-Lovato-s-Confidence-Shines-A-Track-by-Track-Analysis
# Sentences: 65
# 2017-11-01-XC-Finishes-No-3-at-UAA-Championships
# Sentences: 34
# 2015-09-06-Law-School-to-Launch-Specialization-in-Development
# Sentences: 15
# 2017-09-13-Roundup-9-13-17
# Sentences: 21
# 2019-04-03-Eagles-Dominate-In-Three-Straight-Matches
# Sentences: 24
# 2018-11-14-Cross-Country-Earns-Bid-to-NCAA
# Sentences: 33
# 2015-04-23-Ex-Employee-Charged-With-Theft
# Sentences: 5
# 2018-11-07-Emory-Enters-NCAA-Tops-UAA
# Sentences: 33
# 2018-09-12-Miso-Ko-Rolls-Into-Ponce-City-Market
# Sentences: 21
# 2017-02-14--I-Am-Not-Your-Negro-Explores-James-Baldwin-s-Role-in-the-CivilRights-Movement
# Sentences: 25
# 2016-09-16--Red-vs-Blue-Grew-Up-with-Its-Viewers
# Sentences: 16
# 2016-09-27-Doolino-Knows-Best-Midterm-Madness
# Sentences: 13
# 2017-10-24-Crime-Report-10-25-17
# Sentences: 25
# 2014-10-07-Eagles-Take-11th-Straight-Win
# Sentences: 9
# 2019-09-04-Callahan-s-Corner-Respect-Emory-s-Championship-Pedigree
# Sentences: 19
# 2015-10-12-Oxford-Sophomore-Arrested-for-Threatening-Mass-Shooting-on-YikYak
# Sentences: 17
# 2018-07-02-Rosa-Tarbutton-Sumter-Elected-to-Board-of-Trustees
# Sentences: 8
# 2017-04-05-Hospital-DUC-ling-Construction-Disrupts-Students
# Sentences: 37
# 2017-02-25--Get-Out-Delivers-Politically-Charged-Horror-Comedy
# Sentences: 28
# 2017-06-20-United-Attack-Conquer-Columbus-Crew
# Sentences: 35
# 2019-01-30-Chicago-Rapper-Brings-Warmth-to-Atlanta
# Sentences: 23
# 2018-04-11-Team-Blossoms-at-Spring-Invitational
# Sentences: 20

# %% [markdown]
# ## Train model

# %% [markdown]
# Now that we have our corpus ready for gensim, we can train the model. To do so, we call the function `gensim.models.Word2Vec()`. This function has a couple dozen parameters, some of which are more important than others.
#
# Here are a few major ones. Only two are MANDATORY: these are marked with an asterisk:
#
# 1. `sentences*`: This is where you provide your data. It must be in a format of iterable of iterables.
# 2. `sg`: Your choice of training algorithm. There are two standard ways of training W2V vectors -- 'skipgram' and 'CBOW'. If you enter 1 here the skip-gram is applied; otherwise, the default is CBOW.
# 3. `size*`: This is the length of your resulting word vectors. If you have a large corpus (>few billion tokens) you can go up to 100-300 dimensions. Generally word vectors with more dimensions give better results.
# 4. `window`: This is the window of context words you are training on. In other words, how many words come before and after your given word. A good number is 4 here but this can vary depending on what you are interested in. For instance, if you are more interested in embeddings that embody semantic meaning, smaller window sizes work better.
# 5. `alpha`: The learning rate of your model. If you are interested in machine learning experimentation with your vectors you may experiment with this parameter.
# 6. `seed` (int): This is the random seed for your random initialization. All deep learning models initialize the weights with random floats before training. This is a useful field if you want to replicate your experiments because giving this a seed will initialize 'randomly' deterministically.
# 7. `min_count`: This is the minimum frequency threshold. If a given word appears with lower frequency than provided it will be ignored. This is here because words with very low frequency are hard to train.
# 8. `epochs`: This is the number of iterations (entire run) over the corpus, also known as epochs. Default is 5. Usually anything between 1-10 is ok. The trade offs are that if you have higher iterations, it will take longer to train and the model may overfit on your dataset. However, longer training will allow your vectors to perform better on tasks relevant to your dataset.
#
# Most of these settings will not concern us. As you'll see below, we are only going to use four arguments.
#
# \* On newer versions of gensim, `size` has changed to `vector_size`. But Colab has not yet updated theirs so `size` still works.

# %%
# let's train our model!
wheel_model = gensim.models.Word2Vec(
    sentences,
    min_count=2, # default is 5; this trims the corpus for words only used once; 
    size=100, # size of NN layers; default is 100; higher for larger corpora
    # vector_size=100,    # if you are getting an error while running this on your own computer, try this param insted 
    workers=5) # parallel processing; needs Cython

# %% [markdown]
# Hooray! We have a trained word2vec model: `wheel_model`!

# %% [markdown]
# ### Save model — and load it

# %% [markdown]
# It's often useful to save your trained model to disk so that you can reload it as needed. This is very similar syntax to saving topic models.

# %%
# how to store the above files to Google Drive 

from google.colab import drive
drive.mount('/content/gdrive')

wheel_model.save('/content/gdrive/My Drive/wheel_model')
# Out:
# Mounted at /content/gdrive

# %% [markdown]
# And you can load a model in the same way (remember this from our topic model)

# %%
# how you would load an old model from your own google drive
# old_model = gensim.models.Word2Vec.load('/content/gdrive/My Drive/wheel_model') 

# how we are going to all load in the same model -- from my google drive 
gdown.download('https://drive.google.com/uc?export=download&id=1-C3XZFjTDreSvMcZSVtckawy35fNXGJd', quiet=False) 

# load it 
wheel_model = gensim.models.Word2Vec.load('wheel_model')
# Out:
# Downloading...
# From: https://drive.google.com/uc?export=download&id=1-C3XZFjTDreSvMcZSVtckawy35fNXGJd
# To: /content/wheel_model
# 100%|██████████| 59.0M/59.0M [00:00<00:00, 179MB/s]

# %% [markdown]
# ## Let's play!

# %% [markdown]
# ### Similarity

# %% [markdown]
# word2vec can tell us which words, according to its model, are most similar to any other. We call `model.wv.most_similar("word", topn=number of similar words)`. Let's try `class`

# %%
# testing some basic functions

# basic similarity
wheel_model.wv.most_similar("class", topn=10)
# Out:
# [('classes', 0.7094650268554688),
#  ('school', 0.6753657460212708),
#  ('course', 0.671114981174469),
#  ('studying', 0.6504760384559631),
#  ('experience', 0.6376257538795471),
#  ('study', 0.6342734694480896),
#  ('room', 0.6270384788513184),
#  ('semester', 0.6214747428894043),
#  ('undergraduate', 0.6131769418716431),
#  ('event', 0.6044458150863647)]

# %% [markdown]
# Let's think about the results. `class` and `course` make intuitive sense: they have similar meanings to each other. But what's `study`? It's something you do for a class.
#
# Our model's parallel invites our critical analysis: rather than take these results as *true*, we need to reflect, in part through turning to articles themselves and close reading them, on how the model arrives at its results, and what they might imply.
#
# *Remember: everything the model knows it knows from our corpus. What we're learning are assumptions immanent to the corpus.*

# %% [markdown]
# ## Exercise 1:
#
# **Copy the code above and test out some words until you find one that has some interesting (or problematic) similar words.**

# %% [markdown]
# **Answer** It is interesting to see the comparison between the words "asian", "black", and "white". Asian and black generates similar words to each other, where most of the words are different ethnicities and races. However, the word only race the word white generates is "black" (I tested caucasian as well as well).

# %%
# basic similarity code copy
wheel_model.wv.most_similar("asian", topn=10)
# Out:
# [('african', 0.8803611993789673),
#  ('mediterranean', 0.8553394675254822),
#  ('korean', 0.8130248188972473),
#  ('africa', 0.8126314878463745),
#  ('biological', 0.8043367862701416),
#  ('ancient', 0.8002967834472656),
#  ('latin', 0.8001387119293213),
#  ('holocaust', 0.7956336140632629),
#  ('chinese', 0.7944408059120178),
#  ('american', 0.7890257239341736)]

# %%
wheel_model.wv.most_similar("caucasian", topn=10)
# Out:
# [('castile', 0.8195679187774658),
#  ('forallegedly', 0.8093999028205872),
#  ('undercount', 0.8082665205001831),
#  ('philippe', 0.8057286739349365),
#  ('cursed', 0.7985210418701172),
#  ('slapped', 0.7946358919143677),
#  ('sported', 0.7941344380378723),
#  ('world-weary', 0.7915570735931396),
#  ('waterproof', 0.788456916809082),
#  ('ivan', 0.7872964143753052)]

# %%
wheel_model.wv.most_similar("white", topn=10)
# Out:
# [('black', 0.6640344858169556),
#  ('supremacy', 0.6594688892364502),
#  ('predominantly', 0.5969716906547546),
#  ('male', 0.5849848985671997),
#  ('supremacists', 0.5754333138465881),
#  ('color', 0.5681685209274292),
#  ('cellophane', 0.5624448657035828),
#  ('goodrich', 0.5584666728973389),
#  ('plain', 0.5479418039321899),
#  ('males', 0.5432085990905762)]

# %%
wheel_model.wv.most_similar("black", topn=10)
# Out:
# [('color', 0.7080484628677368),
#  ('jewish', 0.7032463550567627),
#  ('muslim', 0.6697509288787842),
#  ('white', 0.6640344262123108),
#  ('female', 0.6178750395774841),
#  ('asian', 0.608405590057373),
#  ('colored', 0.6072382926940918),
#  ('latino', 0.6023068428039551),
#  ('group', 0.5941375494003296),
#  ('african', 0.5530300140380859)]

# %%
#sexual assault linkage to nonbinary
wheel_model.wv.most_similar("nonbinary", topn=10)
# Out:
# [('religions', 0.7637245655059814),
#  ('sexualassault', 0.7538890838623047),
#  ('targeting', 0.7523437738418579),
#  ('independents', 0.7441621422767639),
#  ('financially', 0.7432483434677124),
#  ('couples', 0.7424681782722473),
#  ('harming', 0.7402302026748657),
#  ('inequalities', 0.7387113571166992),
#  ('andother', 0.737116813659668),
#  ('alike', 0.7367554903030396)]

# %% [markdown]
# ## Similarity between two words
#
# We can choose specific words to compare with `model.wv.similarity(w1="word_one",w2="word_two")`

# %%
# similarity b/t two words

print(wheel_model.wv.similarity(w1="professor",w2="teacher"))
print(wheel_model.wv.similarity(w1="professor",w2="friend"))
# Out:
# 0.59389144
# 0.40549552

# %% [markdown]
# As expected, the model believes that your professor is more similar to your teacher than your friend. 🙁

# %% [markdown]
# ### Analogy

# %% [markdown]
# We can also play with analogy tasks. The commonly seen task is:
#
# 'Man is to King as Woman is to ____?'
#
# The general structure is:
# `A is to A\*  as  B is to B\*`
#
# gensim provides two different ways of implementing this task. You may be familiar with the the additive version also called the 3CosAdd method:
#
# $$\underset{b*\in V}{\textrm{arg max}} (cos(b*,b) - cos(b*,a) + cos(b*,a*))$$
#
# This reflects the abstraction of Woman - Man + King. In this maximization, we are searching which word vector will allow us to produce the highest value in this equation.
#
# We can implement this method with a built-in function. Positive here refers to words that give the positive contribution to similarity (nominator), and negative refers to words that contribute negatively (denominatory). Here's the additive method.

# %%
# analogies
# format is: "man is to professor as woman is to ???"
# note that i'm using "she" and "he" here since they occur much more frequently in this particular corpus

result = wheel_model.wv.most_similar(positive=['she', 'professor'], negative=['he'])

print("{}: {:.4f}".format(*result[0])) # this prints the top result
# Out:
# english: 0.7413

# %% [markdown]
# Man is to woman as professor is to...english!? Ah, the bias of the model....

# %% [markdown]
# ## Exercise 2:
#
# **Copy the code above and test out some analogies until you find one that gets you some interesting (or problematic) results.**

# %% [markdown]
# **Answer:**  Conservative is to liberal as bad is to good. This shows how polarized our nation is

# %%
# copying code from above
# format is: "conservative is to bad as liberal is to good"
# note that i'm using "she" and "he" here since they occur much more frequently in this particular corpus

result = wheel_model.wv.most_similar(positive=['liberal', 'bad'], negative=['conservative'])

print("{}: {:.4f}".format(*result[0])) # this prints the top result
# Out:
# good: 0.6489

# %% [markdown]
# ## There's so much more!

# %% [markdown]
# gensim has quite a few built-in tools, and it's worth taking some time to see what's available. Check the documentation here: [https://radimrehurek.com/gensim/models/keyedvectors.html](https://radimrehurek.com/gensim/models/keyedvectors.html)

# %% [markdown]
# ## BONUS: Visualization!

# %% [markdown]
# Find below some code you can use to make visualizations from your word2vec model. We can't visualize all the many dimensions in our model, so we need to reduce them to two dimensions for our meager human brains. We do that with something called principal component analysis (PCA).
#
# Don't worry about the details for now. This is just a fun way to take a look at the output of our model.
#
# **Remember**: Our visualization reduces MANY dimensions to two, so a lot of information is lost.

# %%
### Let's do some visualization ###

import numpy as np

# Get the interactive Tools for Matplotlib
# %matplotlib notebook # doesn't work for colab 
# %matplotlib inline 
import matplotlib.pyplot as plt
plt.style.use('ggplot')

from sklearn.decomposition import PCA

from gensim.test.utils import datapath, get_tmpfile
from gensim.models import KeyedVectors

# %%
def display_pca_scatterplot(model, words=None, sample=0):
    if words == None:
        if sample > 0:
            words = np.random.choice(list(model.wv.vocab.keys()), sample)
        else:
            words = [ word for word in model.wv.vocab ]
        
#    word_vectors = np.array([model[w] for w in words]) <-- gensim 3 version
    word_vectors = np.array([model.wv[w] for w in words]) # gensim 4 version

    twodim = PCA().fit_transform(word_vectors)[:,:2]
    
    plt.figure(figsize=(6,6))
    plt.scatter(twodim[:,0], twodim[:,1], edgecolors='k', c='r')
    for word, (x,y) in zip(words, twodim):
        plt.text(x+0.05, y+0.05, word)

# %%
display_pca_scatterplot(wheel_model, ['exam','stress','finals','rest','sleep'])

# display_pca_scatterplot(ccp_model, sample=20)

# %% [markdown]
# ## Exercise 3a:
#
# **Copy the code above and plot some words that you think might be similar or different from each other.**

# %%
display_pca_scatterplot(wheel_model, ['vinegar','pickle','jar','garlic','cucumber'])

# display_pca_scatterplot(ccp_model, sample=20)

# %% [markdown]
# ## Exercise 3b:
#
# **What do you think the plot shows you about the words? Did they confirm or contradict what you though they would show?**

# %% [markdown]
# **Answer:**  The plot seems to show how similar the words are to each other. The words "vinegar" "cucumber" and "pickle" are the most similar to each other. This confirms what I thought it would show. "Jar" is more similar to "cucumber" than to "garlic." I am surprised that garlic and cucumber are not closer to each other.

# %% [markdown]
# *Lauren F. Klein wrote version 1.0 of this notebook in 2019 based on the [Advanced Topics in Word Vectors workshop](https://dh2018.adho.org/en/machine-reading-part-ii-advanced-topics-in-word-vectors/) at DH 2018 as well as tutorials by [Radim Rehurek](https://rare-technologies.com/word2vec-tutorial/) and [Chris McCormick](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/). It was updated again in 2021 and 2022.*
