# %% [markdown]
# # NLP with spaCy

# %% [markdown]
# Although NLTK lets you do pretty much anything NLP-related, it can sometimes be difficult to parse through all of the different ways that you might approach a specific task. Enter spaCy, a more recent and more user-friendly NLP library, which has become increasingly widespread, particularly for certain core NLP tasks such as part-of-speech (POS) tagging and named-entitiy recognition (NER). We'll be using both NLTK and spaCy during this course, as do most people, since each have their strengths and weaknesses.
#
# One thing to know (and like!) about spaCy is that it relies on machine learning models trained on large amounts of carefully-labeled text. (This is in contrast to the "large language models" that we began the course by talking about, which "learn" language features in other ways.) The English-language spaCy model that we’re going to use in this lesson was trained on an annotated corpus called “OntoNotes”: 2 million+ words drawn from “news, broadcast, talk shows, weblogs, usenet newsgroups, and conversational telephone speech,” which were meticulously tagged by a group of researchers and professionals for people’s names and places, for nouns and verbs, for subjects and objects, and much more.
#
# Another thing to know (but maybe not like?!) about spaCY is that, like a lot of other major machine learning projects, OntoNotes was sponsored by the Defense Advaced Research Projects Agency (DARPA), the branch of the Defense Department that develops technology for the U.S. military. So, in short, it's complicated!
#
# In any case, let's get started.

# %% [markdown]
# ### Loading the language model
#
# I've already downloaded and installed both spaCy and its English-language model (`en_core_web_sm`) on our JupyterHub. This is the model that was trained on the annotated “OntoNotes” corpus.
#
# To load it, we need to do the following

# %%
import spacy
import en_core_web_sm
nlp = en_core_web_sm.load()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [3], in <cell line: 1>()
# ----> 1 import spacy
#       2 import en_core_web_sm
#       3 nlp = en_core_web_sm.load()
#
# ModuleNotFoundError: No module named 'spacy'

# %% [markdown]
# ### Processing a document

# %% [markdown]
# To get started with spaCy, we first need to process our document with the loaded NLP model. As with sentiment analysis, most of the heavy lifting is done in this single line of code--and not by us, thankfully!
#
# After processing, the document object will contain tons of juicy language data — named entities, sentence boundaries, parts of speech — and the rest of our work will be devoted to accessing this information.
#
# Let's create a `Document` object with a few sentences from the Universal Declaration of Human Rights:

# %%
doc = nlp("""All human beings are born free and equal in dignity and rights. 
They are endowed with reason and conscience and should act towards one another in 
a spirit of brotherhood. Everyone has the right to life, liberty and security of person.""")

# %% [markdown]
# ## What can we do with spaCy?

# %% [markdown]
# ### Sentences
#
# spaCy offers an easy way to identify sentences with its `.sents` method. `doc.sents` will turn the doc into a list of sentences. Once you've created a document object, you can iterate over the sentences it contains using the `.sents` attribute as follows:

# %%
print("Here is the doc: ")
print(doc)
print("\n")
print("And here are the doc's sentences: ")

for sent in doc.sents:
    print(sent.text)
# Out:
# Here is the doc:
# All human beings are born free and equal in dignity and rights.
# They are endowed with reason and conscience and should act towards one another in
# a spirit of brotherhood. Everyone has the right to life, liberty and security of person.
#
#
# And here are the doc's sentences:
# All human beings are born free and equal in dignity and rights.
#
# They are endowed with reason and conscience and should act towards one another in
# a spirit of brotherhood.
# Everyone has the right to life, liberty and security of person.

# %% [markdown]
# Nerdy Python note: The `.sents` attribute is a [generator](https://wiki.python.org/moin/Generators), so you can't index or count it directly. Generator functions are also known as "lazy iterators," which are objects that you can loop over like a list, but do not store their contents in memory. This may seem like a bug right now, but it's actually a feature because it's a way of saving memory when you're dealing with large amounts of text.
#
# To index or count the .sents attribute, you'll need to convert it to a list first using the `list()` function. Then you can treat it like a list and access individual items:

# %%
sentences_as_list = list(doc.sents)

# %%
# check the length to make sure it worked

print("Here's the number of sentences: " + str(len(sentences_as_list)))
# Out:
# Here's the number of sentences: 3

# %% [markdown]
# ### Words
#
# Iterating over a document (or a sentence) yields each word in turn. Words are represented with spaCy [Token](https://spacy.io/docs/api/token) objects, which have several interesting attributes.
#
# The `.text` attribute gives the word, and the `.lemma_` attribute gives the word's "lemma." What is a "lemma"?
#
# Here are Daniel Jurafsky and James H. Martin on the subject:
#
# > **Lemmas and Senses**
# >
# > Let’s start by looking at how one word (we’ll choose "mouse") might be defined in a dictionary:
# >
# > mouse (N)
# > 1.  any of numerous small rodents...
# > 2.  a hand-operated device that controls a cursor...
# >
# > Here the form "mouse" is the `lemma`, which is also called the "citation form." The form "mouse" would also be the lemma for the word "mice." One way to think about it is that dictionaries don’t have separated definitions for inflected forms like mice.
# >
# >Similarly, "sing" is the lemma for "sing," "sang," and "sung." In many languages, the infinitive form is used as the lemma for the verb, so Spanish dormir “to sleep” is the lemma for duermes “you sleep”. The specific forms _sung_ or _carpets_ or _sing_ or _duermes_ are called `wordforms`."
#
# Let's see how the words and lemmas compare in our tiny document:

# %%
print("Word, lemma\n")
for word in doc:
    print(word.text + ", " + word.lemma_)
    
# Note: On the underscore at the end of a variable, see
# https://www.datacamp.com/community/tutorials/role-underscore-python#STU
# Out:
# Word, lemma
#
# All, all
# human, human
# beings, being
# are, be
# born, bear
# free, free
# and, and
# equal, equal
# in, in
# dignity, dignity
# and, and
# rights, right
# ., .
#
# ,
#
# They, they
# are, be
# endowed, endow
# with, with
# reason, reason
# and, and
# conscience, conscience
# and, and
# should, should
# act, act
# towards, towards
# one, one
# another, another
# in, in
#
# ,
#
# a, a
# spirit, spirit
# of, of
# brotherhood, brotherhood
# ., .
# Everyone, everyone
# has, have
# the, the
# right, right
# to, to
# life, life
# ,, ,
# liberty, liberty
# and, and
# security, security
# of, of
# person, person
# ., .

# %% [markdown]
# As indicated above, we can also interate through the document by sentence. To wit:

# %%
sentence = list(doc.sents)[1]  # same as sentence = sentences_as_list[1]

for word in sentence:
    print(word.text, word.lemma_)
# Out:
# They they
# are be
# endowed endow
# with with
# reason reason
# and and
# conscience conscience
# and and
# should should
# act act
# towards towards
# one one
# another another
# in in
#
#
#
# a a
# spirit spirit
# of of
# brotherhood brotherhood
# . .

# %% [markdown]
# Why does this distinction between "word" and "lemma" matter? Well for one, at certain times you might want to be able to gather all of the wordforms of a single word together so that you could count them as a single unit. This will come into play as we start counting words in various ways...
#
# But first:

# %% [markdown]
# ### How to load data from a file into spaCy
#
# You can load data from a file easily with spaCy, which is good because most of the text we'll be analyzing in this course will come to us in file form.

# %%
# get the text of the 2020 Democratic platform from GitHub 
import requests 

resp = requests.get('https://raw.githubusercontent.com/laurenfklein/QTM340-Fall22/main/corpora/platforms/democrat_platform_2020.txt')
dem_platform = resp.text

# %% [markdown]
# Next, let's turn the text into a spaCy document, as we did before:

# %%
dem_plat_doc = nlp(dem_platform)

# %% [markdown]
# ...and do the same thing for the 2020 Republican platform:

# %%
resp = requests.get('https://raw.githubusercontent.com/laurenfklein/QTM340-Fall22/main/corpora/platforms/republican_platform_2020.txt')
repub_platform = resp.text

repub_plat_doc = nlp(repub_platform)

# %% [markdown]
# ## Counting keywords (with custom code)
#
# We'll learn other ways to do this later in the semester, but since this will help us on the way to figuring out why named entity recognition is useful, let's think about a scenario in which we want to know how many times President Biden was named in the Democratic platform vs. the Republican platform, we could do something like this:

# %%
# define a basic function to count words

def count_words(keyword, document): # this says: we'll always pass in a keyword to search for  
                                    # and a spacy document to search 
    # here's our keyword hit counter
    key_count = 0
    
    # iterate through all the words in the document  
    for word in document:
        cur_word = word.text # remember, word is an object so you need to look at word.text
        
        # see if the keyword matches the word, and if so, increment our counter;
        if keyword.lower() == cur_word.lower(): # note that this is just a basic string comparison
            
            # if there's a match, increment the keyword counter by 1 
            key_count += 1
    
    # this returns the final keyword count
    return key_count

# %%
# now call our newly defined function for the dem_plat_doc and the repic_plat_doc

num_d_bidens = count_words("Biden", dem_plat_doc)
num_r_bidens = count_words("Biden", repub_plat_doc)

print("Number of Biden mentions in Democratic platform: " + str(num_d_bidens))
print("Number of Biden mentions in Republican platform: " + str(num_r_bidens))
# Out:
# Number of Biden mentions in Democratic platform: 18
# Number of Biden mentions in Republican platform: 2

# %% [markdown]
# What if we wanted to see which people were named in each platform, but we didn't know how to search for them by name? This is where NER comes in.

# %% [markdown]
# ## Named Entity Recognition

# %% [markdown]
# Identifying sentences and words is just the beginning of what spaCy can do. Also encoded in the spaCy `document` is a great deal of information about named entities: that is, about people, places, and many types of things. This is what's known as "Named Entity Recognition," or NER.
#
# You might use NER to identify the geographic locations mentioned in texts, a first step toward mapping them. Or you might use NER to identify the most frequently appearing characters in a novel, or to build a network of characters that appear together. Or you might use NER in a more exploratory capacity, as in the scenario I've outlined above.
#
# Below is a Named Entities chart taken from [spaCy's website](https://spacy.io/api/annotation#named-entities), which shows the different named entities that spaCy can identify, as well as their corresponding "type labels."
#
# Note that "PERSON"--what we're going to look for in a sec--is just one of many different named entities that spaCy can recognize.
#
# Let's try it out.

# %% [markdown]
# |Type Label|Description|
# |:---:|:---:|
# |PERSON|People, including fictional.|
# |NORP|Nationalities or religious or political groups.|
# |FAC|Buildings, airports, highways, bridges, etc.|
# |ORG|Companies, agencies, institutions, etc.|
# |GPE|Countries, cities, states.|
# |LOC|Non-GPE locations, mountain ranges, bodies of water.|
# |PRODUCT|Objects, vehicles, foods, etc. (Not services.)|
# |EVENT|Named hurricanes, battles, wars, sports events, etc.|
# |WORK_OF_ART|Titles of books, songs, etc.|
# |LAW|Named documents made into laws.|
# |LANGUAGE|Any named language.|
# |DATE|Absolute or relative dates or periods.|
# |TIME|Times smaller than a day.|
# |PERCENT|Percentage, including ”%“.|
# |MONEY|Monetary values, including unit.|
# |QUANTITY|Measurements, as of weight or distance.|
# |ORDINAL|“first”, “second”, etc.|
# |CARDINAL|Numerals that do not fall under another type.|

# %% [markdown]
# Here's how we pull out all of the people mentioned in the Democratic platform using the `ents` method (short for "entitites":

# %%
# an empty list we'll use to store the people
people = []
    
# iterate through all the words in the document (note this could also be sentences) 
for ent in dem_plat_doc.ents: # this is a method that turns the doc into entitites
    if ent.label_ == "PERSON": # again, here's basic string comparison
        if ent.text not in people: # we'll only add new people
            people.append(ent.text)
            
people
# Out:
# ['Oreilles Band',
#  'Trump',
#  'Frederick Douglass',
#  'Donald Trump',
#  'Historically Black Colleges',
#  'Latino',
#  'Black',
#  'secondary boycotts',
#  'Sherman',
#  'Olmstead',
#  'L. C.',
#  'Latinos',
#  'Ryan White HIV/AIDS Program',
#  'Cancer Moonshot',
#  'Pell Grants',
#  'Matthew Shepard',
#  'James Byrd',
#  'Jim Crow',
#  'Juneteenth',
#  'Obama',
#  'Tribes',
#  'Alaska Natives',
#  'Alaska Native',
#  'Indian Tribes',
#  'Buckley v. Valeo',
#  'Maria',
#  'pre-K',
#  'Early Head Start',
#  'Nicolas Maduro’s',
#  'Temporary Protected Status',
#  'Undermining',
#  'Xi Jinping',
#  'Vladimir Putin’s']

# %% [markdown]
# **Can you modify the code above to pull out the people named in the Republican platform?**

# %%
## Remove below

# here's an empty list we can use to store the people
people = []
    
# Iterate through all the words in the document  
for ent in repub_plat_doc.ents: # this is a method that turns the doc into entitites
    if ent.label_ == "PERSON":
        if ent.text not in people: # only add new people
            people.append(ent.text)
            
people
# Out:
# ['Donald Trump',
#  'Trump',
#  'Mary Fallin',
#  'John Barrasso',
#  'Virginia Foxx\n\n                                                                CO-CHAIR',
#  'Obama',
#  'Reagan',
#  'Lame Duck Congress',
#  'Carter',
#  'Clinton Administrations',
#  'Eisenhower',
#  'Ronald Reagan',
#  'Abraham Lincoln',
#  'John Adams',
#  'Antonin Scalia',
#  'George Washington’s',
#  'John Marshall',
#  'Joseph Storey',
#  'Scalia',
#  'George Washington',
#  'Thomas Jefferson',
#  'Clinton',
#  'George H.W. Bush',
#  'Bill Clinton',
#  'Kelo',
#  'Inventors',
#  'Manner',
#  'Law',
#  'James Wilson',
#  'Godzilla',
#  'Glass',
#  'Alaska Natives',
#  'Kennedy',
#  'Common Core',
#  'STEM',
#  'Mifeprex',
#  'Steve Gleason Act',
#  'marijuana',
#  'Alexander Hamilton',
#  'Jimmy Carter',
#  'Abraham Lincoln’s',
#  'Bashar Assad',
#  'Americanism',
#  'Kim',
#  'Truman',
#  'George W. Bush’s',
#  'Islam',
#  'Boko Haram',
#  'Sisi of Egypt',
#  'Hillary Clinton',
#  'Century Threats',
#  'Pearl Harbor',
#  'Virginia Foxx\n\n                                                    Subcommittee',
#  'Delbert Hosemann Andy Puzder',
#  'Kathy Kiernan',
#  "Leslie Rutledge\n\n                                             America's",
#  'Tom Schriebel',
#  'Russ Walker\n\n                                               Great',
#  'Carolyn McLarty',
#  'Patricia Longo',
#  'Ron Rabin Steve Yates',
#  'Jim Cams            Rachel Hoff            Julie Adams      \n     Judy Cams         ',
#  'Jim Crawford',
#  'Cindy Graves      Sandra',
#  'Judy Eledge',
#  'Joe Gruters',
#  'Tony Perkins',
#  'Eric Brakey',
#  'Stacey Guerin',
#  'Andrea Kadar      Juan',
#  'Carlos Benitez      ',
#  'Adrienne King',
#  'Amy Carnevale',
#  'Leslie Rutledge      William McClary',
#  'Bob Maginn',
#  'Noel Hentschel',
#  'Vicki Keen             Joe Hune',
#  'Andy Puzder',
#  'Steve Yates',
#  'Robin Coran',
#  'Stephanie Holderfield',
#  'Andy Aplikowski',
#  'Justin Everett',
#  'John Lynch',
#  'Janet Beihoffer',
#  'Anthony D’Amelio',
#  'James Bopp            Lynn Fitch',
#  'Patricia Longo         ',
#  'Brenda Goff         ',
#  'Delbert Hosemann',
#  'Mary Kay Culp                            \n                         Kris Kobach                             \n\n\x0cMONTANA',
#  'Seth Berglee            ',
#  'David Barton',
#  'OHIO',
#  'Diana Denman',
#  'David Johnson',
#  'Debby Brehm        ',
#  'Tracey Monroe-Winbush      ',
#  'Boyd Matheson \nBrian Buescher',
#  'Rick Cochran',
#  'Jesse Law                  OREGON',
#  'Russ Walker',
#  'Cynthia Dunbar',
#  'Thomas Valentine',
#  'Jim McErlane         VIRGIN',
#  'Joseph Pennacchio       ',
#  'Carol Sides',
#  'Jonathan Gardner      Jorge',
#  'Andrea Moore',
#  'Philip Wilson',
#  'Thomas Dadey',
#  'Lee Ann Sennick         Melody',
#  'Anne Dickerson         SOUTH',
#  'Alan Clemmons       ',
#  'Mary Forrester         ',
#  'LaDonna Ryggs',
#  'Kathy Kiernan \n',
#  'Ron Rabin               ',
#  'Tom Schreibel \nNORTH DAKOTA             ',
#  'Kelly Armstrong           Hal Wick          Marti',
#  'Kelly Schmidt',
#  'Dick Shanor',
#  'Victor Ashe',
#  'Ben Key',
#  'Andrew Bremberg',
#  'Bill Gribbin',
#  'Eric Ueland',
#  'Mary Salvi',
#  'David Schiappa',
#  'Parliamentarian Justin Riemer',
#  'Mary Elizabeth Taylor',
#  'Clerk Allison Curry',
#  'Clerk Sloane Skinner',
#  'Clerk Karen Portik',
#  'Marcia Brown',
#  'Sheila Berkley',
#  'Mike Mears',
#  'Rachel Packebush',
#  'Ed Cowling',
#  'Blake Glovitz',
#  'Kim Owens',
#  'Will Gillette',
#  'Gordon James\n\n                                                               Court',
#  'Stephen Mengelkamp',
#  'Jeff Schlagenhauf',
#  'Eric Ueland\n\n                                                                    Government',
#  'Katy Talento',
#  'Stephen Higgins',
#  "Robert Porter\n\n                                                                America's",
#  'Justin Memmott\n\n                                                               Great',
#  'Michael Stransky',
#  'Robert Wilkie',
#  'John Bolton',
#  'Judy Van Rest',
#  'William Martin',
#  'Mitch Bainwol',
#  'Anne Phelps',
#  'Steven Duffield',
#  'Mike Ambrosini',
#  'Caroline Anderegg',
#  'Carl Anderson',
#  'Alex Angelson',
#  'Christine Anton',
#  'Sara Armstrong',
#  'Michael Babyak',
#  'Gineen Bresso',
#  'Tyler Brown',
#  'Jeffrey Brownlee',
#  'Courtney Butcher',
#  'Anna Katherine Cabaniss',
#  'Joseph Chang',
#  'Jason Chung',
#  'CC Cobaugh',
#  'Paul Coyer',
#  'Sharon Day',
#  'Logan Dryden',
#  'Kim Ekmark',
#  'Max Everett',
#  'Dirk Eyman',
#  'Jonathan Du',
#  'Grant Gardner',
#  'Mike Gilding',
#  'Ed Goeas',
#  'Jackson Greene',
#  'William Heartsill',
#  'Rebecca Heilig',
#  'Lauren Hernandez',
#  'Mike Holley',
#  'CJ Jordan',
#  'Katie Hrkman',
#  'Dave Juday',
#  'Kate Karnes',
#  'Sarah Keeny',
#  'Jennifer Ketchum',
#  'Kirsten Kukowski',
#  'Dan Kunsman',
#  'Dee Dee Lancaster',
#  'Gerrit Lansing',
#  'Jeff Larson',
#  'Anne Lesser',
#  'Ryan Mahoney',
#  'Matthew Mazzone',
#  'Arjun Mody',
#  'Janet Montesi',
#  'Kimberly Morrall',
#  'Vanessa Morrone',
#  'Maison Newenhouse',
#  'Kathryn Neville',
#  'Lexi Nord',
#  'Denise Northrup',
#  'Andrew Olmem',
#  'Mike Omegna',
#  'Caroline Ozer',
#  'John Phillippe',
#  'Brandon Renz',
#  'Jackie Rivera',
#  'Christine Samuelian',
#  'Audrey Scagnelli',
#  'Tory Sendek',
#  'Lani Short',
#  'Harold “Hal” Smith',
#  'Steve Smith',
#  'Veronica Smith',
#  'Sean Spicer',
#  'Elizabeth Stangl',
#  'Elizabeth Steil',
#  'Melinda Stell',
#  'Maddison Stone',
#  'Jan Sumrall',
#  'James Tobin',
#  'Lauren Toomey',
#  'Courtney Uckele',
#  'Mike Vallante',
#  'Evan Walker',
#  'Katie Walsh',
#  'Lindsey Walters',
#  'David Wilezol',
#  'Madeleine Westerhout']

# %% [markdown]
# **Python Bonus! Looking at the syntax of the function above, can you write a function that will pull out the people in any document?**

# %% [markdown]
# ## Visualizing spaCy NER with displaCy
#
# Here's a neat thing! To quickly see spaCy's NER in action, we can use the [spaCy module `displacy`](https://spacy.io/usage/visualizers#ent) with the `style=` parameter set to "ent" to see how spaCy tags its documents. (DisplaCy is special spaCy module for visualization).

# %% [markdown]
# To do so, we’re going to need to import displaCy, Also, because the `spaCy` code expects all strings to be unicode strings, per above, we can also include `from __future__ import unicode_literals` to make our lives easier.

# %%
from __future__ import unicode_literals
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

# %%
displacy.render(dem_plat_doc, style="ent", jupyter=True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2020 Democratic Party Platform
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br> The platform was considered by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the 2020 Platform Committee
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  at its meeting on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     July 27, 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# , and was approved by
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Democratic National Convention
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br>                                        on
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     August 18, 2020
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# .</br>                              TABLE OF CONTENTS</br></br>DEMOCRATIC NATIONAL CONVENTION LAND ACKNOWLEDGEMENT</br></br> PREAMBLE</br></br>                      PROTECTING AMERICANS AND RECOVERING FROM THE COVID-19 PANDEMIC</br></br> BUILDING A
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     STRONGER
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , FAIRER ECONOMY</br></br>
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Protecting Workers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Families
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and Creating Millions of Jobs Across America Raising Wages and Promoting Workers’ Rights Enacting Robust Work-Family Policies Investing in the Engines of Job Creation Building A Fair System of International Trade for Our Workers Putting Homeownership in Reach and Guaranteeing Safe Housing for Every American Leveling the Economic Playing Field</br></br>        Reforming the Tax Code to Benefit Working Families Curbing Wall Street Abuses Ending Poverty</br></br>        Protecting Consumer Rights and Privacy Tackling Runaway Corporate Concentration Guaranteeing a Secure and Dignified Retirement</br></br> ACHIEVING UNIVERSAL,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     AFFORDABLE
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , QUALITY HEALTH CARE</br></br>    Securing Universal Health Care Through a Public Option</br></br>    Bringing Down Drug Prices and Taking on
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Pharmaceutical Industry
#
#     Reducing Health Care Costs and Improving Health Care Quality
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# </br></br>        Expanding Access to Mental Health and Substance Use Treatment Expanding Long-Term Care Services and Supports Eliminate Racial,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Gender
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Geographic Health Inequities Protecting Native American Health Securing Reproductive Health, Rights
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
# , and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Justice Protecting
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Promoting Maternal Health Protecting LGBTQ+ Health Strengthening and Supporting the Health Care Workforce Investing in Health Science and Research
#
#
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     8
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     13
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     14
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  16 16 20 20 22 22 23 23 25
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br></br>
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     25
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
# </br></br>
# <mark class="entity" style

# %% [markdown]
# Pretty neat, huh? Except, it's not completely perfect...
#
# **Can you find some examples of things it tagged properly?**
#
# **What about examples of things it misidentified?**
#
# (You can scroll through the introductory material if you need to).

# %% [markdown]
# Tagged Democrats and Christians properly (as NORP) and many orgs were tagged properly (ie the Organization of American States (ORG) and the United Nations Declaration on the Rights of Indigenous Peoples (ORG).
#
# Misidentified: They called the Mexico City Policy a GPE. Tagged Uyghurs and Yezidis as GPE, which is incorrect.

# %% [markdown]
# This is a good reminder than spaCy is far from perfect and you always need to check how it does!
#
# This is all we're going to do with NER today. As you can see this is just the very tip of the iceberg. You could now easily get, say, a full list of persons or orgs or products from any text. Feel free to explore further on your own.

# %% [markdown]
# ## Dictionaries
#
# One other basic way to analyze text is through what's known as a dictionary. (Not a Python dictionary!). This is just a set of words that evoke some category, optionally paired with a rating on some scale. As I mentioned last class, this is how the first methods of sentiment analysis worked--by counting up the number of "positive" and "negative" words that matched two predetermined sets of words--or dictionaries to produce the sentiment score.
#
# Even though there are now fancier ways to categorize langugage, dictionaries are still widely used--and to sometimes profound effect, as we saw in the "Birth Stories" paper.
#
# The words that constitute a dictionary are determined according to a wide range of methods, from completely hand-crafted, to semi-supervised, to fully "learned" (by computers).
#
# Let's look at a simple example.
#
# Here we'll define our own "immigration" dictionary by picking some words that we think have to do with the topic of immigration. (On the scale of hand-crafted to learned, this one is *extremely* hand-crafted).

# %%
immigration_dictionary=set(["wall", "border", "borders", "immigrants","immigration"])

# %% [markdown]
# We can actully use our previously defined `count_words` function to search both party platforms for how they stack up against the immigration dictionary:

# %%
dem_counts = 0
repub_counts = 0

for word in immigration_dictionary:
    dem_counts += count_words(word, dem_plat_doc)
    repub_counts += count_words(word, repub_plat_doc)
    
print("Immigratation scores:")
print("Dems: " + str(dem_counts))
print("Repubs: " + str(repub_counts))
# Out:
# Immigratation scores:
# Dems: 63
# Repubs: 38

# %% [markdown]
# Interesting! For our (flimsy) definition of immmigration, the Democratic platform seem to have mentioned it more than the Republican platform at a ratio of nearly 2:1.

# %% [markdown]
# # Part-of-Speech Tagging
#
# I've left part-of-speech (PoS) tagging until last because it's simultaneously very useful, very complicated (unless you're a big grammar nerd), and very boring (again, unless you're a big grammar nerd).
#
# Why should we bother? Well, for one, parts of speech are the grammatical units of language — such as (in English) nouns, verbs, adjectives, adverbs, pronouns, and prepositions. Each of these parts of speech plays a different role in a sentence. By computationally identifying parts of speech, we can start computationally exploring syntax, the relationship between words — rather than only focusing on words in isolation.
#
# I've attempted to make this lesson more exciting by including some dymanically-generated brightly colored charts and some [xkcd](https://xkcd.com/1443/). Buckle up!

# %% [markdown]
# <img src="https://imgs.xkcd.com/comics/language_nerd.png" >

# %% [markdown]
# ## Part-of-Speech Tagging with spaCy
#
# In spaCy, POS tagging works much likes NER tagging. Here is a chart (which resembles the NER chart) of which parts of speech spaCy is able to recognize and identify:

# %% [markdown]
# | POS   | Description               | Examples                                      |
# |:-----:|:-------------------------:|:---------------------------------------------:|
# | ADJ   | adjective                 | big, old, green, incomprehensible, first      |
# | ADP   | adposition                | in, to, during                                |
# | ADV   | adverb                    | very, tomorrow, down, where, there            |
# | AUX   | auxiliary                 | is, has (done), will (do), should (do)        |
# | CONJ  | conjunction               | and, or, but                                  |
# | CCONJ | coordinating conjunction  | and, or, but                                  |
# | DET   | determiner                | a, an, the                                    |
# | INTJ  | interjection              | psst, ouch, bravo, hello                      |
# | NOUN  | noun                      | girl, cat, tree, air, beauty                  |
# | NUM   | numeral                   | 1, 2017, one, seventy-seven, IV, MMXIV        |
# | PART  | particle                  | ’s, not,                                      |
# | PRON  | pronoun                   | I, you, he, she, myself, themselves, somebody |
# | PROPN | proper noun               | Mary, John, London, NATO, HBO                 |
# | PUNCT | punctuation               | ., (, ), ?                                    |
# | SCONJ | subordinating conjunction | if, while, that                               |
# | SYM   | symbol                    | $, %, §, ©, +, −, ×, ÷, =, :), 😝             |
# | VERB  | verb                      | run, runs, running, eat, ate, eating          |
# | X     | other                     | sfpksdpsxmsa                                  |
# | SPACE | space                     |                                               |

# %% [markdown]
# You can access the POS for any word using the `pos_` attribute. If you want a more specific designation, you can use the `tag_` attribute.
#
# Note that this *is* slightly different than accessing NER tags, which requires that you start with the document's entities (`document.ents`) rather than the document itself. There are technical reasons for this that I can explain if you're curious.

# %% [markdown]
# ### Enough talk. Let's see POS tagging in action!
#
# Let's look at the parts-of-speech in the Republican party platform.

# %%
print("Word, POS, tag\n")

for word in repub_plat_doc:
    print(word.text, word.pos_, word.tag_)
# Out:
# Streaming output truncated to the last 5000 lines.
# a DET DT
# friendship NOUN NN
# beyond ADP IN
# the DET DT
# reach NOUN NN
# of ADP IN
# those PRON DT
# who PRON WP
# wish VERB VBP
# to PART TO
# divide VERB VB
# us PRON PRP
# . PUNCT .
# We PRON PRP
# have VERB VBP
# common ADJ JJ
# imperatives NOUN NNS
# : PUNCT :
# Ending VERB VBG
# terrorism NOUN NN
# , PUNCT ,
# combating VERB VBG
# nuclear ADJ JJ
# proliferation NOUN NN
# , PUNCT ,
# promoting VERB VBG
# trade NOUN NN
# , PUNCT ,
# and CCONJ CC
# more ADJ JJR
# . PUNCT .
# We PRON PRP
# also ADV RB
# have VERB VBP
# a DET DT
# common ADJ JJ
# problem NOUN NN
# : PUNCT :
# The DET DT
# continuing VERB VBG
# erosion NOUN NN
# of ADP IN
# personal ADJ JJ
# liberty NOUN NN
# and CCONJ CC
# fundamental ADJ JJ
# rights NOUN NNS
# under ADP IN
# the DET DT
# current ADJ JJ
# officials NOUN NNS
# in ADP IN
# the DET DT
# Kremlin PROPN NNP
# . PUNCT .
# Repressive PROPN NNP
# at ADP IN
# home NOUN NN
# and CCONJ CC
# reckless ADJ JJ
# abroad ADV RB
# , PUNCT ,
# their PRON PRP$
# policies NOUN NNS
# imperil VERB VBP
# the DET DT
# nations NOUN NNS
# which PRON WDT
# regained VERB VBD
# their PRON PRP$
# self NOUN NN
# - PUNCT HYPH
# determination NOUN NN
# upon SCONJ IN
# the DET DT
# collapse NOUN NN
# of ADP IN
# the DET DT
# Soviet PROPN NNP
# Union PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# meet VERB VB
# the DET DT
# return NOUN NN
# of ADP IN
# Russian ADJ JJ
# belligerence NOUN NN
# with ADP IN
# the DET DT
# same ADJ JJ
# resolve NOUN NN
# that PRON WDT
# led VERB VBD
# to ADP IN
# the DET DT
# collapse NOUN NN
# of ADP IN
# the DET DT
# Soviet PROPN NNP
# Union PROPN NNP
# . PUNCT .
# We PRON PRP
# will AUX MD
# not PART RB
# accept VERB VB
# any DET DT
# territorial ADJ JJ
# change NOUN NN
# in ADP IN
# Eastern PROPN NNP
# Europe PROPN NNP
# imposed VERB VBD
#
#  SPACE _SP
# by ADP IN
# force NOUN NN
# , PUNCT ,
# in ADP IN
# Ukraine PROPN NNP
# , PUNCT ,
# Georgia PROPN NNP
# , PUNCT ,
# or CCONJ CC
# elsewhere ADV RB
# , PUNCT ,
# and CCONJ CC
# will AUX MD
# use VERB VB
# all DET DT
# appropriate ADJ JJ
# constitutional ADJ JJ
# measures NOUN NNS
# to PART TO
# bring VERB VB
# to ADP IN
# justice NOUN NN
# the DET DT
# practitioners NOUN NNS
# of ADP IN
# aggression NOUN NN
# and CCONJ CC
# assassination NOUN NN
# . PUNCT .
#
#
#       SPACE _SP
# We PRON PRP
# urge VERB VBP
# greater ADJ JJR
# attention NOUN NN
# in ADP IN
# U.S. PROPN NNP
# diplomacy NOUN NN
# , PUNCT ,
# trade NOUN NN
# , PUNCT ,
# and CCONJ CC
# strategic ADJ JJ
# planning NOUN NN
# , PUNCT ,
# to ADP IN
# the DET DT
# nations NOUN NNS
# of ADP IN
# Eurasia PROPN NNP
# , PUNCT ,
# formerly ADV RB
# parts NOUN NNS
# of ADP IN
# the DET DT
# Soviet PROPN NNP
# Empire PROPN NNP
# . PUNCT .
# Caught VERB VBN
# between ADP IN
# their PRON PRP$
# two NUM CD
# authoritarian ADJ JJ
# neighbors NOUN NNS
# , PUNCT ,
# their PRON PRP$
# path NOUN NN
# toward ADP IN
# democratic ADJ JJ
# institutions NOUN NNS
# has AUX VBZ
# been AUX VBN
# uncertain ADJ JJ
# . PUNCT .
# We PRON PRP
# urge VERB VBP
# our PRON PRP$
# government NOUN NN
# and CCONJ CC
# our PRON PRP$
# allies NOUN NNS
# to PART TO
# work VERB VB
# toward ADP IN
# the DET DT
# integration NOUN NN
# of ADP IN
# the DET DT
# Central ADJ JJ
# Asian ADJ JJ
# republics NOUN NNS
# into ADP IN
# the DET DT
# global ADJ JJ
# economy NOUN NN
# through ADP IN
# foreign ADJ JJ
# investment NOUN NN
# , PUNCT ,
# which PRON WDT
# can AUX MD
# bring VERB VB
# with ADP IN
# it PRON PRP
# market NOUN NN
# and CCONJ CC
# political ADJ JJ
# reforms NOUN NNS
# and CCONJ CC
# a DET DT
# firmer ADJ JJR
# establishment NOUN NN
# of ADP IN
# the DET DT
# rule NOUN NN
# of ADP IN
# law NOUN NN
# . PUNCT .
# Those DET DT
# developments NOUN NNS
# will AUX MD
# not PART RB
# only ADV RB
# improve VERB VB
# the DET DT
# living NOUN NN
# conditions NOUN NNS
# throughout ADP IN
# that DET DT
# vast ADJ JJ
# area NOUN NN
# but CCONJ CC
# are AUX VBP
# likely ADJ JJ
# to PART TO
# reduce VERB VB
# the DET DT
# lure NOUN NN
# of ADP IN
# the DET DT
# radical ADJ JJ
# ideologies NOUN NNS
# that PRON WDT
# already ADV RB
# threaten VERB VBP
# the DET DT
# region NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# Family PROPN NNP
# of ADP IN
# the DET DT
# Americas PROPN NNPS
#
#
#       SPACE _SP
# Our PRON PRP$
# future NOUN NN
# is AUX VBZ
# intimately ADV RB
# tied VERB VBN
# to ADP IN
# the DET DT
# future NOUN NN
# of ADP IN
# the DET DT
# Americas PROPN NNPS
# . PUNCT .
# Family NOUN NN
# , PUNCT ,
# language NOUN NN
# , PUNCT ,
# culture NOUN NN
# , PUNCT ,
# environment NOUN NN
# , PUNCT ,
# and CCONJ CC
# trade NOUN NN
# link VERB VBP
# us PRON PRP
# closely ADV RB
# with ADP IN
# both PRON DT
# Canada PROPN NNP
# and CCONJ CC
# Mexico PROPN NNP
# . PUNCT .
# Our PRON PRP$
# relations NOUN NNS
# with ADP IN
# both PRON DT
# of ADP IN
# these DET DT
# friends NOUN NNS
# will AUX MD
# be AUX VB
# based VERB VBN
# upon SCONJ IN
# continuing VERB VBG
# cooperation NOUN NN
# and CCONJ CC
# our PRON PRP$
# mutually ADV RB
# shared VERB VBN
# interests NOUN NNS
# . PUNCT .
# Our PRON PRP$
# attention NOUN NN
# to ADP IN
# trade NOUN NN
# and CCONJ CC
# environmental ADJ JJ
# issues NOUN NNS
# will AUX MD
# contribute VERB VB
# to ADP IN
# strong ADJ JJ
# economic ADJ JJ
# growth NOUN NN
# and CCONJ CC
# prosperity NOUN NN
# throughout ADP IN
# the DET DT
# Americas PROPN NNPS
# . PUNCT .
#
#
#       SPACE _SP
# We PRON PRP
# thank VERB VBP
# our PRON PRP$
# neighbors NOUN NNS
# in ADP IN
# Mexico PROPN NNP
# and CCONJ CC
# Canada PROPN NNP
# who PRON WP
# have AUX VBP
# been AUX VBN
# our PRON PRP$
# partners NOUN NNS
# in ADP IN
# the DET DT
# fight NOUN NN
# against ADP IN
# terrorism NOUN NN
# and CCONJ CC
# the DET DT
# war NOUN NN
# on ADP IN
# drugs NOUN NNS
# . PUNCT .
# The DET DT
# Mexican ADJ JJ
# people NOUN NNS
# deserve VERB VBP
# our PRON PRP$
# assistance NOUN NN
# as SCONJ IN
# they PRON PRP
# bravely ADV RB
# resist VERB VBP
# the DET DT
# drug NOUN NN
# cartels VERB VBZ
# that PRON WDT
# traffic VERB VBP
# in ADP IN
# death NOUN NN
# on ADP IN
# both DET DT
# sides NOUN NNS
# of ADP IN
# our PRON PRP$
# border NOUN NN
# . PUNCT .
# Their PRON PRP$
# rich ADJ JJ
# cultural ADJ JJ
# and CCONJ CC
# religious ADJ JJ
# heritage NOUN NN
# , PUNCT ,
# shared VERB VBN
# by ADP IN
# many ADJ JJ
# millions NOUN NNS
# of ADP IN
# our PRON PRP$
# fellow ADJ JJ
# citizens NOUN NNS
# , PUNCT ,
# should AUX MD
# foster VERB VB
# greater ADJ JJR
# understanding NOUN NN
# and CCONJ CC
# cooperation NOUN NN
# between ADP IN
# our PRON PRP$
# countries NOUN NNS
# . PUNCT .
#
#
#       SPACE _SP
# Our PRON PRP$
# Canadian ADJ JJ
# neighbors NOUN NNS
# can AUX MD
# count VERB VB
# on ADP IN
# our PRON PRP$
# cooperation NOUN NN
# and CCONJ CC
# respect NOUN NN
# . PUNCT .
# To PART TO
# advance VERB VB
# North PROPN NNP
# America PROPN NNP
# ’s PART POS
# energy NOUN NN
# independence NOUN NN
# , PUNCT ,
# we PRON PRP
# intend VERB VBP
# to PART TO
# reverse VERB VB
# the DET DT
# current ADJ JJ
# Administration PROPN NNP
# ’s PART POS
# blocking NOUN NN
# of ADP IN
# the DET DT
# Keystone PROPN NNP
# XL PROPN NNP
# Pipeline PROPN NNP
# . PUNCT .
# Apart ADV RB
# from ADP IN
# its PRON PRP$
# economic ADJ JJ
# value NOUN NN
# , PUNCT ,
# that DET DT
# project NOUN NN
# has AUX VBZ
# become VERB VBN
# a DET DT
# symbol NOUN NN
# in ADP IN
# the DET DT
# contest NOUN NN
# between ADP IN
# the DET DT
# public ADJ JJ
# ’s NOUN NN
# desire NOUN NN
# for ADP IN
# economic ADJ JJ
# development NOUN NN
# and CCONJ CC
# the DET DT
# government NOUN NN
# ’s PART POS
# hostility NOUN NN
# to ADP IN
# growth NOUN NN
# . PUNCT .
# We PRON PRP
# stand VERB VBP
# with ADP IN
# the DET DT
# people NOUN NNS
# . PUNCT .
#
#
#       SPACE _SP
# We PRON PRP
# express VERB VBP
# our PRON PRP$
# solidarity NOUN NN
# with ADP IN
# all DET PDT
# the DET DT
# peoples NOUN NNS
#
#
#  SPACE _SP
# of ADP IN
# the DET DT
# Western PROPN NNP
# Hemisphere PROPN NNP
# . PUNCT .
# Their PRON PRP$
# aspirations NOUN NNS
# for ADP IN
# economic ADJ JJ
# betterment NOUN NN
# and CCONJ CC
# political ADJ JJ
# liberty NOUN NN
# have AUX VBP
# deserved VERB VBN
# better ADV RBR
# from ADP IN
# our PRON PRP$
# government NOUN NN
# than ADP IN
# its PRON PRP$
# policies NOUN NNS
# of ADP IN
# the DET DT
# last ADJ JJ
# eight NUM CD
# years NOUN NNS
# . PUNCT .
# The DET DT
# current ADJ JJ
# Administration PROPN NNP
# has AUX VBZ
# abandoned VERB VBN
# America PROPN NNP
# ’s PART POS
# friends NOUN NNS
# and CCONJ CC
# rewarded VERB VBD
# its PRON PRP$
# enemies NOUN NNS
# . PUNCT .
# A DET DT
# Republican ADJ JJ
# president NOUN NN
# will AUX MD
# never ADV RB
# embrace VERB VB
# a DET DT
# Marxist ADJ JJ
# dictator NOUN NN
# , PUNCT ,
# in ADP IN
# Venezuela PROPN NNP
# or CCONJ CC
# anywhere ADV RB
# else ADV RB
# . PUNCT .
# The DET DT
# current ADJ JJ
# chief ADJ JJ
# executive NOUN NN
# has AUX VBZ
# allowed VERB VBN
# that SCONJ IN
# country NOUN NN
# to PART TO
# become VERB VB
# a DET DT
# narcoterrorist ADJ JJ
# state NOUN NN
# , PUNCT ,
# an DET DT
# Iranian ADJ JJ
# outpost NOUN NN
# threatening VERB VBG
# Central PROPN NNP
# America PROPN NNP
# , PUNCT ,
# and CCONJ CC
# a DET DT
# safe ADJ JJ
# haven NOUN NN
# for ADP IN
# the DET DT
# agents NOUN NNS
# of ADP IN
# Hezbollah PROPN NNP
# . PUNCT .
# Now ADV RB
# , PUNCT ,
# with ADP IN
# their PRON PRP$
# country NOUN NN
# ruined VERB VBN
# by ADP IN
# socialism NOUN NN
# and CCONJ CC
# on ADP IN
# the DET DT
# verge NOUN NN
# of ADP IN
# chaos NOUN NN
# , PUNCT ,
# the DET DT
# Venezuelan ADJ JJ
# people NOUN NNS
# are AUX VBP
# fighting VERB VBG
# to PART TO
# restore VERB VB
# their PRON PRP$
# democracy NOUN NN
# and CCONJ CC
# regain VERB VB
# their PRON PRP$
# rights NOUN NNS
# . PUNCT .
# When SCONJ WRB
# they PRON PRP
# triumph VERB VBP
# , PUNCT ,
# as SCONJ IN
# they PRON PRP
# surely ADV RB
# will AUX MD
# , PUNCT ,
# the DET DT
# United PROPN NNP
# States PROPN NNP
# will AUX MD
# stand VERB VB
# ready ADJ JJ
# to PART TO
# help VERB VB
# them PRON PRP
# restore VERB VB
# their PRON PRP$
# country NOUN NN
# to ADP IN
# the DET DT
# family NOUN NN
# of ADP IN
# the DET DT
# Americas PROPN NNPS
# . PUNCT .
#
#
#       SPACE _SP
# We PRON PRP
# affirm VERB VBP
# our PRON PRP$
# friendship NOUN NN
# and CCONJ CC
# admiration NOUN NN
# for ADP IN
# the DET DT
# people NOUN NNS
# of ADP IN
# Colombia PROPN NNP
# and CCONJ CC
# call VERB VB
# on ADP IN
# the DET DT
# Republican PROPN NNP
# Congress PROPN NNP
# to PART TO
# express VERB VB
# its PRON PRP$
# solidarity NOUN NN
# with ADP IN
# their PRON PRP$
# decades NOUN NNS
# - PUNCT HYPH
# long ADJ JJ
# fight NOUN NN
# against ADP IN
# the DET DT
# terrorist ADJ JJ
# FARC PROPN NNP
# . PUNCT .
# Their PRON PRP$
# sacrifice NOUN NN
# and CCONJ CC
# suffering NOUN NN
# must AUX MD
# not PART RB
# be AUX VB
# betrayed VERB VBN
# by ADP IN
# the DET DT
# accession NOUN NN
# to ADP IN
# power NOUN NN
# of ADP IN
# murderers NOUN NNS
# and CCONJ CC
# drug NOUN NN
# lords NOUN NNS
# . PUNCT .
#
#
#       SPACE _SP
# We PRON PRP
# want VERB VBP
# to PART TO
# welcome VERB VB
# the DET DT
# people NOUN NNS
# of ADP IN
# Cuba PROPN NNP
# back ADV RB
# into ADP IN
# our PRON PRP$
# hemispheric ADJ JJ
# family NOUN NN
# — PUNCT :
# after SCONJ IN
# their PRON PRP$
# corrupt ADJ JJ
# rulers NOUN NNS
# are AUX VBP
# forced VERB VBN
# from ADP IN
# power NOUN NN
# and CCONJ CC
# brought VERB VBN
# to ADP IN
# account NOUN NN
# for ADP IN
# their PRON PRP$
# crimes NOUN NNS
# against ADP IN
# humanity NOUN NN
# . PUNCT .
# We PRON PRP
# stand VERB VBP
# with ADP IN
# the DET DT
# Women PROPN NNPS
# in ADP IN
# White PROPN NNP
# and CCONJ CC
# all DET PDT
# the DET DT
# victims NOUN NNS
# of ADP IN
# the DET DT
# loathsome ADJ JJ
# regime NOUN NN
# that PRON WDT
# clings VERB VBZ
# to ADP IN
# power NOUN NN
# in ADP IN
# Havana PROPN NNP
# . PUNCT .
# We PRON PRP
# do AUX VBP
# not PART RB
# say VERB VB
# this PRON DT
# lightly ADV RB
# : PUNCT :
# They PRON PRP
# have AUX VBP
# been AUX VBN
# betrayed VERB VBN
# by ADP IN
# those PRON DT
# who PRON WP
# are AUX VBP
# currently ADV RB
# in ADP IN
# control NOUN NN
# of ADP IN
# U.S. PROPN NNP
# foreign ADJ JJ
# policy NOUN NN
# . PUNCT .
# The DET DT
# current ADJ JJ
# Administration PROPN NNP
# ’s PART POS
# “ PUNCT ``
# opening VERB VBG
# to ADP IN
# Cuba PROPN NNP
# ” PUNCT ''
# was AUX VBD
# a DET DT
# shameful ADJ JJ
# accommodation NOUN NN
# to ADP IN
# the DET DT
# demands NOUN NNS
# of ADP IN
# its PRON PRP$
# tyrants NOUN NNS
# . PUNCT .
# It PRON PRP
# will AUX MD
# only ADV RB
# strengthen VERB VB
# their PRON PRP$
# military ADJ JJ
# dictatorship NOUN NN
# . PUNCT .
# We PRON PRP
# call VERB VBP
# on ADP IN
# the DET DT
# Congress PROPN NNP
# to PART TO
# uphold VERB VB
# current ADJ JJ
# U.S. PROPN NNP
# law NOUN NN
# which PRON WDT
# sets VERB VBZ
# conditions NOUN NNS
# for ADP IN
# the DET DT
# lifting NOUN NN
# of ADP IN
# sanctions NOUN NNS
# on ADP IN
# the DET DT
# island NOUN NN
# : PUNCT :
# Legalization NOUN NN
# of ADP IN
# political ADJ JJ
# parties NOUN NNS
# , PUNCT ,
# an DET DT
# independent ADJ JJ
# media NOUN NNS
# , PUNCT ,
# and CCONJ CC
# free ADJ JJ
# and CCONJ CC
# fair ADJ JJ
# internationally ADV RB
# - PUNCT HYPH
# supervised ADJ JJ
# elections NOUN NNS
# . PUNCT .
# We PRON PRP
# call VERB VBP
# for ADP IN
# a DET DT
# dedicated ADJ JJ
# platform NOUN NN
# for ADP IN
# the DET DT
# transmission NOUN NN
# of ADP IN
# Radio PROPN NNP
# and CCONJ CC
# TV PROPN NNP
# Marti PROPN NNP
# and CCONJ CC
# for ADP IN
# the DET DT
# promotion NOUN NN
# of ADP IN
# internet NOUN NN
# access NOUN NN
# and CCONJ CC
# circumvention NOUN NN
# technology NOUN NN
# as ADP IN
# tools NOUN NNS
# to PART TO
# strength VERB VB
# Cuba PROPN NNP
# ’s PRON DT
# pro ADJ JJ
# - ADJ JJ
# democracy ADJ JJ
# movement NOUN NN
# . PUNCT .
# We PRON PRP
# support VERB VBP
# the DET DT
# work NOUN NN
# of ADP IN
# the DET DT
# Commission PROPN NNP
# for ADP IN
# Assistance NOUN NN
# to ADP IN
# a DET DT
# Free PROPN NNP
# Cuba PROPN NNP
# and CCONJ CC
# affirm VERB VB
# the DET DT
# principles NOUN NNS
# of ADP IN
# the DET DT
# Cuban PROPN NNP
# Adjustment PROPN NNP
# Act PROPN NNP
# of ADP IN
# 1966 NUM CD
# , PUNCT ,
# recognizing VERB VBG
# the DET DT
# rights NOUN NNS
# of ADP IN
# Cubans PROPN NNPS
# fleeing VERB VBG
# Communism PROPN NNP
# . PUNCT .
#
#  SPACE _SP
# Africa PROPN NNP
# : PUNCT :
# The DET DT
# Promise PROPN NNP
# and CCONJ CC
# the DET DT
# Challenge PROPN NNP
#
#
#       SPACE _SP
# We PRON PRP
# recognize VERB VBP
# Africa PROPN NNP
# ’s PART POS
# extraordinary ADJ JJ
# potential NOUN NN
# . PUNCT .
# Both CCONJ CC
# the DET DT
# United PROPN NNP
# States PROPN NNP
# and CCONJ CC
# our PRON PRP$
# many ADJ JJ
# African ADJ JJ
# allies NOUN NNS
# will AUX MD
# become VERB VB
# stronger ADJ JJR
# through ADP IN
# investment NOUN NN
# , PUNCT ,
# trade NOUN NN
# , PUNCT ,
# and CCONJ CC
# promotion NOUN NN
# of ADP IN
# the DET DT
# democratic ADJ JJ
# and CCONJ CC
# free ADJ JJ
# market NOUN NN
# principles NOUN NNS
# that PRON WDT
# have AUX VBP
# brought VERB VBN
# prosperity NOUN NN
# around ADP IN
# the DET DT
# world NOUN NN
# . PUNCT .
# We PRON PRP
# pledge VERB VBP
# to PART TO
# be AUX VB
# the DET DT
# best ADJ JJS
# partner NOUN NN
# of ADP IN
# all DET DT
# African ADJ JJ
# nations NOUN NNS
# in ADP IN
# their PRON PRP$
# pursuit NOUN NN
# of ADP IN
# economic ADJ JJ
# freedom NOUN NN
# and CCONJ CC
# human ADJ JJ
# rights NOUN NNS
# . PUNCT .
# The DET DT
# Republican PROPN NNP
# Congress PROPN NNP
# has AUX VBZ
# extended VERB VBN
# to ADP IN
# 2025 NUM CD
# the DET DT
# African PROPN NNP
# Growth PROPN NNP
# and CCONJ CC
# Opportunity PROPN NNP
# Act PROPN NNP
# , PUNCT ,
# and CCONJ CC
# President PROPN NNP
# George PROPN NNP
# W. PROPN NNP
# Bush PROPN NNP
# ’s PART POS
# health NOUN NN
# initiatives NOUN NNS
# — PUNCT :
# AIDS NOUN NN
# relief NOUN NN
# under ADP IN
# PEPFAR PROPN NNP
# and CCONJ CC
# the DET DT
# Global PROPN NNP
# Fund PROPN NNP
# to PART TO
# Fight PROPN NNP
# AIDS PROPN NNP
# , PUNCT ,
# Tuberculosis PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Malaria PROPN NNP
# — PUNCT :
# continue VERB VBP
# to PART TO
# save VERB VB
# millions NOUN NNS
# of ADP IN
# lives NOUN NNS
# . PUNCT .
# Peace NOUN NN
# Corps PROPN NNP
# volunteers NOUN NNS
# and CCONJ CC
# U.S. PROPN NNP
# Seabees PROPN NNP
# teach VERB VBP
# and CCONJ CC
# build VERB VB
# in ADP IN
# villages NOUN NNS
# that PRON WDT
# know VERB VBP
# firsthand ADV RB
# our PRON PRP$
# country NOUN NN
# ’s PART POS
# idealism NOUN NN
# . PUNCT .
#
#
#       SPACE _SP
# We PRON PRP
# stand VERB VBP
# in ADP IN
# solidarity NOUN NN
# with ADP IN
# those DET DT
# African ADJ JJ
# countries NOUN NNS
# now ADV RB
# under ADP IN
# assault NOUN NN
# by ADP IN
# the DET DT
# forces NOUN NNS
# of ADP IN
# radical ADJ JJ
# Islam PROPN NNP
# : PUNCT :
# Boko PROPN NNP
# Haram PROPN NNP
# , PUNCT ,
# al PROPN NNP
# - PUNCT HYPH
# Shabaab PROPN NNP
# , PUNCT ,
# and CCONJ CC
# others NOUN NNS
# like ADP IN
# them PRON PRP
# . PUNCT .
# Their PRON PRP$
# terror NOUN NN
# falls VERB VBZ
# on ADP IN
# both CCONJ CC
# Muslims PROPN NNPS
# and CCONJ CC
# Christians PROPN NNPS
# , PUNCT ,
# on ADP IN
# anyone PRON NN
# who PRON WP
# will AUX MD
# not PART RB
# submit VERB VB
# to ADP IN
# their PRON PRP$
# savage ADJ JJ
# ideology NOUN NN
# . PUNCT .
# We PRON PRP
# urge VERB VBP
# governments NOUN NNS
# throughout ADP IN
# the DET DT
# continent NOUN NN
# to PART TO
# recognize VERB VB
# this DET DT
# threat NOUN NN
# to ADP IN
# their PRON PRP$
# own ADJ JJ
# people NOUN NNS
# . PUNCT .
# We PRON PRP
# support VERB VBP
# closer ADJ JJR
# cooperation NOUN NN
# in ADP IN
# both PRON DT
# military ADJ JJ
# and CCONJ CC
# economic ADJ JJ
# matters NOUN NNS
# with ADP IN
# those PRON DT
# on ADP IN
# the DET DT
# front ADJ JJ
# lines NOUN NNS
# of ADP IN
# civilization NOUN NN
# ’s PART POS
# battle NOUN NN
# against ADP IN
# the DET DT
# forces NOUN NNS
# of ADP IN
# evil NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# Sovereign PROPN NNP
# American PROPN NNP
# Leadership PROPN NNP
# in ADP IN
# International PROPN NNP
# Organizations PROPN NNPS
#
#
#       SPACE _SP
# There PRON EX
# is VERB VBZ
# no DET DT
# substitute NOUN NN
# for ADP IN
# principled VERB VBN
# American ADJ JJ
# leadership NOUN NN
# . PUNCT .
# Since SCONJ IN
# the DET DT
# end NOUN NN
# of ADP IN
# World PROPN NNP
# War PROPN NNP
# II PROPN NNP
# , PUNCT ,
# the DET DT
# United PROPN NNP
# States PROPN NNP
# , PUNCT ,
# through ADP IN
# the DET DT
# founding NOUN NN
# of ADP IN
# the DET DT
# United PROPN NNP
# Nations PROPN NNP
# and CCONJ CC
# NATO PROPN NNP
# , PUNCT ,
# has AUX VBZ
# participated VERB VBN
# in ADP IN
# a DET DT
# number NOUN NN
# of ADP IN
# international ADJ JJ
# organizations NOUN NNS
# which PRON WDT
# can AUX MD
# , PUNCT ,
# but CCONJ CC
# sometimes ADV RB
# do AUX VBP
# not PART RB
# , PUNCT ,
# serve VERB VB
# the DET DT
# cause NOUN NN
# of ADP IN
# peace NOUN NN
# and CCONJ CC
# prosperity NOUN NN
# . PUNCT .
# While SCONJ IN
# acting VERB VBG
# through ADP IN
# them PRON PRP
# our PRON PRP$
# country NOUN NN
# must AUX MD
# always ADV RB
# reserve VERB VB
# the DET DT
# right NOUN NN
# to PART TO
# go VERB VB
# its PRON PRP$
# own ADJ JJ
# way NOUN NN
# . PUNCT .
# We PRON PRP
# must AUX MD
# not PART RB
# be AUX VB
# silent ADJ JJ
# about ADP IN
# our PRON PRP$
# country NOUN NN
# ’s PART POS
# cause NOUN NN
# . PUNCT .
# That PRON DT
# is AUX VBZ
# why SCONJ WRB
# we PRON PRP
# have AUX VBP
# long ADV RB
# supported VERB VBN
# our PRON PRP$
# country NOUN NN
# ’s PART POS
# international ADJ JJ
# broadcasting NOUN NN
# to ADP IN
# Eastern PROPN NNP
# Europe PROPN NNP
# , PUNCT ,
# the DET DT
# Middle PROPN NNP
# East PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Asia PROPN NNP
# . PUNCT .
#
#
#       SPACE _SP
# Our PRON PRP$
# continued ADJ JJ
# participation NOUN NN
# in ADP IN
# the DET DT
# United PROPN NNP
# Nations PROPN NNP
# should AUX MD
# be AUX VB
# contingent ADJ JJ
# upon SCONJ IN
# the DET DT
# enactment NOUN NN
# of ADP IN
# long ADJ JJ
# - PUNCT HYPH
# overdue ADJ JJ
# changes NOUN NNS
# in ADP IN
# the DET DT
# way NOUN NN
# that PRON WDT
# institution NOUN NN
# functions NOUN NNS
# . PUNCT .
# American ADJ JJ
# taxpayers NOUN NNS
# , PUNCT ,
# the DET DT
# chief ADJ JJ
# funders NOUN NNS
# of ADP IN
# the DET DT
# U.N. PROPN NNP
# , PUNCT ,
# deserve VERB VBP
# full ADJ JJ
# transparency NOUN NN
# in ADP IN
# the DET DT
# financial ADJ JJ
#
#
#  SPACE _SP
# operations NOUN NNS
# of ADP IN
# its PRON PRP$
# overpaid VERB VBN
# bureaucrats NOUN NNS
# . PUNCT .
# We PRON PRP
# should AUX MD
# no ADV RB
# longer ADV RB
# tolerate VERB VB
# its PRON PRP$
# managerial ADJ JJ
# scandals NOUN NNS
# , PUNCT ,
# its PRON PRP$
# Human PROPN NNP
# Rights PROPN NNPS
# Council PROPN NNP
# composed VERB VBN
# of ADP IN
# some PRON DT
# of ADP IN
# the DET DT
# world NOUN NN
# ’s PART POS
# worst ADJ JJS
# tyrants NOUN NNS
# , PUNCT ,
# and CCONJ CC
# its PRON PRP$
# treatment NOUN NN
# of ADP IN
# Israel PROPN NNP
# as ADP IN
# a DET DT
# pariah NOUN NN
# state NOUN NN
# . PUNCT .
# The DET DT
# U.N. PROPN NNP
# ’s PART POS
# Population PROPN NNP
# Fund PROPN NNP
# has AUX VBZ
# , PUNCT ,
# from ADP IN
# its PRON PRP$
# origin NOUN NN
# , PUNCT ,
# been AUX VBN
# rooted VERB VBN
# in ADP IN
# no DET DT
# - PUNCT HYPH
# growth NOUN NN
# policies NOUN NNS
# that PRON WDT
# limit VERB VBP
# economic ADJ JJ
# development NOUN NN
# in ADP IN
# the DET DT
# countries NOUN NNS
# needing VERB VBG
# it PRON PRP
# most ADV RBS
# . PUNCT .
# Its PRON PRP$
# complicity NOUN NN
# in ADP IN
# China PROPN NNP
# ’s PART POS
# barbaric ADJ JJ
# program NOUN NN
# of ADP IN
# forced ADJ JJ
# abortion NOUN NN
# led VERB VBD
# President PROPN NNP
# Reagan PROPN NNP
# to PART TO
# set VERB VB
# a DET DT
# wall NOUN NN
# of ADP IN
# separation NOUN NN
# — PUNCT :
# his PRON PRP$
# Mexico PROPN NNP
# City PROPN NNP
# Policy PROPN NNP
# , PUNCT ,
# which PRON WDT
# prohibits VERB VBZ
# the DET DT
# granting NOUN NN
# of ADP IN
# federal ADJ JJ
# monies NOUN NNS
# to ADP IN
# non ADJ JJ
# - ADJ JJ
# governmental ADJ JJ
# organizations NOUN NNS
# that PRON WDT
# provide VERB VBP
# or CCONJ CC
# promote VERB VB
# abortion NOUN NN
# . PUNCT .
# We PRON PRP
# affirm VERB VBP
# his PRON PRP$
# position NOUN NN
# and CCONJ CC
# , PUNCT ,
# in ADP IN
# light NOUN NN
# of ADP IN
# plummeting VERB VBG
# birth NOUN NN
# rates NOUN NNS
# around ADP IN
# the DET DT
# world NOUN NN
# , PUNCT ,
# suggest VERB VBP
# a DET DT
# reevaluation NOUN NN
# of ADP IN
# the DET DT
# U.N. PROPN NNP
# ’s PART POS
# record NOUN NN
# on ADP IN
# economic ADJ JJ
# progress NOUN NN
# . PUNCT .
#
#
#       SPACE _SP
# Precisely ADV RB
# because SCONJ IN
# we PRON PRP
# take VERB VBP
# our PRON PRP$
# country NOUN NN
# ’s PART POS
# treaty NOUN NN
# obligations NOUN NNS
# seriously ADV RB
# , PUNCT ,
# we PRON PRP
# oppose VERB VBP
# ratification NOUN NN
# of ADP IN
# international ADJ JJ
# agreements NOUN NNS
# whose DET WP$
# long ADJ JJ
# - PUNCT HYPH
# range NOUN NN
# implications NOUN NNS
# are AUX VBP
# ominous ADJ JJ
# or CCONJ CC
# unclear ADJ JJ
# . PUNCT .
# We PRON PRP
# do AUX VBP
# not PART RB
# support VERB VB
# the DET DT
# U.N. PROPN NNP
# Convention PROPN NNP
# on ADP IN
# Women PROPN NNP
# ’s PART POS
# Rights PROPN NNPS
# , PUNCT ,
# the DET DT
# Convention PROPN NNP
# on ADP IN
# the DET DT
# Rights PROPN NNPS
# of ADP IN
# the DET DT
# Child NOUN NN
# , PUNCT ,
# the DET DT
# Convention PROPN NNP
# on ADP IN
# the DET DT
# Rights PROPN NNPS
# of ADP IN
# Persons PROPN NNPS
# with ADP IN
# Disabilities NOUN NNS
# , PUNCT ,
# and CCONJ CC
# the DET DT
# U.N. PROPN NNP
# Arms PROPN NNP
# Trade PROPN NNP
# Treaty PROPN NNP
# , PUNCT ,
# as ADV RB
# well ADV RB
# as ADP IN
# various ADJ JJ
# declarations NOUN NNS
# from ADP IN
# the DET DT
# U.N. PROPN NNP
# Conference PROPN NNP
# on ADP IN
# Environment PROPN NNP
# and CCONJ CC
# Development PROPN NNP
# . PUNCT .
# Because SCONJ IN
# of ADP IN
# our PRON PRP$
# concern NOUN NN
# for ADP IN
# American ADJ JJ
# sovereignty NOUN NN
# , PUNCT ,
# domestic ADJ JJ
# management NOUN NN
# of ADP IN
# our PRON PRP$
# fisheries NOUN NNS
# , PUNCT ,
# and CCONJ CC
# our PRON PRP$
# country NOUN NN
# ’s PART POS
# long ADJ JJ
# - PUNCT HYPH
# term NOUN NN
# energy NOUN NN
# needs NOUN NNS
# , PUNCT ,
# we PRON PRP
# have VERB VBP
# deep ADJ JJ
# reservations NOUN NNS
# about ADP IN
# the DET DT
# regulatory ADJ JJ
# , PUNCT ,
# legal ADJ JJ
# , PUNCT ,
# and CCONJ CC
# tax NOUN NN
# regimes NOUN NNS
# inherent ADJ JJ
# in ADP IN
# the DET DT
# Law PROPN NNP
# of ADP IN
# the DET DT
# Sea PROPN NNP
# Treaty PROPN NNP
# . PUNCT .
# We PRON PRP
# emphatically ADV RB
# reject VERB VBP
# U.N. PROPN NNP
# Agenda PROPN NNP
# 21 NUM CD
# as ADP IN
# erosive ADJ JJ
# of ADP IN
# U.S. PROPN NNP
# sovereignty NOUN NN
# , PUNCT ,
# and CCONJ CC
# we PRON PRP
# oppose VERB VBP
# any DET DT
# form NOUN NN
# of ADP IN
# Global PROPN NNP
# Tax PROPN NNP
# . PUNCT .
#
#
#       SPACE _SP
# To PART TO
# shield VERB VB
# members NOUN NNS
# of ADP IN
# our PRON PRP$
# Armed PROPN NNP
# Forces PROPN NNPS
# and CCONJ CC
# others NOUN NNS
# in ADP IN
# service NOUN NN
# to ADP IN
# America PROPN NNP
# from ADP IN
# ideological ADJ JJ
# prosecutions NOUN NNS
# overseas ADV RB
# , PUNCT ,
# the DET DT
# Republican PROPN NNP
# Party PROPN NNP
# does AUX VBZ
# not PART RB
# accept VERB VB
# the DET DT
# jurisdiction NOUN NN
# of ADP IN
# the DET DT
# International PROPN NNP
# Criminal PROPN NNP
# Court PROPN NNP
# . PUNCT .
# We PRON PRP
# support VERB VBP
# statutory ADJ JJ
# protection NOUN NN
# for ADP IN
# U.S. PROPN NNP
# personnel NOUN NNS
# and CCONJ CC
# officials NOUN NNS
# as SCONJ IN
# they PRON PRP
# act VERB VBP
# abroad ADV RB
# to PART TO
# meet VERB VB
# our PRON PRP$
# global ADJ JJ
# security NOUN NN
# requirements NOUN NNS
# , PUNCT ,
# and CCONJ CC
# we PRON PRP
# deplore VERB VBP
# the DET DT
# current ADJ JJ
# inaction NOUN NN
# of ADP IN
# the DET DT
# Administration PROPN NNP
# in ADP IN
# that DET DT
# regard NOUN NN
# . PUNCT .
# Our PRON PRP$
# service NOUN NN
# members NOUN NNS
# must AUX MD
# be AUX VB
# subject ADJ JJ
# only ADV RB
# to ADP IN
# American ADJ JJ
# law NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# Defending VERB VBG
# International PROPN NNP
# Religious PROPN NNP
# Freedom PROPN NNP
#
#
#       SPACE _SP
# The DET DT
# U.S. PROPN NNP
# Commission PROPN NNP
# on ADP IN
# International PROPN NNP
# Religious PROPN NNP
# Freedom PROPN NNP
# , PUNCT ,
# an DET DT
# initiative NOUN NN
# of ADP IN
# Congressional PROPN NNP
# Republicans PROPN NNPS
# , PUNCT ,
# has AUX VBZ
# been AUX VBN
# neglected VERB VBN
# by ADP IN
# the DET DT
# current ADJ JJ
#
#  SPACE _SP
# Administration PROPN NNP
# at ADP IN
# a DET DT
# time NOUN NN
# when SCONJ WRB
# its PRON PRP$
# voice NOUN NN
# more ADV RBR
# than ADP IN
# ever ADV RB
# needs VERB VBZ
# to PART TO
# be AUX VB
# heard VERB VBN
# . PUNCT .
# Religious ADJ JJ
# minorities NOUN NNS
# across ADP IN
# the DET DT
# Middle PROPN NNP
# East PROPN NNP
# have AUX VBP
# been AUX VBN
# driven VERB VBN
# from ADP IN
# their PRON PRP$
# ancient ADJ JJ
# homelands NOUN NNS
# , PUNCT ,
# and CCONJ CC
# thousands NOUN NNS
# , PUNCT ,
# there ADV RB
# and CCONJ CC
# in ADP IN
# Africa PROPN NNP
# , PUNCT ,
# have AUX VBP
# been AUX VBN
# slaughtered VERB VBN
# for ADP IN
# their PRON PRP$
# faith NOUN NN
# in ADP IN
# what PRON WP
# the DET DT
# State PROPN NNP
# Department PROPN NNP
# has AUX VBZ
# , PUNCT ,
# belatedly ADV RB
# , PUNCT ,
# labeled VERB VBN
# genocide NOUN NN
# . PUNCT .
# The DET DT
# United PROPN NNP
# States PROPN NNP
# must AUX MD
# stand VERB VB
# with ADP IN
# leaders NOUN NNS
# , PUNCT ,
# like ADP IN
# President PROPN NNP
# Sisi PROPN NNP
# of ADP IN
# Egypt PROPN NNP
# who PRON WP
# has AUX VBZ
# bravely ADV RB
# protected VERB VBN
# the DET DT
# rights NOUN NNS
# of ADP IN
# Coptic PROPN NNP
# Christians PROPN NNPS
# in ADP IN
# Egypt PROPN NNP
# , PUNCT ,
# and CCONJ CC
# call VERB VB
# on ADP RP
# other ADJ JJ
# leaders NOUN NNS
# across ADP IN
# the DET DT
# region NOUN NN
# to PART TO
# ensure VERB VB
# that SCONJ IN
# all DET DT
# religious ADJ JJ
# minorities NOUN NNS
# , PUNCT ,
# whether SCONJ IN
# Yazidi PROPN NNP
# , PUNCT ,
# Bahai PROPN NNP
# , PUNCT ,
# Orthodox PROPN NNP
# , PUNCT ,
# Catholic ADJ JJ
# or CCONJ CC
# Protestant PROPN NNP
# Christians PROPN NNPS
# , PUNCT ,
# are AUX VBP
# free ADJ JJ
# to PART TO
# practice VERB VB
# their PRON PRP$
# religion NOUN NN
# without ADP IN
# fear NOUN NN
# of ADP IN
# persecution NOUN NN
# . PUNCT .
# At ADP IN
# a DET DT
# time NOUN NN
# when SCONJ WRB
# China PROPN NNP
# has AUX VBZ
# renewed VERB VBN
# its PRON PRP$
# destruction NOUN NN
# of ADP IN
# churches NOUN NNS
# , PUNCT ,
# Christian ADJ JJ
# home NOUN NN
# - PUNCT HYPH
# schooling NOUN NN
# parents NOUN NNS
# are AUX VBP
# jailed VERB VBN
# in ADP IN
# parts NOUN NNS
# of ADP IN
# Europe PROPN NNP
# , PUNCT ,
# and CCONJ CC
# even ADV RB
# Canada PROPN NNP
# threatens VERB VBZ
# pastors NOUN NNS
# for ADP IN
# their PRON PRP$
# preaching NOUN NN
# , PUNCT ,
# a DET DT
# Republican ADJ JJ
# administration NOUN NN
# will AUX MD
# return VERB VB
# the DET DT
# advocacy NOUN NN
# of ADP IN
# religious ADJ JJ
# liberty NOUN NN
# to ADP IN
# a DET DT
# central ADJ JJ
# place NOUN NN
# in ADP IN
# its PRON PRP$
# diplomacy NOUN NN
# , PUNCT ,
# will AUX MD
# quickly ADV RB
# designate VERB VB
# the DET DT
# systematic ADJ JJ
# killing NOUN NN
# of ADP IN
# religious ADJ JJ
# and CCONJ CC
# ethnic ADJ JJ
# minorities NOUN NNS
# a DET DT
# genocide NOUN NN
# , PUNCT ,
# and CCONJ CC
# will AUX MD
# work VERB VB
# with ADP IN
# the DET DT
# leaders NOUN NNS
# of ADP IN
# other ADJ JJ
# nations NOUN NNS
# to PART TO
# condemn VERB VB
# and CCONJ CC
# combat NOUN NN
# genocidal ADJ JJ
# acts NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# America PROPN NNP
# ’s PART POS
# Generosity PROPN NNP
# : PUNCT :
# International PROPN NNP
# Assistance PROPN NNP
# that PRON WDT
# Makes VERB VBZ
# a DET DT
# Difference NOUN NN
#
#
#       SPACE _SP
# Foreign ADJ JJ
# aid NOUN NN
# must AUX MD
# serve VERB VB
# America PROPN NNP
# ’s PART POS
# interests NOUN NNS
# first ADV RB
# . PUNCT .
# In ADP IN
# today NOUN NN
# ’s PART POS
# world NOUN NN
# of ADP IN
# complex ADJ JJ
# challenges NOUN NNS
# , PUNCT ,
# international ADJ JJ
# assistance NOUN NN
# is AUX VBZ
# a DET DT
# critical ADJ JJ
# tool NOUN NN
# for ADP IN
# advancing VERB VBG
# America PROPN NNP
# ’s PART POS
# security NOUN NN
# and CCONJ CC
# economic ADJ JJ
# interests NOUN NNS
# by ADP IN
# preventing VERB VBG
# conflict NOUN NN
# , PUNCT ,
# building VERB VBG
# stability NOUN NN
# , PUNCT ,
# opening VERB VBG
# markets NOUN NNS
# for ADP IN
# private ADJ JJ
# investment NOUN NN
# , PUNCT ,
# and CCONJ CC
# responding VERB VBG
# to ADP IN
# suffering NOUN NN
# and CCONJ CC
# need VERB VB
# with ADP IN
# the DET DT
# compassion NOUN NN
# that PRON WDT
# is AUX VBZ
# at ADP IN
# the DET DT
# heart NOUN NN
# of ADP IN
# our PRON PRP$
# country NOUN NN
# ’s PART POS
# values NOUN NNS
# . PUNCT .
# A DET DT
# strong ADJ JJ
# commitment NOUN NN
# to ADP IN
# international ADJ JJ
# development NOUN NN
# and CCONJ CC
# diplomacy NOUN NN
# , PUNCT ,
# alongside ADP IN
# defense NOUN NN
# , PUNCT ,
# was AUX VBD
# a DET DT
# key ADJ JJ
# component NOUN NN
# of ADP IN
# President PROPN NNP
# Reagan PROPN NNP
# ’s PART POS
# “ PUNCT ``
# peace NOUN NN
# through ADP IN
# strength NOUN NN
# ” PUNCT ''
# strategy NOUN NN
# . PUNCT .
# It PRON PRP
# can AUX MD
# sometimes ADV RB
# serve VERB VB
# as ADP IN
# an DET DT
# alternative ADJ JJ
# means NOUN NNS
# of ADP IN
# keeping VERB VBG
# the DET DT
# peace NOUN NN
# , PUNCT ,
# far ADV RB
# less ADV RBR
# costly ADJ JJ
# both CCONJ CC
# in ADP IN
# dollars NOUN NNS
# and CCONJ CC
# in ADP IN
# human ADJ JJ
# lives NOUN NNS
# than ADP IN
# military ADJ JJ
# engagement NOUN NN
# . PUNCT .
# The DET DT
# Millennium PROPN NNP
# Challenge PROPN NNP
# Corporation PROPN NNP
# , PUNCT ,
# spearheaded VERB VBN
# by ADP IN
# the DET DT
# last ADJ JJ
# Republican PROPN NNP
# Administration PROPN NNP
# , PUNCT ,
# has AUX VBZ
# established VERB VBN
# a DET DT
# new ADJ JJ
# model NOUN NN
# of ADP IN
# foreign ADJ JJ
# assistance NOUN NN
# that PRON WDT
# helps VERB VBZ
# ensure VERB VB
# taxpayer NOUN NN
# dollars NOUN NNS
# are AUX VBP
# spent VERB VBN
# on ADP IN
# projects NOUN NNS
# that PRON WDT
# are AUX VBP
# effective ADJ JJ
# , PUNCT ,
# results NOUN NNS
# - PUNCT HYPH
# driven VERB VBN
# , PUNCT ,
# transparent ADJ JJ
# , PUNCT ,
# and CCONJ CC
# accountable ADJ JJ
# . PUNCT .
# We PRON PRP
# must AUX MD
# embrace VERB VB
# this DET DT
# model NOUN NN
# throughout ADP IN
# our PRON PRP$
# foreign ADJ JJ
# assistance NOUN NN
# programs NOUN NNS
# and CCONJ CC
# efforts NOUN NNS
# as ADP IN
# a DET DT
# catalyst NOUN NN
# for ADP IN
# private ADJ JJ
# sector NOUN NN
# investment NOUN NN
# to PART TO
# combat NOUN NN
# corruption NOUN NN
# , PUNCT ,
# strengthen VERB VB
# the DET DT
# rule NOUN NN
# of ADP IN
# law NOUN NN
# , PUNCT ,
# and CCONJ CC
# open VERB VB
# new ADJ JJ
# markets NOUN NNS
#
#
#  SPACE _SP
# for ADP IN
# American ADJ JJ
# goods NOUN NNS
# and CCONJ CC
# services NOUN NNS
# in ADP IN
# a DET DT
# competitive ADJ JJ
# global ADJ JJ
# economy NOUN NN
# . PUNCT .
# Foreign ADJ JJ
# assistance NOUN NN
# programs NOUN NNS
# must AUX MD
# not PART RB
# only ADV RB
# project VERB VB
# the DET DT
# best ADJ JJS
# of ADP IN
# American ADJ JJ
# values NOUN NNS
# , PUNCT ,
# but CCONJ CC
# must AUX MD
# work VERB VB
# to PART TO
# create VERB VB
# self NOUN NN
# - PUNCT HYPH
# sustainability NOUN NN
# and CCONJ CC
# leverage VERB VB
# the DET DT
# resources NOUN NNS
# and CCONJ CC
# capacity NOUN NN
# of ADP IN
# the DET DT
# private ADJ JJ
# sector NOUN NN
# . PUNCT .
# Even ADV RB
# more ADV RBR
# important ADJ JJ
# is AUX VBZ
# the DET DT
# overseas ADJ JJ
# assistance NOUN NN
# -billions NOUN NNS
# of ADP IN
# dollars NOUN NNS
# and CCONJ CC
# volunteer NOUN NN
# hours NOUN NNS
# — PUNCT :
# provided VERB VBN
# by ADP IN
# America PROPN NNP
# ’s PART POS
# foundations NOUN NNS
# , PUNCT ,
# educational ADJ JJ
# institutions NOUN NNS
# , PUNCT ,
# faith NOUN NN
# - PUNCT HYPH
# based VERB VBN
# groups NOUN NNS
# , PUNCT ,
# and CCONJ CC
# charitable ADJ JJ
# individuals NOUN NNS
# . PUNCT .
# Their PRON PRP$
# essential ADJ JJ
# role NOUN NN
# in ADP IN
# international ADJ JJ
# development NOUN NN
# should AUX MD
# be AUX VB
# weighed VERB VBN
# in ADP IN
# any DET DT
# revision NOUN NN
# of ADP IN
# the DET DT
# tax NOUN NN
# code NOUN NN
# . PUNCT .
#
#
#       SPACE _SP
# The DET DT
# advance NOUN NN
# of ADP IN
# political ADJ JJ
# freedom NOUN NN
# and CCONJ CC
# entrepreneurial ADJ JJ
# capitalism NOUN NN
# drives VERB VBZ
# economic ADJ JJ
# growth NOUN NN
# , PUNCT ,
# catalyzes VERB VBZ
# private ADJ JJ
# sector NOUN NN
# development NOUN NN
# , PUNCT ,
# and CCONJ CC
# is AUX VBZ
# the DET DT
# only ADJ JJ
# sustainable ADJ JJ
# solution NOUN NN
# to ADP IN
# poverty NOUN NN
# . PUNCT .
# Over ADP IN
# the DET DT
# last ADJ JJ
# 50 NUM CD
# years NOUN NNS
# , PUNCT ,
# the DET DT
# level NOUN NN
# of ADP IN
# private ADJ JJ
# investment NOUN NN
# overseas ADV RB
# from ADP IN
# the DET DT
# United PROPN NNP
# States PROPN NNP
# has AUX VBZ
# eclipsed VERB VBN
# aid NOUN NN
# many ADJ JJ
# times NOUN NNS
# over ADV RB
# . PUNCT .
# Our PRON PRP$
# development NOUN NN
# strategy NOUN NN
# must AUX MD
# build VERB VB
# on ADP IN
# recent ADJ JJ
# Republican ADJ JJ
# efforts NOUN NNS
# to PART TO
# use VERB VB
# foreign ADJ JJ
# assistance NOUN NN
# to PART TO
# catalyze VERB VB
# private ADJ JJ
# sector NOUN NN
# investment NOUN NN
# and CCONJ CC
# expertise NOUN NN
# in ADP IN
# addressing VERB VBG
# global ADJ JJ
# challenges NOUN NNS
# that PRON WDT
# can AUX MD
# build VERB VB
# a DET DT
# more ADV RBR
# stable ADJ JJ
# world NOUN NN
# and CCONJ CC
# advance VERB VB
# America PROPN NNP
# ’s PART POS
# national ADJ JJ
# security NOUN NN
# and CCONJ CC
# economic ADJ JJ
# interests NOUN NNS
# . PUNCT .
#
#
#       SPACE _SP
# The DET DT
# integrity NOUN NN
# of ADP IN
# our PRON PRP$
# country NOUN NN
# ’s PART POS
# foreign ADJ JJ
# assistance NOUN NN
# program NOUN NN
# has AUX VBZ
# been AUX VBN
# compromised VERB VBN
# by ADP IN
# the DET DT
# current ADJ JJ
# Administration PROPN NNP
# ’s NOUN NN
# attempt NOUN NN
# to PART TO
# impose VERB VB
# on ADP IN
# foreign ADJ JJ
# recipients NOUN NNS
# , PUNCT ,
# especially ADV RB
# the DET DT
# peoples NOUN NNS
# of ADP IN
# Africa PROPN NNP
# , PUNCT ,
# its PRON PRP$
# own ADJ JJ
# radical ADJ JJ
# social ADJ JJ
# agenda NOUN NN
# while SCONJ IN
# excluding VERB VBG
# faith NOUN NN
# - PUNCT HYPH
# based VERB VBN
# groups NOUN NNS
# — PUNCT :
# the DET DT
# sector NOUN NN
# with ADP IN
# the DET DT
# best ADJ JJS
# track NOUN NN
# record NOUN NN
# in ADP IN
# promoting VERB VBG
# development NOUN NN
# - PUNCT :
# because SCONJ IN
# they PRON PRP
# will AUX MD
# not PART RB
# conform VERB VB
# to ADP IN
# that DET DT
# agenda NOUN NN
# . PUNCT .
# We PRON PRP
# pledge VERB VBP
# to PART TO
# reverse VERB VB
# this DET DT
# course NOUN NN
# , PUNCT ,
# encouraging VERB VBG
# more ADJ JJR
# involvement NOUN NN
# by ADP IN
# the DET DT
# most ADV RBS
# effective ADJ JJ
# aid NOUN NN
# organizations NOUN NNS
# and CCONJ CC
# trusting VERB VBG
# developing VERB VBG
# peoples NOUN NNS
# to PART TO
# build VERB VB
# their PRON PRP$
# futures NOUN NNS
# through ADP IN
# their PRON PRP$
# own ADJ JJ
# values NOUN NNS
# . PUNCT .
#
#
#  SPACE _SP
# Advancing VERB VBG
# Human PROPN NNP
# Rights PROPN NNPS
#
#
#       SPACE _SP
# To ADP IN
# those PRON DT
# who PRON WP
# stand VERB VBP
# in ADP IN
# the DET DT
# darkness NOUN NN
# of ADP IN
# tyranny NOUN NN
# , PUNCT ,
# America PROPN NNP
# has AUX VBZ
# always ADV RB
# been AUX VBN
# a DET DT
# beacon NOUN NN
# of ADP IN
# hope NOUN NN
# , PUNCT ,
# and CCONJ CC
# so ADV RB
# it PRON PRP
# must AUX MD
# remain VERB VB
# . PUNCT .
# Radical ADJ JJ
# Islamic ADJ JJ
# terrorism NOUN NN
# poses VERB VBZ
# an DET DT
# existential ADJ JJ
# threat NOUN NN
# to ADP IN
# personal ADJ JJ
# freedom NOUN NN
# and CCONJ CC
# peace NOUN NN
# around ADP IN
# the DET DT
# world NOUN NN
# . PUNCT .
# We PRON PRP
# oppose VERB VBP
# its PRON PRP$
# brutal ADJ JJ
# assault NOUN NN
# on ADP IN
# all DET DT
# human ADJ JJ
# beings NOUN NNS
# , PUNCT ,
# all PRON DT
# of ADP IN
# whom PRON WP
# have VERB VBP
# inherent ADJ JJ
# dignity NOUN NN
# . PUNCT .
# The DET DT
# Republican PROPN NNP
# Party PROPN NNP
# stands VERB VBZ
# united ADJ JJ
# with ADP IN
# all DET DT
# victims NOUN NNS
# of ADP IN
# terrorism NOUN NN
# and CCONJ CC
# will AUX MD
# fight VERB VB
# at ADP IN
# home NOUN NN
# and CCONJ CC
# abroad ADV RB
# to PART TO
# destroy VERB VB
# terrorist ADJ JJ
# organizations NOUN NNS
# and CCONJ CC
# protect VERB VB
# the DET DT
# lives NOUN NNS
# and CCONJ CC
# fundamental ADJ JJ
# liberties NOUN NNS
# of ADP IN
# all DET DT
# people NOUN NNS
# . PUNCT .
# Republicans PROPN NNPS
# have AUX VBP
# led VERB VBN
# the DET DT
# way NOUN NN
# in ADP IN
# promoting VERB VBG
# initiatives NOUN NNS
# that PRON WDT
# have AUX VBP
# protected VERB VBN
# and CCONJ CC
# rescued VERB VBD
# millions NOUN NNS
# of ADP IN
# the DET DT
# world NOUN NN
# ’s SPACE _SP
#
#  SPACE _SP
# most ADV RBS
# vulnerable ADJ JJ
# and CCONJ CC
# persecuted VERB VBN
# . PUNCT .
# Standing VERB VBG
# up ADP RP
# for ADP IN
# repressed ADJ JJ
# religious ADJ JJ
# groups NOUN NNS
# , PUNCT ,
# prisoners NOUN NNS
# of ADP IN
# conscience NOUN NN
# , PUNCT ,
# women NOUN NNS
# trafficked VERB VBD
# into ADP IN
# sexual ADJ JJ
# slavery NOUN NN
# , PUNCT ,
# and CCONJ CC
# those PRON DT
# suffering VERB VBG
# from ADP IN
# disease NOUN NN
# or CCONJ CC
# starvation NOUN NN
# is AUX VBZ
# not PART RB
# just ADV RB
# consistent ADJ JJ
# with ADP IN
# American ADJ JJ
# values NOUN NNS
# . PUNCT .
# It PRON PRP
# advances VERB VBZ
# important ADJ JJ
# security NOUN NN
# and CCONJ CC
# economic ADJ JJ
# interests NOUN NNS
# as ADV RB
# well ADV RB
# . PUNCT .
# A DET DT
# Republican ADJ JJ
# administration NOUN NN
# will AUX MD
# never ADV RB
# say VERB VB
# , PUNCT ,
# as SCONJ IN
# Hillary PROPN NNP
# Clinton PROPN NNP
# did VERB VBD
# as ADP IN
# Secretary PROPN NNP
# of ADP IN
# State PROPN NNP
# in ADP IN
# 2009 NUM CD
# , PUNCT ,
# that SCONJ IN
# raising VERB VBG
# human ADJ JJ
# rights NOUN NNS
# concerns NOUN NNS
# “ PUNCT ``
# ca AUX MD
# n’t PART RB
# interfere VERB VB
# with ADP IN
# the DET DT
# global ADJ JJ
# economic ADJ JJ
# crisis NOUN NN
# , PUNCT ,
# the DET DT
# global ADJ JJ
# climate NOUN NN
# change NOUN NN
# crisis NOUN NN
# , PUNCT ,
# and CCONJ CC
# the DET DT
# security NOUN NN
# crisis NOUN NN
# . PUNCT .
# ” PUNCT ''
#
#
#      SPACE _SP
# The DET DT
# United PROPN NNP
# States PROPN NNP
# needs VERB VBZ
# a DET DT
# radical ADJ JJ
# rethinking NOUN NN
# of ADP IN
# our PRON PRP$
# human ADJ JJ
# rights NOUN NNS
# diplomacy NOUN NN
# . PUNCT .
# A DET DT
# Republican ADJ JJ
# administration NOUN NN
# will AUX MD
# adopt VERB VB
# a DET DT
# “ PUNCT ``
# whole ADJ JJ
# of ADP IN
# government NOUN NN
# ” PUNCT ''
# approach NOUN NN
# to PART TO
# protect VERB VB
# fundamental ADJ JJ
# freedoms NOUN NNS
# globally ADV RB
# , PUNCT ,
# one NUM CD
# where SCONJ WRB
# pressing VERB VBG
# human ADJ JJ
# rights NOUN NNS
# and CCONJ CC
# rule NOUN NN
# of ADP IN
# law NOUN NN
# issues NOUN NNS
# are AUX VBP
# integrated VERB VBN
# at ADP IN
# every DET DT
# appropriate ADJ JJ
# level NOUN NN
# of ADP IN
# our PRON PRP$
# bilateral ADJ JJ
# relationships NOUN NNS
# and CCONJ CC
# strategic ADJ JJ
# decisionmaking NOUN NN
# . PUNCT .
# Republican ADJ JJ
# policy NOUN NN
# will AUX MD
# reflect VERB VB
# the DET DT
# fact NOUN NN
# that SCONJ IN
# the DET DT
# health NOUN NN
# of ADP IN
# the DET DT
# U.S. PROPN NNP
# economy NOUN NN
# and CCONJ CC
# environment NOUN NN
# , PUNCT ,
# the DET DT
# safety NOUN NN
# of ADP IN
# our PRON PRP$
# food NOUN NN
# and CCONJ CC
# drug NOUN NN
# supplies NOUN NNS
# , PUNCT ,
# the DET DT
# security NOUN NN
# of ADP IN
# our PRON PRP$
# investments NOUN NNS
# and CCONJ CC
# personal ADJ JJ
# information NOUN NN
# in ADP IN
# cyberspace NOUN NN
# , PUNCT ,
# and CCONJ CC
# the DET DT
# stability NOUN NN
# and CCONJ CC
# security NOUN NN
# of ADP IN
# the DET DT
# oceans NOUN NNS
# will AUX MD
# increasingly ADV RB
# depend VERB VB
# on ADP IN
# allowing VERB VBG
# the DET DT
# free ADJ JJ
# flow NOUN NN
# of ADP IN
# news NOUN NN
# and CCONJ CC
# information NOUN NN
# and CCONJ CC
# developing VERB VBG
# an DET DT
# independent ADJ JJ
# judiciary NOUN NN
# and CCONJ CC
# civil ADJ JJ
# society NOUN NN
# in ADP IN
# countries NOUN NNS
# with ADP IN
# repressive ADJ JJ
# governments NOUN NNS
# such ADJ JJ
# as ADP IN
# China PROPN NNP
# , PUNCT ,
# Russia PROPN NNP
# , PUNCT ,
# and CCONJ CC
# many ADJ JJ
# nations NOUN NNS
# in ADP IN
# the DET DT
# Middle PROPN NNP
# East PROPN NNP
# and CCONJ CC
# Africa PROPN NNP
# . PUNCT .
#
#
#  SPACE _SP
# Liberty PROPN NNP
# to ADP IN
# Captives NOUN NNS
# : PUNCT :
#
#
#  SPACE _SP
# Combatting VERB VBG
# Human ADJ JJ
# Trafficking NOUN NN
#
#
#      SPACE _SP
# As SCONJ IN
# an DET DT
# estimated VERB VBN
# 21 NUM CD
# million NUM CD
# people NOUN NNS
# worldwide ADV RB
# are AUX VBP
# trapped VERB VBN
# in ADP IN
# modern ADJ JJ
# day NOUN NN
# slavery NOUN NN
# , PUNCT ,
# we PRON PRP
# are AUX VBP
# reminded VERB VBN
# to PART TO
# be AUX VB
# vigilant ADJ JJ
# against ADP IN
# human ADJ JJ
# trafficking NOUN NN
# in ADP IN
# whatever DET WDT
# form NOUN NN
# it PRON PRP
# appears VERB VBZ
# . PUNCT .
# We PRON PRP
# will AUX MD
# use VERB VB
# the DET DT
# full ADJ JJ
# force NOUN NN
# of ADP IN
# the DET DT
# law NOUN NN
# against ADP IN
# those PRON DT
# who PRON WP
# engage VERB VBP
# in ADP IN
# commercial ADJ JJ
# sexual ADJ JJ
# exploitation NOUN NN
# and CCONJ CC
# forced VERB VBN
# or CCONJ CC
# bonded VERB VBN
# labor NOUN NN
# of ADP IN
# men NOUN NNS
# , PUNCT ,
# women NOUN NNS
# , PUNCT ,
# or CCONJ CC
# children NOUN NNS
# ; PUNCT :
# involuntary ADJ JJ
# domestic ADJ JJ
# servitude NOUN NN
# ; PUNCT :
# trafficking VERB VBG
# in ADP IN
# persons NOUN NNS
# for ADP IN
# the DET DT
# purpose NOUN NN
# of ADP IN
# organ NOUN NN
# removal NOUN NN
# ; PUNCT :
# and CCONJ CC
# the DET DT
# illegal ADJ JJ
# recruitment NOUN NN
# and CCONJ CC
# use NOUN NN
# of ADP IN
# child NOUN NN
# soldiers NOUN NNS
# . PUNCT .
# Building VERB VBG
# on ADP IN
# the DET DT
# accomplishments NOUN NNS
# of ADP IN
# the DET DT
# last ADJ JJ
# Republican ADJ JJ
# administration NOUN NN
# in ADP IN
# implementing VERB VBG
# the DET DT
# Trafficking VERB VBG
# Victims PROPN NNPS
# Protection PROPN NNP
# Act PROPN NNP
# of ADP IN
# 2000 NUM CD
# , PUNCT ,
# we PRON PRP
# call VERB VBP
# for ADP IN
# increased VERB VBN
# diplomatic ADJ JJ
# efforts NOUN NNS
# and CCONJ CC
# accountability NOUN NN
# for ADP IN
# foreign ADJ JJ
# governments NOUN NNS
# to PART TO
# prosecute VERB VB
# traffickers NOUN NNS
# , PUNCT ,
# including VERB VBG
# penalties NOUN NNS
# for ADP IN
# any DET DT
# public ADJ JJ
# officials NOUN NNS
# who PRON WP
# may AUX MD
# be AUX VB
# complicit ADJ JJ
# in ADP IN
# this DET DT
# devastating ADJ JJ
# crime NOUN NN
# . PUNCT .
# We PRON PRP
# will AUX MD
# highlight VERB VB
# the DET DT
# need NOUN NN
# to PART TO
# stop VERB VB
# slave NOUN NN
# labor NOUN NN
# , PUNCT ,
# taking VERB VBG
# steps NOUN NNS
#
#
#  SPACE _SP
# to PART TO
# prevent VERB VB
# overseas ADJ JJ
# labor NOUN NN
# contractors NOUN NNS
# who PRON WP
# exploit VERB VBP
# foreign ADJ JJ
# workers NOUN NNS
# from ADP IN
# supporting VERB VBG
# military ADJ JJ
# bases NOUN NNS
# abroad ADV RB
# or CCONJ CC
# exporting VERB VBG
# goods NOUN NNS
# to ADP IN
# the DET DT
# United PROPN NNP
# States PROPN NNP
# . PUNCT .
# A DET DT
# Republican ADJ JJ
# administration NOUN NN
# will AUX MD
# strategize VERB VB
# with ADP IN
# partners NOUN NNS
# around ADP IN
# the DET DT
# world NOUN NN
# to PART TO
# prevent VERB VB
# the DET DT
# demand NOUN NN
# for ADP IN
# trafficking VERB VBG
# victims NOUN NNS
# that PRON WDT
# makes VERB VBZ
# exploitation NOUN NN
# lucrative ADJ JJ
# and CCONJ CC
# will AUX MD
# prosecute VERB VB
# sex NOUN NN
# tourists NOUN NNS
# and CCONJ CC
# domestic ADJ JJ
# buyers NOUN NNS
# to ADP IN
# the DET DT
# fullest ADJ JJS
# extent NOUN NN
# of ADP IN
# the DET DT
# law NOUN NN
# . PUNCT .
# We PRON PRP
# will AUX MD
# work VERB VB
# at ADP IN
# home NOUN NN
# and CCONJ CC
# abroad ADV RB
# to PART TO
# ensure VERB VB
# that SCONJ IN
# trafficking VERB VBG
# victims NOUN NNS
# are AUX VBP
# identified VERB VBN
# among ADP IN
# migrants NOUN NNS
# , PUNCT ,
# refugees NOUN NNS
# , PUNCT ,
# and CCONJ CC
# our PRON PRP$
# own ADJ JJ
# citizens NOUN NNS
# so SCONJ IN
# they PRON PRP
# receive VERB VBP
# the DET DT
# rehabilitative ADJ JJ
# care NOUN NN
# needed VERB VBN
# to PART TO
# heal VERB VB
# and CCONJ CC
# thrive VERB VB
# . PUNCT .
#
#
#      SPACE _SP
# America PROPN NNP
# ’s PART POS
# continuing VERB VBG
# participation NOUN NN
# in ADP IN
# the DET DT
# international ADJ JJ
# campaign NOUN NN
# against ADP IN
# human ADJ JJ
# trafficking NOUN NN
# merits VERB VBZ
# our PRON PRP$
# support NOUN NN
# . PUNCT .
# The DET DT
# goal NOUN NN
# of ADP IN
# our PRON PRP$
# domestic ADJ JJ
# antitrafficking NOUN NN
# programs NOUN NNS
# should AUX MD
# be AUX VB
# the DET DT
# rescue NOUN NN
# and CCONJ CC
# safe ADJ JJ
# return NOUN NN
# of ADP IN
# victims NOUN NNS
# to ADP IN
# their PRON PRP$
# homes NOUN NNS
# , PUNCT ,
# not PART RB
# creating VERB VBG
# a DET DT
# longterm NOUN NN
# dependency NOUN NN
# upon SCONJ IN
# public ADJ JJ
# support NOUN NN
# . PUNCT .
# We PRON PRP
# call VERB VBP
# for ADP IN
# greater ADJ JJR
# scrutiny NOUN NN
# of ADP IN
# overseas ADJ JJ
# labor NOUN NN
# contractors NOUN NNS
# to PART TO
# prevent VERB VB
# abuses NOUN NNS
# against ADP IN
# temporary ADJ JJ
# foreign ADJ JJ
# workers NOUN NNS
# brought VERB VBD
# to ADP IN
# the DET DT
# United PROPN NNP
# States PROPN NNP
# . PUNCT .
# The DET DT
# horrific ADJ JJ
# deaths NOUN NNS
# of ADP IN
# smuggled ADJ JJ
# workers NOUN NNS
# on ADP IN
# our PRON PRP$
# southwestern ADJ JJ
# border NOUN NN
# at ADP IN
# the DET DT
# hands NOUN NNS
# of ADP IN
# drug NOUN NN
# cartels NOUN NNS
# and CCONJ CC
# other ADJ JJ
# gangs NOUN NNS
# highlight VERB VBP
# the DET DT
# need NOUN NN
# for ADP IN
# total ADJ JJ
# security NOUN NN
# in ADP IN
# that DET DT
# region NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# Facing VERB VBG
# 21st ADJ JJ
# Century PROPN NNP
# Threats PROPN NNPS
# : PUNCT :
#
#
#  SPACE _SP
# Cybersecurity NOUN NN
# in ADP IN
# an DET DT
# Insecure PROPN NNP
# World PROPN NNP
#
#
#      SPACE _SP
# Cyber PROPN NNP
# attacks VERB VBZ
# against ADP IN
# our PRON PRP$
# businesses NOUN NNS
# , PUNCT ,
# institutions NOUN NNS
# , PUNCT ,
# and CCONJ CC
# the DET DT
# government NOUN NN
# itself PRON PRP
# have AUX VBP
# become VERB VBN
# almost ADV RB
# routine ADJ JJ
# . PUNCT .
# They PRON PRP
# will AUX MD
# continue VERB VB
# until SCONJ IN
# the DET DT
# world NOUN NN
# understands VERB VBZ
# that SCONJ IN
# an DET DT
# attack NOUN NN
# will AUX MD
# not PART RB
# be AUX VB
# tolerated VERB VBN
# - PUNCT :
# that SCONJ IN
# we PRON PRP
# are AUX VBP
# prepared ADJ JJ
# to PART TO
# respond VERB VB
# in ADP IN
# kind NOUN NN
# and CCONJ CC
# in ADP IN
# greater ADJ JJR
# magnitude NOUN NN
# . PUNCT .
# Despite SCONJ IN
# their PRON PRP$
# promises NOUN NNS
# to ADP IN
# the DET DT
# contrary NOUN NN
# , PUNCT ,
# Russia PROPN NNP
# and CCONJ CC
# China PROPN NNP
# see VERB VBP
# cyber ADJ JJ
# operations NOUN NNS
# as ADP IN
# a DET DT
# part NOUN NN
# of ADP IN
# a DET DT
# warfare NOUN NN
# strategy NOUN NN
# during ADP IN
# peacetime NOUN NN
# . PUNCT .
# Our PRON PRP$
# response NOUN NN
# should AUX MD
# be AUX VB
# to PART TO
# cause VERB VB
# diplomatic ADJ JJ
# , PUNCT ,
# financial ADJ JJ
# , PUNCT ,
# and CCONJ CC
# legal ADJ JJ
# pain NOUN NN
# , PUNCT ,
# curtailing VERB VBG
# visas NOUN NNS
# for ADP IN
# guilty ADJ JJ
# parties NOUN NNS
# , PUNCT ,
# freezing VERB VBG
# their PRON PRP$
# assets NOUN NNS
# , PUNCT ,
# and CCONJ CC
# pursuing VERB VBG
# criminal ADJ JJ
# actions NOUN NNS
# against ADP IN
# them PRON PRP
# . PUNCT .
# We PRON PRP
# should AUX MD
# seek VERB VB
# to PART TO
# weaken VERB VB
# control NOUN NN
# over ADP IN
# the DET DT
# internet NOUN NN
# by ADP IN
# regimes NOUN NNS
# that PRON WDT
# engage VERB VBP
# in ADP IN
# cyber PROPN NNP
# crimes NOUN NNS
# . PUNCT .
# We PRON PRP
# must AUX MD
# stop VERB VB
# playing VERB VBG
# defense NOUN NN
# and CCONJ CC
# go VERB VB
# on ADP IN
# offense NOUN NN
# to PART TO
# avoid VERB VB
# the DET DT
# cyber NOUN NN
# - PUNCT HYPH
# equivalent NOUN NN
# of ADP IN
# Pearl PROPN NNP
# Harbor PROPN NNP
# . PUNCT .
#
#
#      SPACE _SP
# The DET DT
# Republican PROPN NNP
# Congress PROPN NNP
# has AUX VBZ
# passed VERB VBN
# important ADJ JJ
# legislation NOUN NN
# to PART TO
# advance VERB VB
# information NOUN NN
# - PUNCT HYPH
# sharing NOUN NN
# among ADP IN
# entities NOUN NNS
# endangered VERB VBN
# by ADP IN
# cyber PROPN NNP
# attacks NOUN NNS
# . PUNCT .
# We PRON PRP
# will AUX MD
# explore VERB VB
# the DET DT
# possibility NOUN NN
# of ADP IN
# a DET DT
# free ADJ JJ
# market NOUN NN
# for ADP IN
# Cyber PROPN NNP
# - PUNCT HYPH
# Insurance PROPN NNP
# and CCONJ CC
# make VERB VB
# clear ADJ JJ
# that SCONJ IN
# users NOUN NNS
# have VERB VBP
# a DET DT
# self- SPACE _SP
#
#  SPACE _SP
# defense NOUN NN
# right NOUN NN
# to PART TO
# deal VERB VB
# with ADP IN
# hackers NOUN NNS
# as SCONJ IN
# they PRON PRP
# see VERB VBP
# fit ADJ JJ
# . PUNCT .
# It PRON PRP
# is AUX VBZ
# critical ADJ JJ
# that SCONJ IN
# we PRON PRP
# protect VERB VBP
# the DET DT
# cyber ADJ JJ
# supply NOUN NN
# chain NOUN NN
# to PART TO
# ensure VERB VB
# against ADP IN
# contamination NOUN NN
# of ADP IN
# components NOUN NNS
# made VERB VBN
# all ADV RB
# over ADP IN
# the DET DT
# world NOUN NN
# , PUNCT ,
# sometimes ADV RB
# in ADP IN
# offending VERB VBG
# countries NOUN NNS
# . PUNCT .
# Our PRON PRP$
# own ADJ JJ
# cyber NOUN NN
# workforce NOUN NN
# should AUX MD
# be AUX VB
# expanded VERB VBN
# with ADP IN
# the DET DT
# assistance NOUN NN
# of ADP IN
# the DET DT
# military ADJ JJ
# , PUNCT ,
# business NOUN NN
# , PUNCT ,
# and CCONJ CC
# hacker NOUN NN
# communities NOUN NNS
# to PART TO
# better ADV RBR
# protect VERB VB
# our PRON PRP$
# country NOUN NN
# . PUNCT .
#
#
#  SPACE _SP
# Protection NOUN NN
# Against ADP IN
# an DET DT
# Electromagnetic PROPN NNP
# Pulse PROPN NNP
#
#
#      SPACE _SP
# A DET DT
# single ADJ JJ
# nuclear ADJ JJ
# weapon NOUN NN
# detonated VERB VBN
# at ADP IN
# high ADJ JJ
# altitude NOUN NN
# over ADP IN
# this DET DT
# country NOUN NN
# would AUX MD
# collapse VERB VB
# our PRON PRP$
# electrical ADJ JJ
# grid NOUN NN
# and CCONJ CC
# other ADJ JJ
# critical ADJ JJ
# infrastructures NOUN NNS
# and CCONJ CC
# endanger VERB VB
# the DET DT
# lives NOUN NNS
# of ADP IN
# millions NOUN NNS
# . PUNCT .
# With SCONJ IN
# North PROPN NNP
# Korea PROPN NNP
# in ADP IN
# possession NOUN NN
# of ADP IN
# nuclear ADJ JJ
# missiles NOUN NNS
# and CCONJ CC
# Iran PROPN NNP
# close ADV RB
# to ADP IN
# having VERB VBG
# them PRON PRP
# , PUNCT ,
# an DET DT
# EMP PROPN NNP
# is AUX VBZ
# no ADV RB
# longer ADV RBR
# a DET DT
# theoretical ADJ JJ
# concern NOUN NN
# — PUNCT :
# it PRON PRP
# is AUX VBZ
# a DET DT
# real ADJ JJ
# threat NOUN NN
# . PUNCT .
# Moreover ADV RB
# , PUNCT ,
# China PROPN NNP
# and CCONJ CC
# Russia PROPN NNP
# include VERB VBP
# sabotage NOUN NN
# as ADP IN
# part NOUN NN
# of ADP IN
# their PRON PRP$
# warfare NOUN NN
# planning NOUN NN
# . PUNCT .
# Nonetheless ADV RB
# , PUNCT ,
# hundreds NOUN NNS
# of ADP IN
# electrical ADJ JJ
# utilities NOUN NNS
# in ADP IN
# the DET DT
# United PROPN NNP
# States PROPN NNP
# have AUX VBP
# not PART RB
# acted VERB VBN
# to PART TO
# protect VERB VB
# themselves PRON PRP
# from ADP IN
# EMP PROPN NNP
# , PUNCT ,
# and CCONJ CC
# they PRON PRP
# can AUX MD
# not PART RB
# be AUX VB
# expected VERB VBN
# to PART TO
# do VERB VB
# ...
# ) PUNCT -RRB-
# Marchi PROPN NNP
#
#       SPACE _SP
# ARKANSAS PROPN NNP
#                SPACE _SP
# HAWAII PROPN NNP
#              SPACE _SP
# MASSACHUSETTS PROPN NNP
#
#     SPACE _SP
# John PROPN NNP
# Nabholz PROPN NNP
#          SPACE _SP
# Adrienne PROPN NNP
# King PROPN NNP
#           SPACE _SP
# Amy PROPN NNP
# Carnevale PROPN NNP
#
#    SPACE _SP
# Leslie PROPN NNP
# Rutledge PROPN NNP
#       SPACE _SP
# William PROPN NNP
# McClary PROPN NNP
#           SPACE _SP
# Bob PROPN NNP
# Maginn PROPN NNP
#
#      SPACE _SP
# CALIFORNIA PROPN NNP
#               SPACE _SP
# IDAHO PROPN NNP
#                 SPACE _SP
# MICHIGAN PROPN NNP
#
#    SPACE _SP
# Noel PROPN NNP
# Hentschel PROPN NNP
#           SPACE _SP
# Vicki PROPN NNP
# Keen PROPN NNP
#              SPACE _SP
# Joe PROPN NNP
# Hune PROPN NNP
#
#      SPACE _SP
# Andy PROPN NNP
# Puzder PROPN NNP
#           SPACE _SP
# Steve PROPN NNP
# Yates PROPN NNP
#           SPACE _SP
# Meshawn PROPN NNP
# Maddock PROPN NNP
#
#       SPACE _SP
# COLORADO PROPN NNP
#               SPACE _SP
# ILLINOIS PROPN NNP
#               SPACE _SP
# MINNESOTA PROPN NNP
#
#      SPACE _SP
# Robin PROPN NNP
# Coran PROPN NNP
#      SPACE _SP
# Stephanie PROPN NNP
# Holderfield PROPN NNP
#      SPACE _SP
# Andy PROPN NNP
# Aplikowski PROPN NNP
#
#    SPACE _SP
# Justin PROPN NNP
# Everett PROPN NNP
#           SPACE _SP
# John PROPN NNP
# Lynch PROPN NNP
#           SPACE _SP
# Janet PROPN NNP
# Beihoffer PROPN NNP
#
#      SPACE _SP
# CONNECTICUT PROPN NNP
#             SPACE _SP
# INDIANA PROPN NNP
#               SPACE _SP
# MISSISSIPPI PROPN NNP
#
#   SPACE _SP
# Anthony PROPN NNP
# D’Amelio NOUN NN
#          SPACE _SP
# James PROPN NNP
# Bopp PROPN NNP
#             SPACE _SP
# Lynn PROPN NNP
# Fitch PROPN NNP
#
#    SPACE _SP
# Patricia PROPN NNP
# Longo PROPN NNP
#          SPACE _SP
# Brenda PROPN NNP
# Goff PROPN NNP
#          SPACE _SP
# Delbert PROPN NNP
# Hosemann PROPN NNP
#
#       SPACE _SP
# DELAWARE PROPN NNP
#                 SPACE _SP
# IOWA PROPN NNP
#                 SPACE _SP
# MISSOURI PROPN NNP
#
#    SPACE _SP
# Allison PROPN NNP
# Brokaw PROPN NNP
#         SPACE _SP
# Ben PROPN NNP
# Barringer PROPN NNP
#         SPACE _SP
# Hardy PROPN NNP
# Billington PROPN NNP
#
#    SPACE _SP
# Timothy PROPN NNP
# Houseal PROPN NNP
#         SPACE _SP
# Tamara PROPN NNP
# Scott PROPN NNP
#             SPACE _SP
# Bev PROPN NNP
# Ehlen PROPN NNP
#
#                              SPACE _SP
# KANSAS PROPN NNP
#
#                          SPACE _SP
# Mary PROPN NNP
# Kay PROPN NNP
# Culp PROPN NNP
#
#                           SPACE _SP
# Kris PROPN NNP
# Kobach PROPN NNP
#
#
#  SPACE _SP
# MONTANA PROPN NNP
#            SPACE _SP
# NORTHERN PROPN NNP
# MARIANA PROPN NNP
# ISLANDS PROPN NNPS
# TEXAS PROPN NNP
#
#  SPACE _SP
# Seth PROPN NNP
# Berglee PROPN NNP
#             SPACE _SP
# Ivan PROPN NNP
# Blanco PROPN NNP
#             SPACE _SP
# David PROPN NNP
# Barton PROPN NNP
#
#  SPACE _SP
# Debra PROPN NNP
# Lamm PROPN NNP
#                   SPACE _SP
# OHIO PROPN NNP
#                SPACE _SP
# Diana PROPN NNP
# Denman PROPN NNP
#
#  SPACE _SP
# NEBRASKA VERB VBZ
#                SPACE _SP
# David PROPN NNP
# Johnson PROPN NNP
#        SPACE _SP
# UTAH PROPN NNP
#
#  SPACE _SP
# Debby PROPN NNP
# Brehm PROPN NNP
#         SPACE _SP
# Tracey PROPN NNP
# Monroe PROPN NNP
# - PUNCT HYPH
# Winbush PROPN NNP
#       SPACE _SP
# Boyd PROPN NNP
# Matheson PROPN NNP
#
#  SPACE _SP
# Brian PROPN NNP
# Buescher PROPN NNP
#             SPACE _SP
# OKLAHOMA PROPN NNP
#             SPACE _SP
# Gayle PROPN NNP
# Ruzicka PROPN NNP
#
#  SPACE _SP
# NEVADA PROPN NNP
#                    SPACE _SP
# Marc PROPN NNP
# Hader PROPN NNP
#         SPACE _SP
# VERMONT PROPN NNP
#
#  SPACE _SP
# Juanita PROPN NNP
# Cox VERB VBZ
#            SPACE _SP
# Carolyn PROPN NNP
# McLarty PROPN NNP
#           SPACE _SP
# Rick PROPN NNP
# Cochran PROPN NNP
#
#  SPACE _SP
# Jesse PROPN NNP
# Law PROPN NNP
#                   SPACE _SP
# OREGON PROPN NNP
#            SPACE _SP
# Darcie PROPN NNP
# Johnston PROPN NNP
#
#  SPACE _SP
# NEW PROPN NNP
# HAMPSHIRE PROPN NNP
#             SPACE _SP
# Donna PROPN NNP
# Cain PROPN NNP
#         SPACE _SP
# VIRGINIA PROPN NNP
#
#  SPACE _SP
# Juliana PROPN NNP
# Bergeron PROPN NNP
#         SPACE _SP
# Russ PROPN NNP
# Walker PROPN NNP
#           SPACE _SP
# Cynthia PROPN NNP
# Dunbar PROPN NNP
#
#  SPACE _SP
# Stephen PROPN NNP
# Stepanek PROPN NNP
#         SPACE _SP
# PENNSYLVANIA PROPN NNP
#        SPACE _SP
# Thomas PROPN NNP
# Valentine PROPN NNP
#
#  SPACE _SP
# NEW PROPN NNP
# JERSEY PROPN NNP
#               SPACE _SP
# Jim PROPN NNP
# McErlane PROPN NNP
#          SPACE _SP
# VIRGIN PROPN NNP
# ISLANDS PROPN NNPS
#
#  SPACE _SP
# Joseph PROPN NNP
# Pennacchio PROPN NNP
#        SPACE _SP
# Carol PROPN NNP
# Sides PROPN NNPS
#            SPACE _SP
# April PROPN NNP
# Newland PROPN NNP
#
#  SPACE _SP
# Jill PROPN NNP
# Space PROPN NNP
#               SPACE _SP
# PUERTO PROPN NNP
# RICO PROPN NNP
#          SPACE _SP
# Humberto PROPN NNP
# O’Neal PROPN NNP
#
#  SPACE _SP
# NEW PROPN NNP
# MEXICO PROPN NNP
#         SPACE _SP
# Jenniffer PROPN NNP
# Gonzalez PROPN NNP
# - PUNCT HYPH
# Colon PROPN NNP
#        SPACE _SP
# WASHINGTON PROPN NNP
#
#  SPACE _SP
# Jonathan PROPN NNP
# Gardner PROPN NNP
#       SPACE _SP
# Jorge PROPN NNP
# San PROPN NNP
# Miguel PROPN NNP
#       SPACE _SP
# Manette PROPN NNP
# Merrill PROPN NNP
#
#  SPACE _SP
# Andrea PROPN NNP
# Moore PROPN NNP
#             SPACE _SP
# RHODE VERB VBP
# ISLAND NOUN NN
#           SPACE _SP
# Philip PROPN NNP
# Wilson PROPN NNP
#
#  SPACE _SP
# NEW PROPN NNP
# YORK PROPN NNP
#               SPACE _SP
# Giovanni PROPN NNP
# Cicione PROPN NNP
#         SPACE _SP
# WEST PROPN NNP
# VIRGINIA PROPN NNP
#
#  SPACE _SP
# Thomas PROPN NNP
# Dadey PROPN NNP
#           SPACE _SP
# Lee PROPN NNP
# Ann PROPN NNP
# Sennick PROPN NNP
#          SPACE _SP
# Melody PROPN NNP
# Potter PROPN NNP
#
#  SPACE _SP
# Anne PROPN NNP
# Dickerson PROPN NNP
#          SPACE _SP
# SOUTH PROPN NNP
# CAROLINA PROPN NNP
#         SPACE _SP
# Victor PROPN NNP
# Sprouse PROPN NNP
#
#  SPACE _SP
# NORTH PROPN NNP
# CAROLINA PROPN NNP
#          SPACE _SP
# Alan PROPN NNP
# Clemmons PROPN NNP
#        SPACE _SP
# WISCONSIN PROPN NNP
#
#  SPACE _SP
# Mary PROPN NNP
# Forrester PROPN NNP
#          SPACE _SP
# LaDonna PROPN NNP
# Ryggs PROPN NNP
#           SPACE _SP
# Kathy PROPN NNP
# Kiernan PROPN NNP
#
#  SPACE _SP
# Ron PROPN NNP
# Rabin PROPN NNP
#                SPACE _SP
# SOUTH PROPN NNP
# DAKOTA ADJ JJ
#           SPACE _SP
# Tom PROPN NNP
# Schreibel PROPN NNP
#
#  SPACE _SP
# NORTH PROPN NNP
# DAKOTA PROPN NNP
#              SPACE _SP
# Nancy PROPN NNP
# Neff PROPN NNP
#         SPACE _SP
# WYOMING PROPN NNP
#
#  SPACE _SP
# Kelly PROPN NNP
# Armstrong PROPN NNP
#            SPACE _SP
# Hal PROPN NNP
# Wick PROPN NNP
#           SPACE _SP
# Marti PROPN NNP
# Halverson PROPN NNP
#
#  SPACE _SP
# Kelly PROPN NNP
# Schmidt PROPN NNP
#             SPACE _SP
# TENNESSEE PROPN NNP
#               SPACE _SP
# Dick PROPN NNP
# Shanor PROPN NNP
#
#                          SPACE _SP
# Victor PROPN NNP
# Ashe PROPN NNP
#
#                         SPACE _SP
# Connie PROPN NNP
# Hunter PROPN NNP
#
#
#                                                         SPACE _SP
# Platform PROPN NNP
# Staff PROPN NNP
#
#
#                                                      SPACE _SP
# Ben PROPN NNP
# Key PROPN NNP
# , PUNCT ,
# Executive PROPN NNP
# Director PROPN NNP
# Andrew PROPN NNP
# Bremberg PROPN NNP
# , PUNCT ,
# Policy PROPN NNP
# Director PROPN NNP
# Bill PROPN NNP
# Gribbin PROPN NNP
# , PUNCT ,
# Editor PROPN NNP
# Eric PROPN NNP
# Ueland PROPN NNP
# , PUNCT ,
# Assistant PROPN NNP
# Editor PROPN NNP
# Mary PROPN NNP
# Salvi PROPN NNP
# , PUNCT ,
# Executive PROPN NNP
# Assistant PROPN NNP
# David PROPN NNP
# Schiappa PROPN NNP
# , PUNCT ,
# Parliamentarian PROPN NNP
# Justin PROPN NNP
# Riemer PROPN NNP
# , PUNCT ,
# Counsel PROPN NNP
# Mary PROPN NNP
# Elizabeth PROPN NNP
# Taylor PROPN NNP
# , PUNCT ,
# Clerk PROPN NNP
# Allison PROPN NNP
# Curry PROPN NNP
# , PUNCT ,
# Clerk PROPN NNP
# Sloane PROPN NNP
# Skinner PROPN NNP
# , PUNCT ,
# Clerk PROPN NNP
# Karen PROPN NNP
# Portik PROPN NNP
# , PUNCT ,
# Graphic PROPN NNP
# Designer PROPN NNP
# Marcia PROPN NNP
# Brown PROPN NNP
# , PUNCT ,
# Production PROPN NNP
# Sheila PROPN NNP
# Berkley PROPN NNP
# , PUNCT ,
# Platform PROPN NNP
# Consultant NOUN NN
# Mike PROPN NNP
# Mears PROPN NNP
# , PUNCT ,
# Director PROPN NNP
# of ADP IN
# Strategic PROPN NNP
# Partnerships PROPN NNP
# Rachel PROPN NNP
# Packebush PROPN NNP
# , PUNCT ,
# Intern PROPN NNP
#
#
#                                                               SPACE _SP
# Administrative PROPN NNP
# Team PROPN NNP
#
#
#                                       SPACE _SP
# Brian PROPN NNP
# O’Malley NOUN NN
# , PUNCT ,
# Ed PROPN NNP
# Cowling PROPN NNP
# , PUNCT ,
# Blake PROPN NNP
# Glovitz PROPN NNP
# , PUNCT ,
# Kim PROPN NNP
# Owens PROPN NNP
# , PUNCT ,
# Will PROPN NNP
# Gillette PROPN NNP
# , PUNCT ,
# Gordon PROPN NNP
# James PROPN NNP
#
#
#                                                                 SPACE _SP
# Court PROPN NNP
# Reporter PROPN NNP
#
#
#                                                         SPACE _SP
# Stephen PROPN NNP
# Mengelkamp PROPN NNP
# , PUNCT ,
# Nate PROPN NNP
# Riveness PROPN NNP
#
#
#                                                                   SPACE _SP
# Policy PROPN NNP
# Staff NOUN NN
#
#
#                                                                  SPACE _SP
# Restoring VERB VBG
# the DET DT
# American PROPN NNP
# Dream PROPN NNP
#
#
#                                                                        SPACE _SP
# Jeff PROPN NNP
# Schlagenhauf PROPN NNP
# Eric PROPN NNP
# Ueland PROPN NNP
#
#
#                                                                      SPACE _SP
# Government PROPN NNP
# Reform PROPN NNP
#
#
#                                                                        SPACE _SP
# Danielle PROPN NNP
# Cutrona PROPN NNP
# Katy PROPN NNP
# Talento PROPN NNP
#
#
#                                                                   SPACE _SP
# A PROPN NNP
# Rebirth PROPN NNP
# of ADP IN
# Constitutional ADJ JJ
# Government PROPN NNP
#
#
#                                                                               SPACE _SP
# Stephen PROPN NNP
# Higgins PROPN NNP
# Robert PROPN NNP
# Porter PROPN NNP
#
#
#                                                                  SPACE _SP
# America PROPN NNP
# 's PART POS
# Natural PROPN NNP
# Resources PROPN NNPS
# : PUNCT :
# Agriculture PROPN NNP
# , PUNCT ,
# Energy PROPN NNP
# , PUNCT ,
# and CCONJ CC
# the DET DT
# Environment PROPN NNP
#
#
#                                                                               SPACE _SP
# Brian PROPN NNP
# Clifford PROPN NNP
# Justin PROPN NNP
# Memmott PROPN NNP
#
#
#                                                                 SPACE _SP
# Great PROPN NNP
# American PROPN NNP
# Families PROPN NNPS
# , PUNCT ,
# Education PROPN NNP
# , PUNCT ,
# Healthcare PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Criminal PROPN NNP
# Justice PROPN NNP
#
#
#                                                                            SPACE _SP
# Katie PROPN NNP
# Altshuler PROPN NNP
# Cyrus PROPN NNP
# Artz PROPN NNP
#
#
#                                                                         SPACE _SP
# America PROPN NNP
# Resurgent PROPN NNP
#
#
#                                                                           SPACE _SP
# Jonathan PROPN NNP
# Burks PROPN NNP
# Michael PROPN NNP
# Stransky PROPN NNP
# Robert PROPN NNP
# Wilkie PROPN NNP
#
#
#                                                                       SPACE _SP
# Former PROPN NNP
# Executive PROPN NNP
# Directors PROPN NNPS
#
#
#                                       SPACE _SP
# Ambassador PROPN NNP
# John PROPN NNP
# Bolton PROPN NNP
# , PUNCT ,
# 1984 NUM CD
# ; PUNCT :
# Judy PROPN NNP
# Van PROPN NNP
# Rest PROPN NNP
# , PUNCT ,
# 1992 NUM CD
# ; PUNCT :
# William PROPN NNP
# Martin PROPN NNP
# , PUNCT ,
# 1996 NUM CD
# ; PUNCT :
# Mitch PROPN NNP
# Bainwol PROPN NNP
# , PUNCT ,
# 2000 NUM CD
# ; PUNCT :
#
#
#                                                                 SPACE _SP
# Anne PROPN NNP
# Phelps PROPN NNP
# , PUNCT ,
# 2004 NUM CD
# ; PUNCT :
# Steven PROPN NNP
# Duffield PROPN NNP
# , PUNCT ,
# 2008 NUM CD
#
#
#                                                                             SPACE _SP
# Special PROPN NNP
# Thanks NOUN NNS
#
#
#                       SPACE _SP
# Mike PROPN NNP
# Ambrosini PROPN NNP
# , PUNCT ,
# Caroline PROPN NNP
# Anderegg PROPN NNP
# , PUNCT ,
# Carl PROPN NNP
# Anderson PROPN NNP
# , PUNCT ,
# Alex PROPN NNP
# Angelson PROPN NNP
# , PUNCT ,
# Christine PROPN NNP
# Anton PROPN NNP
# , PUNCT ,
# Sara PROPN NNP
# Armstrong PROPN NNP
# , PUNCT ,
# Michael PROPN NNP
# Babyak PROPN NNP
# , PUNCT ,
# Gineen PROPN NNP
# Bresso PROPN NNP
# , PUNCT ,
# Tyler PROPN NNP
# Brown PROPN NNP
# , PUNCT ,
# Jeffrey PROPN NNP
# Brownlee PROPN NNP
# , PUNCT ,
# Courtney PROPN NNP
# Butcher PROPN NNP
# , PUNCT ,
# Anna PROPN NNP
# Katherine PROPN NNP
# Cabaniss PROPN NNP
# , PUNCT ,
# Joseph PROPN NNP
# Chang PROPN NNP
# , PUNCT ,
# Jason PROPN NNP
# Chung PROPN NNP
# , PUNCT ,
# CC PROPN NNP
# Cobaugh PROPN NNP
# , PUNCT ,
# Paul PROPN NNP
# Coyer PROPN NNP
# , PUNCT ,
# Sharon PROPN NNP
# Day PROPN NNP
# , PUNCT ,
# Logan PROPN NNP
# Dryden PROPN NNP
# , PUNCT ,
# Kim PROPN NNP
# Ekmark PROPN NNP
# , PUNCT ,
# Max PROPN NNP
# Everett PROPN NNP
# , PUNCT ,
# Dirk PROPN NNP
# Eyman PROPN NNP
# , PUNCT ,
# Jonathan PROPN NNP
# Du PROPN NNP
# , PUNCT ,
# Grant PROPN NNP
# Gardner PROPN NNP
# , PUNCT ,
# Mike PROPN NNP
# Gilding PROPN NNP
# , PUNCT ,
# Ed PROPN NNP
# Goeas PROPN NNP
# , PUNCT ,
# Jackson PROPN NNP
# Greene PROPN NNP
# , PUNCT ,
# Julia PROPN NNP
# Griswold PROPN NNP
# , PUNCT ,
# William PROPN NNP
# Heartsill PROPN NNP
# , PUNCT ,
# Rebecca PROPN NNP
# Heilig PROPN NNP
# , PUNCT ,
# Lauren PROPN NNP
# Hernandez PROPN NNP
# , PUNCT ,
# Mike PROPN NNP
# Holley PROPN NNP
# , PUNCT ,
# CJ PROPN NNP
# Jordan PROPN NNP
# , PUNCT ,
# Katie PROPN NNP
# Hrkman PROPN NNP
# , PUNCT ,
# Dave PROPN NNP
# Juday PROPN NNP
# , PUNCT ,
# Kate PROPN NNP
# Karnes PROPN NNP
# , PUNCT ,
# Sarah PROPN NNP
# Keeny PROPN NNP
# , PUNCT ,
# Jennifer PROPN NNP
# Ketchum PROPN NNP
# , PUNCT ,
# Kirsten PROPN NNP
# Kukowski PROPN NNP
# , PUNCT ,
# Dan PROPN NNP
# Kunsman PROPN NNP
# , PUNCT ,
# Dee PROPN NNP
# Dee PROPN NNP
# Lancaster PROPN NNP
# , PUNCT ,
# Bronwyn PROPN NNP
# Lance PROPN NNP
# - PUNCT HYPH
# Chester PROPN NNP
# , PUNCT ,
# Gerrit PROPN NNP
# Lansing PROPN NNP
# , PUNCT ,
# Jeff PROPN NNP
# Larson PROPN NNP
# , PUNCT ,
# Anne PROPN NNP
# Lesser PROPN NNP
# , PUNCT ,
# Ryan PROPN NNP
# Mahoney PROPN NNP
# , PUNCT ,
# Matthew PROPN NNP
# Mazzone PROPN NNP
# , PUNCT ,
# Arjun PROPN NNP
# Mody PROPN NNP
# , PUNCT ,
# Janet PROPN NNP
# Montesi PROPN NNP
# , PUNCT ,
# Kimberly PROPN NNP
# Morrall PROPN NNP
# , PUNCT ,
# Vanessa PROPN NNP
# Morrone PROPN NNP
# , PUNCT ,
# Maison PROPN NNP
# Newenhouse PROPN NNP
# , PUNCT ,
# Kathryn PROPN NNP
# Neville PROPN NNP
# , PUNCT ,
# Lexi PROPN NNP
# Nord PROPN NNP
# , PUNCT ,
# Denise PROPN NNP
# Northrup PROPN NNP
# , PUNCT ,
# Andrew PROPN NNP
# Olmem PROPN NNP
# , PUNCT ,
# Mike PROPN NNP
# Omegna PROPN NNP
# , PUNCT ,
# Caroline PROPN NNP
# Ozer PROPN NNP
# , PUNCT ,
# John PROPN NNP
# Phillippe PROPN NNP
# , PUNCT ,
# Brandon PROPN NNP
# Renz PROPN NNP
# , PUNCT ,
# Jackie PROPN NNP
# Rivera PROPN NNP
# , PUNCT ,
# Christine PROPN NNP
# Samuelian PROPN NNP
# , PUNCT ,
# Audrey PROPN NNP
# Scagnelli PROPN NNP
# , PUNCT ,
# Tory PROPN NNP
# Sendek PROPN NNP
# , PUNCT ,
# Raj PROPN NNP
# Shah PROPN NNP
# , PUNCT ,
# Lani PROPN NNP
# Short PROPN NNP
# , PUNCT ,
# Harold PROPN NNP
# “ PUNCT ``
# Hal PROPN NNP
# ” PUNCT ''
# Smith PROPN NNP
# , PUNCT ,
# Steve PROPN NNP
# Smith PROPN NNP
# , PUNCT ,
# Veronica PROPN NNP
# Smith PROPN NNP
# , PUNCT ,
# Sean PROPN NNP
# Spicer PROPN NNP
# , PUNCT ,
# Elizabeth PROPN NNP
# Stangl PROPN NNP
# , PUNCT ,
# Elizabeth PROPN NNP
# Steil PROPN NNP
# , PUNCT ,
# Melinda PROPN NNP
# Stell PROPN NNP
# , PUNCT ,
# Maddison PROPN NNP
# Stone PROPN NNP
# , PUNCT ,
# Jan PROPN NNP
# Sumrall PROPN NNP
# , PUNCT ,
# James PROPN NNP
# Tobin PROPN NNP
# , PUNCT ,
# Lauren PROPN NNP
# Toomey PROPN NNP
# , PUNCT ,
# Courtney PROPN NNP
# Uckele PROPN NNP
# , PUNCT ,
# Mike PROPN NNP
# Vallante PROPN NNP
# , PUNCT ,
# Evan PROPN NNP
# Walker PROPN NNP
# , PUNCT ,
# Katie PROPN NNP
# Walsh PROPN NNP
# , PUNCT ,
# Lindsey PROPN NNP
# Walters PROPN NNP
# , PUNCT ,
# David PROPN NNP
# Wilezol PROPN NNP
# , PUNCT ,
# Madeleine PROPN NNP
# Westerhout PROPN NNP
# , PUNCT ,
# Kathi PROPN NNP
# Wise PROPN NNP
#
#
#                                                                    SPACE _SP
# Printed PROPN NNP
# by ADP IN
# Consolidated PROPN NNP
# Solutions PROPN NNPS
# The DET DT
# Lanci PROPN NNP
# , PUNCT ,
# Moeritz PROPN NNP
# , PUNCT ,
# and CCONJ CC
# Reville PROPN NNP
# Family PROPN NNP
#
#  SPACE _SP
# RNO2016 PROPN NNP
#
#
#  SPACE _SP
# CLEVELAND PROPN NNP
#
#
#  SPACE _SP
# REPUBLICAN PROPN NNP
# NATIONAL PROPN NNP
# CONVENTION PROPN NNP
#
#
#  SPACE _SP
# ★ VERB VBP
# REPUBLICAN PROPN NNP
# PLATFORM PROPN NNP
# 2016 NUM CD
# ★ VERB VBP

# %% [markdown]
# ### Extracting words by part of speech
#
# Now we can write simple code to extract and recombine words by their part of speech. The following code creates two lists, one for all the nouns and another for all of the adjectives in the Republican platform:

# %%
nouns = []
adjectives = []

for word in repub_plat_doc:
    if word.pos_ == 'NOUN' and word.text not in nouns:
        nouns.append(word.text)
    elif word.pos_ == 'ADJ' and word.text not in adjectives:
        adjectives.append(word.text)

print("here are the first 20 nouns: " + str(nouns[0:19]))
print("and here are the first 20 adjectives: " + str(adjectives[0:19]))
# Out:
# here are the first 20 nouns: ['RESOLUTION', 'PLATFORM', 'size', 'scope', 'restrictions', 'gatherings', 'meetings', 'concern', 'safety', 'convention', 'attendees', 'hosts', 'appreciation', 'fact', 'contingent', 'delegates', 'platform', 'breadth', 'perspectives']
# and here are the first 20 adjectives: ['strict', 'small', 'new', 'Republican', 'historical', 'political', 'able', 'strong', 'misleading', 'unbiased', 'first', 'accurate', 'American', 'common', 'other', 'exceptional', 'historic', 'refuge', 'exemplar']

# %% [markdown]
# And below, some code to print out random pairings of an adjective from the text with a noun from the text:

# %%
import random
print(random.choice(adjectives) + " " + random.choice(nouns))
print(random.choice(adjectives) + " " + random.choice(nouns))
print(random.choice(adjectives) + " " + random.choice(nouns))
print(random.choice(adjectives) + " " + random.choice(nouns))
# Out:
# actual pressure
# balanced measurement
# chief duties
# Judicial loss

# %% [markdown]
# ### **Excercise #1**

# %% [markdown]
# Remember from a few cells up above how the `.tag_` attribute allows us to be even more specific thtan the `.pos` attribute about the parts of speech we want?
#
# How would we iterate through the words included in the Republican platform to get a list of only verbs in the past participle?
#
# *Hint: you'll find the name of the tag you're looking for [here](https://spacy.io/api/annotation#pos-tagging). Click on "English" to expand.*

# %%
verbs = []

for word in repub_plat_doc:
    if word.tag_ == 'VBN' and word.text not in verbs:
        verbs.append(word.text)
    

print("here are the verbs in past participle: " + str(verbs))
# Out:
# here are the verbs in past participle: ['scaled', 'voted', 'born', 'agreed', 'misrepresented', 'failed', 'espoused', 'RESOLVED', 'ruled', 'Paid', 'Authorized', 'protected', 'created', 'endowed', 'written', 'preserved', 'separated', 'given', 'Based', 'been', 'led', 'become', 'earned', 'declined', 'shortchanged', 'dismantled', 'replaced', 'abandoned', 'doubled', 'attacked', 'related', 'sustained', 'increased', 'lost', 'compared', 'left', 'plunged', 'seen', 'elected', 'exceeded', 'offered', 'based', 'engineered', 'simplified', 'lowered', 'changed', 'consumed', 'repeated', 'tied', 'recovered', 'taxed', 'repatriated', 'headquartered', 'committed', 'called', 'negotiated', 'resulted', 'supported', 'violated', 'rejected', 'supposed', 'rushed', 'undertaken', 'controlled', 'known', 'killed', 'limited', 'encouraged', 'shackled', 'made', 'helped', 'relieved', 'designed', 'guaranteed', 'favored', 'abolished', 'subjected', 'advanced', 'used', 'harmed', 'connected', 'resolved', 'regulated', 'capitalized', 'lived', 'managed', 'escalated', 'fallen', 'plummeted', 'prevented', 'reconsidered', 'backed', 'exposed', 'taken', 'insured', 'secured', 'named', 'meant', 'diverted', 'spent', 'funded', 'needed', 'permitted', 'concerned', 'reversed', 'collapsed', 'transformed', 'deployed', 'done', 'wired', 'reduced', 'established', 'slowed', 'proposed', 'carried', 'implemented', 'insulated', 'fixed', 'passed', 'repealed', 'outlawed', 'built', 'handled', 'paid', 'reviewed', 'demanded', 'incurred', 'placed', 'pursued', 'granted', 'recognized', 'ordered', 'held', 'imposed', 'refused', 'confirmed', 'enabled', 'applauded', 'endorsed', 'understood', 'adopted', 'enacted', 'reserved', 'expressed', 'appointed', 'usurped', 'rooted', 'construed', 'required', 'vested', 'delegated', 'Unelected', 'approved', 'entrusted', 'disciplined', 'demonstrated', 'barred', 'prohibited', 'defied', 'Protected', 'unregulated', 'forced', 'loved', 'affirmed', 'conceived', 'fated', 'perpetrated', 'responded', 'brought', 'deprived', 'infringed', 'revealed', 'borne', 'Born', 'intended', 'torn', 'organized', 'Retained', 'retained', 'ignored', 'enumerated', 'returned', 'attached', 'conditioned', 'harassed', 'denied', 'counted', 'verified', 'stationed', 'allowed', 'expanded', 'imported', 'crafted', 'expected', 'pushed', 'had', 'curbed', 'ended', 'modified', 'proven', 'suffered', 'equipped', 'issued', 'stopped', 'improved', 'fostered', 'developed', 'isolated', 'dedicated', 'instituted', 'removed', 'impacted', 'produced', 'estimated', 'summed', 'stayed', 'relicensed', 'slashed', 'struck', 'liquefied', 'blocked', 'owned', 'occurred', 'stuck', 'triggered', 'mainstreamed', 'added', 'caused', 'directed', 'politicized', 'compensated', 'excluded', 'tolerated', 'identified', 'designated', 'stunted', 'shown', 'reflected', 'submitted', 'ratified', 'solved', 'begun', 'happened', 'Left', 'focused', 'imperiled', 'headed', 'adjusted', 'administered', 'replicated', 'dictated', 'assured', 'considered', 'launched', 'devised', 'announced', 'impeded', 'unleashed', 'watched', 'murdered', 'disadvantaged', 'obeyed', 'outlined', 'rescinded', 'deported', 'penalized', 'halted', 'noted', 'vetted', 'admitted', 'specified', 'entered', 'deemed', 'abrogated', 'transmitted', 'lied', 'impeached', 'convicted', 'prepared', 'compelled', 'renewed', 'Blocked', 'undermined', 'rewritten', 'scrapped', 'confined', 'packed', 'honored', 'grown', 'withdrawn', 'safeguarded', 'exhibited', 'gone', 'integrated', 'tasked', 'sponsored', 'authorized', 'engaged', 'revived', 'marginalized', 'continued', 'learned', 'raised', 'treated', 'enlarged', 'stabilized', 'tested', 'persisted', 'worsened', 'discredited', 'nullified', 'sought', 'driven', 'educated', 'devoted', 'interfered', 'collected', 'filed', 'reported', 'investigated', 'prosecuted', 'decided', 'determined', 'punished', 'entrenched', 'abused', 'denounced', 'restored', 'challenged', 'decoupled', 'empowered', 'risen', 'mandated', 'promoted', 'transported', 'ballooned', 'affected', 'poised',  ...

# %% [markdown]
# ## Larger syntactic units
#
# So we can get individual words by their part of speech. Great! But what if we want larger chunks, based on their syntactic role in the sentence? The easy way is `.noun_chunks`, which is an attribute of a document or a sentence that evaluates to a list of [spans](https://spacy.io/docs/api/span) of noun phrases, regardless of their position in the document:

# %%
for item in dem_plat_doc.noun_chunks:
    print(item.text)
# Out:
# Streaming output truncated to the last 5000 lines.
# America
# OUR DEMOCRACY
# Our government
# our elections
# the interests
# the American people
# the biggest corporations
# Democrats
# Americans
# fundamental right
# Republican governors
# legislatures
# state officials
# who
# people
# color
# young people
# low-income people
# people
# disabilities
# we
# ethics laws
# transparency
# the federal government
# order
# trust
# the American people
# civil servants
# whistleblowers
# political retribution
# the sacred principle
# “one person
# we
# that principle
# every citizen
# race
# income
# disability status
# geography
# English language proficiency
# We
# the determined Republican campaign
# voters
# onerous voter ID laws
# unconstitutional and excessive purges
# the voter rolls
# closures
# polling places
# low-income neighborhoods
# college campuses
# communities
# color
# Americans
# hours-long lines
# their voting rights
# Democrats
# our democracy
# every American’s vote
# We
# it
# legislation
# that
# the Voting Rights Act
# the Department
# Justice
# state laws
# that
# it
# Americans
# We
# voting
# all Americans
# automatic voter registration
# same-day voter registration
# early voting
# home
# vote
# mail
# Democrats
# Election Day
# a national holiday
# celebration
# our democratic institutions
# it
# everyone
# their ballot
# Democrats
# unions
# community groups
# faith organizations
# other civic organizations
# registration
# voting
# voter rights
# We
# the Help America Vote Act
# polling places
# elections
# people
# disabilities
# citizens
# their voting rights
# release
# jail
# prison
# the additional hurdle
# fines
# fees
# order
# Democrats
# emergency funding
# states
# vote
# home
# vote
# mail
# the pandemic
# all jurisdictions
# steps
# continued meaningful, safe opportunities
# person
# We
# the United States Postal Service
# ever a critical component
# our democracy
# timely and efficient delivery
# return
# vote
# mail ballots
# Election officials
# sufficient time
# election day
# all ballots
# We
# voters
# the confidence
# their ballot
# mandatory, statistically meaningful post-election audits
# full transparency
# all election results
# data
# every eligible ballot
# vote
# mail voters
# a meaningful opportunity
# any problem
# their ballot
# A professional and well-trained election workforce
# the administration
# elections
# we
# ongoing federal and state funding
# local elections offices
# Gerrymandering
# our democracy
# Democrats
# measures
# partisan gerrymandering
# federal elections
# Efforts
# legislative districts
# the 2020 Census
# transparency
# public input
# the power
# partisan actors
# that maps
# the will
# voters
# communities
# color
# competitive races
# We
# the integrity
# the decennial Census
# political interference
# apportionment
# redistricting
# the border
# policies
# that
# them
# “safe third countries
# which
# Democrats
# our fight
# systemic and structural racism
# our country
# our immigration system
# the policies
# our borders
# ports
# entry
# detention centers
# immigration law enforcement agencies
# their policies
# operations
# Democrats
# enforcement
# the Trump Administration’s un-American immigrant wealth test
# we
# the enormous damage
# the Trump Administration
# we
# a 21st century immigration system
# that
# our values
# economic opportunity
# all Americans
# our global competitiveness
# Democrats
# it
# long past time
# a roadmap
# the millions
# undocumented workers
# caregivers
# students
# children
# who
# an essential part
# our economy
# the fabric
# our nation
# We
# this process
# those workers
# who
# the pandemic response
# recovery efforts
# health care workers
# farmworkers
# others
# We
# unfair barriers
# naturalization
# application backlogs
# our immigration processes
# These reforms
# our communities
# our families
# our economy
# our country
# Democrats
# President Trump
# ’s
# illegal, chaotic, and reckless changes
# the legal immigration system
# decisions
# family-based immigration
# H-1B
# other visa programs
# that
# our economy
# Democrats
# family unity
# a guiding principle
# our immigration policy
# We
# family reunification
# children
# their families
# we
# family reunification programs
# the Trump Administration
# We
# legislation
# the spouses
# children
# green card holders
# immediate relatives
# their unfair separation
# We
# family-based green card backlogs
# the system
# family-based visas
# we
# Congress
# immigration barriers
# the three- and 10-year bars
# the 10-year waiting period
# waivers
# the permanent bars
# that
# loved ones
# We
# we
# the annual visa cap
# victims
# human trafficking
# victims
# sex trafficking
# violence
# women
# children
# other heinous crimes
# that same sex-couples
# their children
# equal treatment
# the
# immigration and naturalization systems
# America’s commitment
# family-based immigration
# the critical role
# diversity preferences
# our immigration system
# Democrats
# law-abiding individuals
# Temporary Protected Status
# Deferred Enforced Departure
# countries
# they
# we
# a path
# those
# who
# the country
# an extended period
# time
# their lives
# the United States
# Democrats
# employers
# abuse and bully immigrant workers
# all workers
# That
# we
# employers
# workers’ rights
# the enforcement
# labor and employment laws
# the economy
# discrimination
# sexual harassment protections
# wage and hour laws
# health and safety rules
# We
# employers
# advantage
# immigrant workers
# an affirmative process
# deferred action
# workers
# who
# labor violations
# the Domestic Workers’ Bill
# Rights
# Our Workers
# Exploitation and Retaliation (POWER) Act
# We
# enforcement mechanisms
# our values
# international humanitarian obligations
# That
# we
# workplace and community raids
# We
# sensitive locations
# our schools
# houses
# worship
# health care facilities
# benefits offices
# DMVs
# immigration enforcement actions
# prohibit raids
# which
# children
# members
# vulnerable populations
# their caregivers
# We
# enforcement actions
# that
# access
# justice
# courthouses
# freedom
# speech
# assembly
# end programs
# that
# state and local law enforcement
# immigration enforcement
# men
# women
# who
# uniform
# their families
# We
# enforcement officials’ ability
# the pre-Trump practice
# prosecutorial discretion
# cases
# humanitarian issues
# other injustices
# We
# enforcement officials
# individuals
# their political speech
# activity
# their efforts
# individuals’ rights
# We
# detention
# a last resort
# the default
# Democrats
# investments
# more effective and cost-efficient community-based alternatives
# detention
# We
# profit
# any facility
# migrants
# the highest standards
# care
# their safety
# dignity
# We
# all detention centers
# access
# competent interpreters
# who
# migrants' native languages
# dialects
# Detention
# children
# the shortest possible time
# their access
# education
# proper care
# We
# alternatives
# detention
# individuals
# a more peaceful, stable, and free region
# Democrats
# the Trump Administration’s race
# war
# Iran
# nuclear diplomacy
# de
# -
# escalation
# regional dialogue
# Democrats
# the United States
# regime change
# other countries
# the goal
# U.S. policy
# Iran
# We
# the Joint Comprehensive Plan
# Action
# JCPOA
# the best means
# all
# Iran
# a nuclear bomb
# The Trump Administration’s unilateral withdrawal
# the JCPOA
# us
# our allies
# the door
# Iran
# its march
# a nuclear weapons capacity
# that
# the JCPOA
# That
# mutual compliance
# the agreement
# The nuclear deal
# the beginning
# the end
# our diplomacy
# Iran
# Democrats
# a comprehensive diplomatic effort
# constraints
# Iran’s nuclear program
# Iran’s other threatening activities
# its regional aggression
# ballistic missile program
# domestic repression
# Democrats
# we
# our relations
# our Gulf partners
# our interests
# values
# The United States
# an interest
# our partners
# legitimate security threats
# we
# their political and economic modernization
# efforts
# regional tensions
# we
# no interest
# the blank-check era
# the Trump Administration
# authoritarian impulses
# internal rivalries
# catastrophic proxy wars
# efforts
# political openings
# the region
# Effective relations
# the Gulf
# us
# Iraq
# its neighbors
# the country’s stability
# security
# sovereignty
# Democrats
# military presence
# our Iraqi partners
# they
# the lasting defeat
# ISIS
# We
# the offensive
# ISIS
# Syria
# it
# a foothold
# Kurdish and other critical partners
# that fight
# We
# foreign fighter detainees
# diplomacy
# the humanitarian needs
# human and civil rights
# all Syrians
# a political resolution
# this horrific war
# Democrats
# the deepening crisis
# Lebanon
# the Lebanese people
# political and economic reform
# financial stability
# security
# Democrats
# democratic Israel
# the interests
# the United States
# Our commitment
# Israel’s security
# its qualitative military edge
# its right
# itself
# the 2016 Memorandum
# Understanding
# Democrats
# the worth
# every Palestinian
# That
# we
# an end
# a conflict
# that
# so much pain
# We
# a negotiated two-state solution
# that
# Israel’s future
# a Jewish and democratic state
# recognized borders
# the right
# Palestinians
# freedom
# security
# a viable state
# Democrats
# any unilateral steps
# either side
# annexation
# two states
# Democrats
# incitement
# terror
# We
# settlement expansion
# We
# Jerusalem
# a matter
# final status negotiations
# it
# the capital
# Israel
# an undivided city
# people
# all faiths
# Democrats
# diplomatic ties
# critical assistance
# the Palestinian people
# the West Bank
# Gaza
# U.S. law
# We
# any effort
# Israel
# the United Nations
# the Boycott, Divestment, and Sanctions Movement
# the Constitutional right
# our citizens
# free speech

# %% [markdown]
# For anything more sophisticated than this, though, we'll need to learn about how spaCy parses sentences into its syntactic components.

# %% [markdown]
# ### Understanding dependency grammars

# %% [markdown]
# ![syntax_example.png](data:image/png;base64,...)

# %% [markdown]
# The idea of a dependency grammar is that every word in a sentence is a "dependent" on some other word, which is that word's "head." Those "head" words are in turn dependents of other words. The finite verb in the sentence is the ultimate "head" of the sentence, and is not itself dependent on any other word. (The dependents of a particular head are sometimes called its "children.")
#
# The question of how to know what constitutes a "head" and a "dependent" is complicated. As a starting point, here's a passage from [Dependency Grammar and Dependency Parsing](http://stp.lingfil.uu.se/~nivre/docs/05133.pdf):
#
# > Here are some of the criteria that have been proposed for identifying a syntactic relation between a head H and a dependent D in a construction C (Zwicky, 1985; Hudson, 1990):
# >
# > 1. H determines the syntactic category of C and can often replace C.
# > 2. H determines the semantic category of C; D gives semantic specification.
# > 3. H is obligatory; D may be optional.
# > 4. H selects D and determines whether D is obligatory or optional.
# > 5. The form of D depends on H (agreement or government).
# > 6. The linear position of D is specified with reference to H."
#
# There are different *types* of relationships between heads and dependents, and each type of relation has its own name.
#
# **Visit [the displaCy visualizer](https://demos.explosion.ai/displacy/?text=Everyone%20has%20the%20right%20to%20life%2C%20liberty%20and%20security%20of%20person&model=en&cpu=1&cph=0) to see how a particular sentence is parsed, and what the relations between the heads and dependents are.**

# %% [markdown]
# Here's a list of a few dependency relations and what they mean. ([A more complete list can be found here.](http://www.mathcs.emory.edu/~choi/doc/clear-dependency-2012.pdf))
#
# * `nsubj`: this word's head is a verb, and this word is itself the subject of the verb
# * `nsubjpass`: same as above, but for subjects in sentences in the passive voice
# * `dobj`: this word's head is a verb, and this word is itself the direct object of the verb
# * `iobj`: same as above, but indirect object
# * `aux`: this word's head is a verb, and this word is an "auxiliary" verb (like "have", "will", "be")
# * `attr`: this word's head is a copula (like "to be"), and this is the description attributed to the subject of the sentence (e.g., in "This product is a global brand", `brand` is dependent on `is` with the `attr` dependency relation)
# * `det`: this word's head is a noun, and this word is a determiner of that noun (like "the," "this," etc.)
# * `amod`: this word's head is a noun, and this word is an adjective describing that noun
# * `prep`: this word is a preposition that modifies its head
# * `pobj`: this word is a dependent (object) of a preposition

# %%
# Let's take a look at how this works in practice
# We'll go back to using our first doc, the Universal Declaration of Human Rights, for the rest of this notebook

# Let's load it in again in case you're doing this part of the notebook as part of your homework
doc = nlp("All human beings are born free and equal in dignity and rights. They are endowed with reason and conscience and should act towards one another in a spirit of brotherhood. Everyone has the right to life, liberty and security of person.")

for word in list(doc.sents)[2]:
    print("Word:", word.text)
    print("Tag:", word.tag_)
    print("Head:", word.head.text)
    print("Dependency relation:", word.dep_)
    print("Children:", list(word.children))
    print("")
# Out:
# Word: Everyone
# Tag: NN
# Head: has
# Dependency relation: nsubj
# Children: []
#
# Word: has
# Tag: VBZ
# Head: has
# Dependency relation: ROOT
# Children: [Everyone, right, .]
#
# Word: the
# Tag: DT
# Head: right
# Dependency relation: det
# Children: []
#
# Word: right
# Tag: NN
# Head: has
# Dependency relation: dobj
# Children: [the, to]
#
# Word: to
# Tag: IN
# Head: right
# Dependency relation: prep
# Children: [life]
#
# Word: life
# Tag: NN
# Head: to
# Dependency relation: pobj
# Children: [,, liberty]
#
# Word: ,
# Tag: ,
# Head: life
# Dependency relation: punct
# Children: []
#
# Word: liberty
# Tag: NN
# Head: life
# Dependency relation: conj
# Children: [and, security, of]
#
# Word: and
# Tag: CC
# Head: liberty
# Dependency relation: cc
# Children: []
#
# Word: security
# Tag: NN
# Head: liberty
# Dependency relation: conj
# Children: []
#
# Word: of
# Tag: IN
# Head: liberty
# Dependency relation: prep
# Children: [person]
#
# Word: person
# Tag: NN
# Head: of
# Dependency relation: pobj
# Children: []
#
# Word: .
# Tag: .
# Head: has
# Dependency relation: punct
# Children: []

# %% [markdown]
# We can also quickly see spaCy's POS tagging in action by we using the displacy on doc2 with the style= parameter set to "dep" (short for dependency parsing):

# %%
# reimport all our stuff in case you're running this notebook as homework 
from __future__ import unicode_literals
from spacy import displacy
from collections import Counter
import pandas as pd
pd.options.display.max_rows = 600
pd.options.display.max_colwidth = 400

#Set some display options for the visualizer
options = {"compact": True, "distance": 90, "color": "yellow", "bg": "black", "font": "Gill Sans"}

displacy.render(doc, style="dep", jupyter=True, options=options)
# Out:
# <span class="tex2jax_ignore"><svg xmlns="http://www.w3.org/2000/svg" xmlns:xlink="http://www.w3.org/1999/xlink" xml:lang="en" id="e6ef5f2a16fa418d8de65009938b5c01-0" class="displacy" width="3740" height="317.0" direction="ltr" style="max-width: none; height: 317.0px; color: yellow; background: black; font-family: Gill Sans; direction: ltr">
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="50">All</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="50">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="140">human</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="140">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="230">beings</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="230">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="320">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="320">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="410">born</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="410">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="500">free</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="500">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="590">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="590">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="680">equal</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="680">ADJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="770">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="770">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="860">dignity</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="860">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="950">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="950">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1040">rights.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1040">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1130">They</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1130">PRON</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1220">are</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1220">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1310">endowed</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1310">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1400">with</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1400">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1490">reason</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1490">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1580">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1580">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1670">conscience</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1670">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1760">and</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1760">CCONJ</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1850">should</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1850">AUX</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="1940">act</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="1940">VERB</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2030">towards</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2030">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2120">one</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2120">NUM</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2210">another</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2210">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2300">in</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2300">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2390">a</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2390">DET</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2480">spirit</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2480">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2570">of</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2570">ADP</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2660">brotherhood.</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2660">NOUN</tspan>
# </text>
#
# <text class="displacy-token" fill="currentColor" text-anchor="middle" y="227.0">
#     <tspan class="displacy-word" fill="currentColor" x="2750">Everyone</tspan>
#     <tspan class="displacy-tag" dy="2em" fill="currentColor" x="2750">P

# %% [markdown]
# ### Using .subtree for extracting syntactic units
#
# Now that the above makes perfect sense (or your eyes are glazing over), let's learn how the `.subtree` attribute evaluates to a generator (remember that?!) that can be flatted by passing it to `list()`.
#
# In this case, the subtree is a list of the word's syntactic dependents--essentially, the clause that the word belongs to.

# %% [markdown]
# This function merges a subtree and returns a string with the text of the words contained in it:

# %%
def flatten_subtree(st):
       return ''.join([w.text_with_ws for w in list(st)]).strip() # just take my word for it!

# %% [markdown]
# With this function in our toolbox, we can write a loop that prints out the subtree for each word in a sentence:

# %%
for word in list(doc.sents)[2]:
    print("Word:", word.text)
    print("Flattened subtree: ", flatten_subtree(word.subtree))
    print("")
# Out:
# Word: Everyone
# Flattened subtree:  Everyone
#
# Word: has
# Flattened subtree:  Everyone has the right to life, liberty and security of person.
#
# Word: the
# Flattened subtree:  the
#
# Word: right
# Flattened subtree:  the right to life, liberty and security of person
#
# Word: to
# Flattened subtree:  to life, liberty and security of person
#
# Word: life
# Flattened subtree:  life, liberty and security of person
#
# Word: ,
# Flattened subtree:  ,
#
# Word: liberty
# Flattened subtree:  liberty and security of person
#
# Word: and
# Flattened subtree:  and
#
# Word: security
# Flattened subtree:  security
#
# Word: of
# Flattened subtree:  of person
#
# Word: person
# Flattened subtree:  person
#
# Word: .
# Flattened subtree:  .

# %% [markdown]
# Using the subtree and our knowledge of dependency relation types, we can write code that extracts larger syntactic units based on their relationship with the rest of the sentence. For example, to get all of the noun phrases that are subjects of a verb:

# %%
subjects = []
for word in doc:
    if word.dep_ in ('nsubj', 'nsubjpass'):
        subjects.append(flatten_subtree(word.subtree))

# %%
subjects
# Out:
# ['All human beings', 'They', 'Everyone']

# %% [markdown]
# Or every prepositional phrase:

# %%
prep_phrases = []
for word in doc:
    if word.dep_ == 'prep':
        prep_phrases.append(flatten_subtree(word.subtree))

# %%
prep_phrases
# Out:
# ['in dignity and rights',
#  'with reason and conscience',
#  'towards one another',
#  'in a spirit of brotherhood',
#  'of brotherhood',
#  'to life, liberty and security of person',
#  'of person']

# %% [markdown]
# ###**Exercise #2**
#
# Modifying the code above, can you pull out the all of the prepositional phrases in the 2020 Democratic Party Platform?

# %%
prep_phrases = []
for word in dem_plat_doc:
  if word.dep_ == 'prep':
    prep_phrases.append(flatten_subtree(word.subtree))

# %%
prep_phrases
# Out:
# ['at its meeting on July 27, 2020',
#  'on July 27, 2020',
#  'on August 18, 2020',
#  'OF CONTENTS',
#  'FROM THE COVID-19',
#  'of Jobs',
#  'Across America',
#  'in the Engines of Job Creation Building A Fair System of International Trade for Our Workers',
#  'of Job Creation Building A Fair System of International Trade for Our Workers',
#  'of International Trade',
#  'for Our Workers',
#  'in Reach',
#  'for Every American Leveling the Economic Playing Field',
#  'Through a Public Option\n\n    Bringing Down Drug Prices and Taking on the Pharmaceutical Industry\n\n    Reducing Health Care Costs and Improving',
#  'on',
#  'to Mental Health and Substance Use Treatment',
#  'in Health Science and Research',
#  '23',
#  'BY REFORMING OUR CRIMINAL JUSTICE SYSTEM                                                             35\n\n                                           HEALING THE SOUL OF AMERICA\n\n                                              Protecting Americans’',
#  'OF AMERICA\n\n                                              Protecting Americans',
#  'Against Women                                                                  47',
#  'of Gun Violence',
#  'for Puerto Rico',
#  'IN EVERY ZIP CODE',
#  'Across America',
#  'from Crushing Student Debt                                          70',
#  'of First Resort',
#  'for the 21 st century                                            75\n\n        Ending F',
#  'orever',
#  'with Our Veterans and Military Families',
#  'to Address',
#  'on lands that have been stewarded through many centuries by the ancestors and descendants of Tribal Nations who have been here since time immemorial',
#  'through many centuries',
#  'of Tribal Nations',
#  'since time immemorial',
#  'to this continent',
#  'on\n\n                                               Indigenous homelands',
#  'to the millions of Indigenous people',
#  'of Indigenous people',
#  'throughout history who have protected\n\n                                           our lands, waters, and animals',
#  'at our 2020 Democratic National Convention',
#  'on the lands of the Bad River Band of the Lake Superior Tribe of Chippewa Indians',
#  'of the Bad River Band of the Lake Superior Tribe of Chippewa Indians',
#  'of the Lake Superior Tribe of Chippewa Indians',
#  'of Chippewa Indians',
#  'of Lake Superior Chippewa, the Lac du Flambeau Band of Lake Superior Chippewa, the Menominee Nation, the Oneida Nation of Wisconsin, the Red Cliff Band of Lake Superior Chippewa, the St. Croix Chippewa Indians of Wisconsin, the Sokaogon Chippewa Community, and the Stockbridge-Munsee Community, Band of Mohican Indians',
#  'of Lake Superior Chippewa, the Menominee Nation, the Oneida Nation of Wisconsin, the Red Cliff Band of Lake Superior Chippewa, the St. Croix Chippewa Indians of Wisconsin, the Sokaogon Chippewa Community, and the Stockbridge-Munsee Community, Band of Mohican Indians',
#  'of Wisconsin',
#  'of Lake Superior Chippewa, the St. Croix Chippewa Indians of Wisconsin, the Sokaogon Chippewa Community, and the Stockbridge-Munsee Community, Band of Mohican Indians',
#  'of Wisconsin',
#  'of Mohican Indians',
#  'through war and depression',
#  'over fascism and communism',
#  'to far distant corners of the earth',
#  'of the earth',
#  'among the highest forms of patriotism',
#  'of patriotism',
#  'of our highest ideals',
#  'to the polls',
#  'than a candidate',
#  'on the ballot in this election',
#  'in this election',
#  'of our President',
#  'than that',
#  'of our democracy,',
#  'in the world',
#  'before us',
#  'in a century',
#  'since the Great Depression, the worst period of global upheaval in a generation',
#  'of global upheaval',
#  'in a generation',
#  'of our nation',
#  'like never before',
#  'in our society',
#  'of our economy and social safety net',
#  'of racial and economic disparities on health and well-being',
#  'on health and well-being',
#  'of deepening polarization and political paralysis',
#  'on the Trump Administration’s hollowing',
#  'out of our public institutions',
#  'of our public institutions',
#  'of experts',
#  'of science',
#  'in research',
#  'of power',
#  'of duty',
#  'of tens of thousands of Americans',
#  'of Americans',
#  'of tens of millions of American jobs',
#  'of American jobs',
#  'to our children’s education and future',
#  'at tragic economic and human cost',
#  'of the Republican Party’s “America First” foreign policy',
#  'Under President Trump',
#  'under President Trump',
#  'of this nation',
#  'into a crucible, from which we will forge a stronger, brighter, and more equitable future',
#  'from which',
#  'in our democracy',
#  'of opportunity',
#  'for all Americans',
#  'at home',
#  'to where we were four years ago',
#  'from becoming a second Great Depression',
#  'in favor of the\n\x0cwealthiest few and the biggest corporations',
#  'of the\n\x0cwealthiest few and the biggest corporations',
#  'in the cold',
#  'with the American people',
#  'of new jobs',
#  'in income and wealth',
#  'for women',
#  'for all',
#  'not as a privilege for some',
#  'for some',
#  'for every single American',
#  'For a century',
#  'In the depths of the COVID-19 pandemic',
#  'of the COVID-19 pandemic',
#  'from millions of people who depend on it for survival',
#  'of people',
#  'on it',
#  'for survival',
#  'from the voices and votes of the American people',
#  'of the American people',
#  'of the Voting Rights Act',
#  'in all its forms',
#  'of money',
#  'in politics',
#  'of our elections',
#  'from all enemies, foreign and domestic',
#  'as our fate',
#  'in our fight',
#  'for all Americans',
#  'on government',
#  'on their own',
#  'instead of working to make them whole',
#  'of hate',
#  'in our economy and our society',
#  'from top to bottom',
#  'to bottom',
#  'in our great democratic experiment',
#  'by creating a humane, 21st century immigration system that benefits all Americans',
#  'of racism, misogyny, anti-Semitism, anti-Muslim bigotry, or white supremacy',
#  'of all our citizens—women, LGBTQ+ people, religious minorities',
#  'with disabilities, Native Americans',
#  'against',
#  'in too many ways and for too many generations',
#  'to the vision articulated by Frederick Douglass of “a Government founded upon justice',
#  'of “a Government founded upon justice',
#  'upon justice',
#  'of all',
#  'in taking on the climate crisis,',
#  'From Houston, Texas, to Mexico Beach, Florida;',
#  'to Mexico Beach, Florida;',
#  'from San Juan, Puerto Rico, to Davenport, Iowa, the last four years',
#  'to Davenport, Iowa,',
#  'in every ZIP code',
#  'to every child',
#  'in universal early childhood education',
#  'to-prison',
#  'to-opportunity',
#  'in its place',
#  'from crushing student debt',
#  'to a foreign policy that accelerates our domestic renewal',
#  'on what matters most to Americans—more and better jobs, greater security, a cleaner environment, and a more inclusive and resilient society',
#  'to Americans',
#  'with diplomacy',
#  'as our tool of first resort',
#  'of first resort',
#  'of us',
#  'on our own',
#  'to the forces of authoritarianism,',
#  'of authoritarianism',
#  'with clarity and purpose',
#  'on behalf of human rights',
#  'of human rights',
#  'under threat',
#  'with our women and men in uniform, our veterans, and our military families who have carried the burdens of wars that must—at long last—come to an end',
#  'in uniform, our veterans, and our military families who have carried the burdens of wars that must—at long last—come to an end',
#  'of wars',
#  'to an end',
#  'Above all',
#  'in the American idea—its principles, its purpose, and its promise',
#  'of the crass, craven, corrupt leadership we have seen from Donald Trump and the Republican Party',
#  'from Donald Trump and the Republican Party',
#  'beyond repair',
#  'of our nation',
#  'FROM THE COVID-19',
#  'in government',
#  'with the novel coronavirus',
#  'from this deadly pathogen',
#  'Instead of recognizing the danger and confronting it head-on',
#  'to the American people',
#  'about the disease’s severity, its transmissibility, and the threat it posed to lives and livelihoods',
#  'to the COVID-19',
#  'for the deaths of tens of thousands of Americans',
#  'of tens of thousands of Americans',
#  'of Americans',
#  'in our economy',
#  'in health care access',
#  'in access to paid sick leave',
#  'to paid sick leave',
#  'in environmental quality',
#  'in the employment market, and',
#  'in housing',
#  'to disproportionate rates of infection and death among Black Americans, Native Americans, Latinos, and certain Asian American and Pacific Islander communities',
#  'of infection and death',
#  'among Black Americans, Native Americans, Latinos, and certain Asian American and Pacific Islander communities',
#  'to early intelligence reports about the pandemic wasted critical weeks in which we could have prepared for the outbreak',
#  'about the pandemic wasted critical weeks in which we could have prepared for the outbreak',
#  'in which',
#  'for the outbreak',
#  'in the United States',
#  'for cities, states, businesses, and school districts',
#  'of COVID-19',
#  'for the advice of public health experts',
#  'of public health experts',
#  'of personal protective equipment and other critical supplies where they were needed most',
#  'for political obeisance',
#  'Instead of bringing Americans together',
#  'to an increase in hate crimes against Asian Americans and Pacific Islanders',
#  'in hate crimes against Asian Americans and Pacific Islanders',
#  'against Asian Americans and Pacific Islanders',
#  'in the midst of the pandemic',
#  'of the pandemic',
#  'in court',
#  'from tens of millions of people',
#  'of people',
#  'with the scale of the challenge before us',
#  'of the challenge',
#  'before us',
#  'of the COVID-19 pandemic',
#  'to the largest corporations',
#  'for public school systems, colleges, universities, and state and local governments',
#  'of essential workers',
#  'by failing to enact workplace safety standards',
#  'from economic ruin',
#  'by using every available tool to beat back this pandemic, which continues to sicken and kill hundreds of Americans per day',
#  'of Americans',
#  'per day',
#  'to future pandemic threats',
#  'by making COVID-19 testing widely available, convenient, and free to everyone',
#  'to everyone',
#  'for everyone who tests positive for the novel coronavirus',
#  'for the novel coronavirus',
#  'Only through widespread, regular testing and tracing',
#  'of the pandemic',
#  'In a public health crisis',
#  'on each other',
#  'to everyone',
#  'of their wealth, insurance coverage, or immigration status',
#  'from this disease',
#  'among us',
#  'of Americans',
#  'in a pandemic',
#  'for public health',
#  'without the Affordable Care Act in place',
#  'in place',
#  'in the COVID-19 pandemic',
#  'in Medicaid',
#  'of the bill',
#  'for states which have not yet expanded Medicaid to do so',
#  'For people who risk losing their insurance coverage if they lose their jobs in this pandemic and in President Trump’s recession',
#  'in this pandemic and in President Trump’s recession',
#  'of the tab',
#  'for COBRA insurance, which keeps people on their employer-sponsored plans, without restrictions',
#  'on their employer-sponsored plans',
#  'without restrictions',
#  'even outside of the normal open enrollment season',
#  'of the normal open enrollment season',
#  'on the marketplace',
#  'through the Centers for Medicare and Medicaid Services (CMS) which includes a platinum-level choice',
#  'for Medicare and Medicaid Services (CMS)',
#  'with low fees and no deductibles',
#  'in the public option',
#  'at zero cost',
#  'to them',
#  'at any time',
#  'in place',
#  'in another pandemic or severe economic downturn in the future',
#  'in the future',
#  'for themselves',
#  'in times of crisis',
#  'of crisis',
#  'on the advice of Congress',
#  'of Congress',
#  'of critical medical supplies, including personal protective equipment, or',
#  'including personal protective equipment, or',
#  'of needed equipment',
#  'through tools like the Defense Production Act',
#  'like the Defense Production Act',
#  'of lives',
#  'including those of our brave frontline health care workers and other essential workers',
#  'of our brave frontline health care workers and other essential workers',
#  'with private-sector manufacturers',
#  'for both personal protective equipment and essential medicines',
#  'according to need, not political favoritism',
#  'to need, not political favoritism',
#  'in the position of having to compete against each other for life-saving materials',
#  'of having to compete against each other for life-saving materials',
#  'against each other',
#  'for life-saving materials',
#  'in the Americans with Disabilities Act and',
#  'with Disabilities Act and',
#  'in response to the pandemic',
#  'to the pandemic',
#  'of patients with disabilities',
#  'with disabilities',
#  'of health care',
#  'on a patient’s disability',
#  'with disabilities living in group homes and other care facilities',
#  'in group homes and other care facilities',
#  'at greater risk of contracting COVID-19',
#  'of contracting COVID-19',
#  'with disabilities',
#  'during the pandemic',
#  'for residents and staff at nursing homes, which have seen some of the worst COVID-19 outbreaks',
#  'at nursing homes, which have seen some of the worst COVID-19 outbreaks',
#  'of the worst COVID-19 outbreaks',
#  'for telemedicine',
#  'without essential health care',
#  'during the pandemic',
#  'to a global pandemic',
#  'of scientists and public health experts',
#  'from political influence',
#  'for COVID-19 and future infectious diseases',
#  'with support from trusted local organizations in the communities',
#  'from trusted local organizations in the communities',
#  'in the communities',
#  'most at risk',
#  'at risk of contracting',
#  'of contracting',
#  'of underinvestment',
#  'in America’s public health infrastructure',
#  'for the Centers for Disease Control and Prevention (CDC) and for state and local public health departments',
#  'for Disease Control and Prevention',
#  'of which',
#  'during the Great Recession',
#  'at risk of further cuts',
#  'of further cuts',
#  'as a result of President Trump’s recession',
#  'of President Trump’s recession',
#  'through coordinated efforts that are inclusive of underrepresented groups who may be disproportionately impacted',
#  'of underrepresented groups who may be disproportionately impacted',
#  'for Historically Black Colleges and Universities (HBCUs) and other Minority-Serving Institutions (MSIs), which are particularly well suited to research health disparities in the context of COVID-19',
#  'to research health disparities in the context of COVID-19',
#  'in the context of COVID-19',
#  'of COVID-19',
#  'on track',
#  'of infection',
#  'from spreading',
#  'than the United States',
#  'During acute economic downturns',
#  'of our workforce',
#  'to their jobs',
#  'including by promoting payroll support and work-sharing programs with generous rates of wage replacement and requirements that employers maintain workers’ benefits',
#  'by promoting payroll support and work-sharing programs with generous rates of wage replacement and requirements that employers maintain workers’ benefits',
#  'with generous rates of wage replacement and requirements that employers maintain workers’ benefits',
#  'of wage replacement and requirements that employers maintain workers’ benefits',
#  'For those workers who do lose their jobs',
#  'including independent contractors and gig, part-time',
#  'like other employers',
#  'in many states',
#  'of Americans',
#  'that on',
#  'in this crisis',
#  'of Labor',
#  'of state unemployment systems',
#  'from becoming a depression',
#  'due to declines in tax revenues',
#  'in tax revenues',
#  'of COVID-related services and rising unemployment',
#  'into lost jobs in education, health care, and social services—',
#  'in education, health care, and social services—',
#  'of the American people',
#  'to state and local governments, school districts, and public and nonprofit colleges and universities, including HBCUs and MSls',
#  'including HBCUs and MSls',
#  'on maintaining and expanding public-sector employment, including provisions to protect workers’ rights',
#  'including provisions to protect workers’ rights',
#  'In states and cities across the country',
#  'across the country',
#  'between keeping their jobs and keeping their children safe',
#  'to recovering from the COVID-19 pandemic',
#  'from the COVID-19 pandemic',
#  'of care workers, children, parents, and the broader community',
#  "as a result of the COVID-19 pandemic and President Trump's recession",
#  "of the COVID-19 pandemic and President Trump's recession",
#  'with millions of families at risk of being evicted',
#  'of families',
#  'at risk of being evicted',
#  'of being evicted',
#  'for rent',
#  'from becoming homeless and making the pandemic even worse',
#  'of Black-owned small businesses',
#  'at risk',
#  'for Black entrepreneurs and other entrepreneurs of color',
#  'of color',
#  'as',
#  'by expanding funding for Community Development Financial Institutions (CDFIs) and other proven programs that invest in low-income communities and communities of color',
#  'for Community Development Financial Institutions (CDFIs) and other proven programs that invest in low-income communities and communities of color',
#  'in low-income communities and communities of color',
#  'of color',
#  'on big corporations seeking financial assistance to weather the pandemic and President Trump’s recession',
#  'on payroll',
#  'between protecting their health and earning a living',
#  'even under normal circumstances',
#  'in a pandemic',
#  'of national security',
#  'for the Black, Latino, Asian American and Pacific Islander, Native American, and low-income workers who are less likely to be able to work from home',
#  'from home',
#  'as part of the COVID-19 response for all workers in the economy, including contractors, gig workers, domestic workers, and the self-employed',
#  'of the COVID-19 response for all workers in the economy, including contractors, gig workers, domestic workers, and the self-employed',
#  'for all workers in the economy, including contractors, gig workers, domestic workers, and the self-employed',
#  'in the economy',
#  'including contractors, gig workers, domestic workers, and the self-employed',
#  'on the job where the Trump Administration has neglected them, from agriculture to meatpacking plants to manufacturing facilities to hospitals, including by issuing and enforcing effective infectious disease workplace safety standards through the Occupational Safety and Health Administration',
#  'from agriculture to meatpacking plants to manufacturing facilities to hospitals, including by issuing and enforcing effective infectious disease workplace safety standards through the Occupational Safety and Health Administration',
#  'to meatpacking plants to manufacturing facilities to hospitals, including by issuing and enforcing effective infectious disease workplace safety standards through the Occupational Safety and Health Administration',
#  'to manufacturing facilities',
#  'including by issuing and enforcing effective infectious disease workplace safety standards through the Occupational Safety and Health Administration',
#  'by issuing and enforcing effective infectious disease workplace safety standards through the Occupational Safety and Health Administration',
#  'through the Occupational Safety and Health Administration',
#  'of Americans',
#  'at home',
#  'of the pandemic',
#  'in the 21st century',
#  'for receiving an education and for participating in the economy',
#  'in the economy',
#  'to high-speed, affordable broadband service',
#  'from blocking municipalities and rural co-ops from building publicly-owned broadband networks',
#  'from building publicly-owned broadband networks',
#  'for municipal broadband',
#  'to policies that support good jobs and include strong protections for workers’ right to organize',
#  'for workers',
#  'in rural, urban, and Tribal broadband infrastructure',
#  'for accessing high-speed internet',
#  'in digital literacy training programs',
#  'with disabilities',
#  'in school, work, and life',
#  'from their homes',
#  'against broadband providers',
#  'through blocking, throttling, paid prioritization, or other measures that create artificial scarcity and raise consumer prices for this vital service',
#  'for this vital service',
#  'In past public health crises, including the Ebola epidemic',
#  'including the Ebola epidemic',
#  'into treatments and vaccines',
#  'In the COVID-19 pandemic',
#  'with our partners',
#  'of potential vaccines',
#  'to a vaccine candidate from our ally Germany',
#  'from our ally Germany',
#  'for early identification of infectious pathogens',
#  'of infectious pathogens',
#  'for the World Health\n\x0cOrganization (WHO)',
#  'from his dereliction of duty',
#  'of duty',
#  'by drawing from the authoritarian playbook he so admires',
#  'from the authoritarian playbook he so admires',
#  'at home',
#  'by restoring American leadership, driving a coordinated global health and economic response to the COVID-19 pandemic,',
#  'to the COVID-19',
#  'for future global health emergencies',
#  'for the American people',
#  'In a matter of weeks',
#  'of weeks',
#  'of President Trump and his Administration',
#  'to the COVID-19',
#  'out of the Great Recession',
#  'of the Great Recession',
#  'into recession',
#  'in American history',
#  'from the Obama-Biden Administration',
#  'over a recession in the manufacturing sector',
#  'in the manufacturing sector',
#  'after years of growth in the Obama-Biden Administration',
#  'of growth in the Obama-Biden Administration',
#  'in the Obama-Biden Administration',
#  'for a permanent tax cut for big business',
#  'for big business',
#  'by raising taxes on working families',
#  'on working families',
#  'with China',
#  'into bankruptcy',
#  'to the impacts of climate change',
#  'of climate change',
#  'in the clean energy revolution',
#  'to the American people',
#  'in rebuilding and modernizing our nation’s crumbling infrastructure',
#  'against working families and the middle class',
#  'for decades',
#  'of basic needs',
#  'from housing to health care',
#  'to health care',
#  'to child care',
#  'at precipitous rates',
#  'of the economic pie',
#  'with incomes for the top one percent growing five times faster than those of the bottom 90 percent',
#  'for the top one percent growing five times faster than those of the bottom 90 percent',
#  'than those of the bottom 90 percent',
#  'of the bottom 90 percent',
#  'as the land of opportunity',
#  'of opportunity',
#  'in the United States',
#  'than those in Canada, Denmark, or the United Kingdom',
#  'in Canada, Denmark, or the United Kingdom',
#  'to',
#  'with even greater disparities for women of color',
#  'for women of color',
#  'of color',
#  'for Black Americans, Latinos, Native Americans, and certain Asian American and Pacific Islander communities',
#  'compared to median white households',
#  'to median white households',
#  'of Americans',
#  'with the typical white household holding six times more wealth than the typical Latino family and 10 times more wealth than the typical Black family',
#  'than the typical Latino family',
#  'than the typical Black family',
#  'in jobs that can be done safely\n\x0cfrom home',
#  'from home',
#  'for our economy',
#  'for our democracy',
#  'for the soul of our nation',
#  'of our nation',
#  'to forging a new social and economic contract with the American people—a contract that invests in the people and promotes shared prosperity, not one that benefits only big corporations and the wealthiest few',
#  'with the American people',
#  'in the people',
#  'in the richest country on earth',
#  'on earth',
#  'at last',
#  'by securing equal pay for women',
#  'for women',
#  'for all',
#  'at last grapples',
#  'that at last grapples honestly with America',
#  'of racism and disenfranchisement',
#  'of segregation and discrimination',
#  'instead in building equity and mobility for the people of color who have been left out and left behind for generations',
#  'of color',
#  'for generations',
#  'out of President Trump',
#  'of President Trump',
#  'by investing in infrastructure, care work, clean energy, and small businesses to put Americans to work in good-paying jobs',
#  'in infrastructure',
#  'in good-paying jobs',
#  'in the ongoing COVID-19 pandemic',
#  'in our economy and our banking system',
#  'of Jobs',
#  'Across America\n\nAmericans',
#  'for everyone—',
#  'not just for the wealthy and the well-connected',
#  'against the American people',
#  'by rebuilding the American middle class for the 21st century',
#  'for the 21st century',
#  'of race, gender, sexual orientation, gender identity, disability status, national origin, age, or ZIP code',
#  'for working people',
#  'including by raising the federal minimum wage',
#  'by raising the federal minimum wage',
#  'by 2026',
#  'of infection',
#  'from COVID-19 and in the future',
#  'for workers across the economy',
#  'across the economy',
#  'including the right to launch secondary boycotts',
#  'to lower wages and less protection for workers across the economy',
#  'for workers across the economy',
#  'across the economy',
#  'without wage and hour protections for\n\x0cdecades—including domestic workers and farmworkers',
#  'for\n\x0cdecades—including domestic workers and farmworkers',
#  'including domestic workers and farmworkers',
#  'as other workers',
#  'for workers who speak for themselves or their coworkers',
#  'for themselves or their coworkers',
#  'by rewriting the rules that have undermined workers’ ability to advocate for themselves, including non-compete clauses, no-poaching agreements, and contracts that force workers into mandatory arbitration to resolve violations of employment laws',
#  'for themselves',
#  'including non-compete clauses, no-poaching agreements, and contracts that force workers into mandatory arbitration to resolve violations of employment laws',
#  'into mandatory arbitration',
#  'of employment laws',
#  'with majority sign-up',
#  'via “card check” processes—',
#  'to bully and browbeat workers',
#  'in workers’ efforts to organize, including issuing criminal penalties for intentional obstruction',
#  'including issuing criminal penalties for intentional obstruction',
#  'for intentional obstruction',
#  'to the table',
#  'with the employers who actually hold the power, including franchisors',
#  'including franchisors',
#  'in bad faith with their workers',
#  'with their workers',
#  'without fear of coercion, interference, and undue delay',
#  'of coercion, interference, and undue delay',
#  'in promoting and facilitating collective bargaining and helping the parties bring their negotiations to a rapid and successful conclusion,',
#  'to a rapid and successful conclusion',
#  'to a high standard for intervening in strikes',
#  'for intervening in strikes',
#  'in strikes',
#  'including under the Railway Labor Act',
#  'under the Railway Labor Act',
#  'of workers',
#  'under attack',
#  'from having the union they want and update our labor laws to make it more possible',
#  'into multi-employer agreements establishing minimum workplace standards related to wages, benefits, and working conditions',
#  'to wages, benefits, and working conditions',
#  'to employers who steal workers’ wages',
#  'in union-busting, or exploit immigrant workers to depress working conditions for all workers',
#  'for all workers',
#  'at the Department of Labor',
#  'of Labor',
#  'across the economy',
#  'including gig and platform workers',
#  'including minimum wage and overtime pay',
#  'for unpaid or underpaid wages',
#  'of corporate structure',
#  'with community organizations',
#  'under the law',
#  'for the more than 20 million public-sector employees in the United States',
#  'in the United States',
#  'by passing the Public Service Freedom to Negotiate Act, which would provide a federal guarantee for public-sector employees to bargain for better pay and benefits and the working conditions they deserve',
#  'for public-sector employees',
#  'for better pay and benefits and the working conditions they deserve',
#  'without taking on the profound racial biases at work in our employment system',
#  'at work in our employment system',
#  'in our employment system',
#  'between Black workers and white workers',
#  'in 12 months',
#  'for typical Latinas and Native American women',
#  'in rooting out discrimination in our employment system',
#  'in our employment system',
#  'to the Equal Employment Opportunity Commission',
#  'into civil rights violations,',
#  'of the rights of people with disabilities',
#  'of people with disabilities',
#  'with disabilities',
#  'against LGBTQ+ people',
#  'of color',
#  'of color, women, LGBTQ+ people',
#  'with disabilities',
#  'for delivering',
#  'among advanced economies in guaranteeing neither paid sick leave nor paid family leave for all workers',
#  'in guaranteeing neither paid sick leave nor paid family leave for all workers',
#  'for all workers',
#  'on working families',
#  'even in the best of times',
#  'of times',
#  'for public health in the midst of the COVID-19 pandemic',
#  'in the midst of the COVID-19 pandemic',
#  'of the COVID-19 pandemic',
#  'from the unfair choice between attending to urgent health or caretaking needs and earning a paycheck',
#  'between attending to urgent health or caretaking needs and earning a paycheck',
#  'to urgent health or',
#  'of paid family and medical leave',
#  'for all workers and family units',
#  'from childbirth and bond',
#  'with their newborns, foster or adopted children',
#  'for themselves or ailing loved ones',
#  'for high-quality child care',
#  'for too many parents',
#  'between keeping their kids safe and earning a paycheck',
#  'in quality',
#  'including by significantly increasing the Child and Dependent Care Tax Credit and providing access to affordable, high-quality child care on a sliding scale by boosting funding for grants to states to help low-income and middle-class families afford child care',
#  'by significantly increasing the Child and Dependent Care Tax Credit and providing access to affordable, high-quality child care on a sliding scale by boosting funding for grants to states to help low-income and middle-class families afford child care',
#  'to affordable, high-quality child care',
#  'on a sliding scale',
#  'by boosting funding for grants to states to help low-income and middle-class families afford child care',
#  'for grants',
#  'for child care providers',
#  'for three- and four-year-olds',
#  'in expanding long-term services and supports and home and community-based care for seniors and people with disabilities',
#  'for seniors and people with disabilities',
#  'with disabilities',
#  'for paid caregivers in all settings, which will improve working conditions and quality of care while enabling family members to rejoin the workforce',
#  'in all settings, which will improve working conditions and quality of care while enabling family members to rejoin the workforce',
#  'of care',
#  'in the Engines of Job Creation\n\nDemocrats',
#  'of Job Creation\n\nDemocrats',
#  'in resilient, sustainable, and inclusive infrastructure',
#  'through historic investments in clean energy, clean transportation, energy efficiency, and advanced manufacturing',
#  'in clean energy, clean transportation, energy efficiency, and advanced manufacturing',
#  'including by installing 500,000 public charging stations for electric vehicles',
#  'by installing 500,000 public charging stations for electric vehicles',
#  'for electric vehicles',
#  'to the impacts of climate change',
#  'of climate change',
#  'by investing in high-speed rail and passenger and freight rail systems',
#  'in high-speed rail and passenger and freight rail systems',
#  'to public transportation',
#  'as a public good',
#  'including ensuring transit jobs',
#  'to good union jobs',
#  'in rural communities',
#  'to major metropolitan areas',
#  'including public transit',
#  'to all and accessible to people with disabilities',
#  'to people with disabilities',
#  'with disabilities',
#  'from a laggard',
#  'to a leader in passenger rail accessibility',
#  'in passenger rail accessibility',
#  'with disabilities',
#  'like wheelchairs',
#  'for American-made ships',
#  'by ensuring U.S. cargo is carried on ships flying our flag',
#  'on ships flying our flag',
#  'in America',
#  'to clean, reliable drinking water and safe wastewater systems in their homes,',
#  'in their homes',
#  'including by replacing dangerous lead pipes',
#  'by replacing dangerous lead pipes',
#  'in innovative water technologies, including water use efficiency, water conservation, and water reuse and recycling, that reduce water waste and consumer bills',
#  'including water use efficiency, water conservation, and water reuse and recycling, that reduce water waste and consumer bills',
#  'to students with disabilities',
#  'with disabilities',
#  'of high-speed internet access',
#  'by investing in broadband and 5G technology, including rural and municipal broadband',
#  'in broadband',
#  'including rural and municipal broadband',
#  'for workers’ rights',
#  'against internet service providers who violate net neutrality principles',
#  'of an infrastructure bank, a public bank that will leverage public and private resources to build infrastructure projects of national or regional significance, including in rail and transit, clean energy and water infrastructure, broadband, and affordable housing',
#  'of national or regional significance',
#  'including in rail and transit',
#  'in rail and transit',
#  'from the bank',
#  'in workers’ organizing efforts',
#  'through grants, loans, tax incentives, or a national infrastructure bank',
#  'in any infrastructure legislation',
#  'including forced arbitration',
#  'of family sustaining jobs,',
#  'with the high road labor standards with the provisions defined in the Good Jobs\n\x0cfor the 21st Century Energy Act',
#  'with the provisions defined in the Good Jobs\n\x0cfor the 21st Century Energy Act',
#  'in the Good Jobs',
#  'for the 21st Century Energy Act',
#  'of publicly owned infrastructure and assets',
#  'from partisan power grabs seeking to strip them of those assets',
#  'of those assets',
#  'of any proposed transfers of ownership or operations',
#  'of ownership or operations',
#  'of public services or infrastructure',
#  'in our homes, stores, workplaces, and communities',
#  'in America',
#  'for American manufacturing',
#  'of critical supply chains,',
#  'including in medical supplies and pharmaceuticals',
#  'in medical supplies and pharmaceuticals',
#  'through investments in bio-based manufacturing',
#  'in bio-based manufacturing',
#  'in innovation hubs and government programs',
#  'with technical and business expertise',
#  'for federally supported projects, which help increase demand for domestically produced and low-pollution raw materials',
#  'for domestically produced and low-pollution raw materials',
#  'of talent',
#  'across the economy',
#  'in career and technical education and high-quality job training programs with formal worker representation in program development, including pre-apprenticeship opportunities and registered apprenticeships',
#  'with formal worker representation in program development, including pre-apprenticeship opportunities and registered apprenticeships',
#  'in program development, including pre-apprenticeship opportunities and registered apprenticeships',
#  'including pre-apprenticeship opportunities and registered apprenticeships',
#  'in the value of lifelong learning',
#  'of lifelong learning',
#  'among the best job creators in our country',
#  'in our country',
#  'for state small business grant and lending initiatives that generate tens of billions of dollars of private-sector investment',
#  'of dollars of private-sector investment',
#  'of private-sector investment',
#  'especially for small businesses owned by women and people of color',
#  'of color',
#  'to credit',
#  'for small businesses in low-income and rural areas,',
#  'in low-income and rural areas',
#  'including for unbanked or underbanked businesses',
#  'for unbanked or underbanked businesses',
#  'for programs supporting businesses owned by women and people of color, including ending the Trump Administration’s effort to starve the Minority Business Development Agency, improving and expanding Small Business Administration (SBA) programs that most effectively support women- and minority-owned businesses, and increasing opportunities for women- and minority-owned businesses to obtain or participate in federal contracts',
#  'of color',
#  'including ending the Trump Administration’s effort to starve the Minority Business Development Agency, improving and expanding Small Business Administration (SBA) programs that most effectively support women- and minority-owned businesses, and increasing opportunities for women- and minority-owned businesses to obtain or participate in federal contracts',
#  'for women- and minority-owned businesses',
#  'in federal contracts',
#  'in the American heartland and rural communities',
#  'for new and beginning farmers, aquaculture farmers, ranchers, and foresters, including returning veterans, to start and grow their operations by expanding U.S. Department of Agriculture (USDA) ownership and operating loan programs',
#  'including returning veterans, to start and grow their operations by expanding U.S. Department of Agriculture (USDA) ownership and operating loan programs',
#  'by expanding U.S. Department of Agriculture (USDA) ownership and operating loan programs',
#  'of Agriculture',
#  'of racial discrimination in USDA’s core farming programs',
#  'in USDA’s core farming programs',
#  'under the Obama-Biden Administration',
#  'to supporting training and resources for farmers of color',
#  'for farmers of color',
#  'of color',
#  'including by taking steps to limit foreign ownership of U.S. farmland and reforming agricultural subsidies to better support small- and mid-sized farms',
#  'by taking steps to limit foreign ownership of U.S. farmland and reforming agricultural subsidies to better support small- and mid-sized farms',
#  'of U.S. farmland',
#  'on large corporations',
#  'for even the simplest fixes',
#  'for family farmers and ranchers',
#  'by developing and growing regional food systems to deliver fresh, American-grown produce to schools, hospitals, Department of Defense installations, and other major public institutions, so small, mid-size',
#  'to schools, hospitals, Department of Defense installations, and other major public institutions, so small, mid-size',
#  'of Defense',
#  'with America’s farmers, ranchers, and foresters',
#  'in the world',
#  'in agriculture',
#  'for farmers in energy and waste products',
#  'in energy and waste products',
#  'including by strengthening the Renewable Fuel Standard, supporting El5 blends, and supporting research, development, and deployment of advanced biofuels',
#  'by strengthening the Renewable Fuel Standard',
#  'of advanced biofuels',
#  'for sustainable and regenerative agricultural practices that help protect clean air and water and support wildlife habitats, including for threatened pollinators',
#  'including for threatened pollinators',
#  'for threatened pollinators',
#  'in research and development',
#  'to our economy, our communities, and our security',
#  'for farmworkers, including overtime and safety rules protecting workers from exposure to pesticides and extreme heat',
#  'including overtime and safety rules protecting workers from exposure to pesticides and extreme heat',
#  'from exposure to pesticides and extreme heat',
#  'to pesticides and extreme heat',
#  'by tackling market concentration in agriculture, including by strengthening enforcement of the Sherman and Clayton Antitrust Acts and the Packers and Stockyards Act',
#  'in agriculture',
#  'including by strengthening enforcement of the Sherman and Clayton Antitrust Acts and the Packers and Stockyards Act',
#  'by strengthening enforcement of the Sherman and Clayton Antitrust Acts and the Packers and Stockyards Act',
#  'of the Sherman and Clayton Antitrust Acts and the Packers and Stockyards Act',
#  'at facilities that raise and process meat for consumption',
#  'for consumption',
#  'of farm animals',
#  'in accordance with commercially-recognized animal welfare standards',
#  'with commercially-recognized animal welfare standards',
#  'in science, technology, research, and innovation',
#  'with the work of career scientists',
#  'of career scientists',
#  'on scientific discovery',
#  'to America’s economic competitiveness',
#  'in research, development, demonstration, and deployment,',
#  'of science',
#  'across the country',
#  'in aerospace, artificial intelligence, advanced materials, biotechnology, and',
#  'in technology and innovation',
#  'for all Americans',
#  'of color',
#  'in technology',
#  'in low-income communities and communities of color',
#  'of color',
#  'to continuing space exploration and discovery',
#  'in continuing the spirit of discovery that has animated NASA’s human space exploration',
#  'of discovery',
#  'in addition to its scientific and medical research, technological innovation, and educational mission that allows us to better understand our own planet and place in the universe',
#  'to its scientific and medical research, technological innovation, and educational mission that allows us to better understand our own planet and place in the universe',
#  'in the universe',
#  "for the United\n\x0cStates' role in space",
#  'in space',
#  'through our continued presence on the International Space Station',
#  'on the International Space Station',
#  'in partnership with the international community',
#  'with the international community',
#  'to the moon',
#  'to Mars',
#  'in exploring our solar system',
#  'of International Trade',
#  'for Our Workers',
#  'For too long',
#  'to American workers',
#  'to outsource jobs',
#  'of relying too heavily on global supply chains,',
#  'on global supply chains',
#  'for workers and consumers',
#  'after time to deliver for American workers on this crucial issue',
#  'for American workers',
#  'on this crucial issue',
#  'with corporate interests over our workers',
#  'over our workers',
#  'with China',
#  'for winning—creating incredible hardship for American farmers, manufacturers, workers, and consumers in the process',
#  'for American farmers, manufacturers, workers, and consumers in the process',
#  'in the process',
#  'for labor, human rights',
#  'in the core text of our trade deals',
#  'of our trade deals',
#  'on the pro-labor provisions added to the United States-Mexico-Canada Agreement (USMCA) by Democratic members of Congress',
#  'to the United States-Mexico-Canada Agreement (USMCA)',
#  'of Congress',
#  'against China or any other country that tries to undercut American manufacturing by manipulating their currencies and maintaining a misaligned exchange rate with the dollar, dumping products like steel and aluminum in our markets, or providing unfair subsidies',
#  'by manipulating their currencies and maintaining a misaligned exchange rate with the dollar, dumping products like steel and aluminum in our markets, or providing unfair subsidies',
#  'with the dollar',
#  'like steel and aluminum',
#  'in our markets',
#  'Unlike President Trump',
#  'to efforts from China and other state actors to steal America’s intellectual property',
#  'from China and other state actors',
#  'from conducting cyberespionage against our companies',
#  'against our companies',
#  'of taxes',
#  'from taxpayers',
#  'to American farmers',
#  'by working with our allies to stand up to China and negotiate from the strongest possible position',
#  'with our allies',
#  'to China',
#  'from the strongest possible position',
#  'in Reach',
#  'for Every American\n\nHomeownership',
#  'at the center of the American Dream',
#  'of the American Dream',
#  'in reach',
#  'for all',
#  'of red-lining, rising income inequality, and predatory lending practices targeting low-income families and people of color',
#  'of color',
#  'for millions of working families',
#  'of working families',
#  'to building generational wealth',
#  'to homeownership',
#  'to those who have been unfairly excluded and',
#  'against',
#  'to closing the racial wealth gap',
#  'of affordable housing units',
#  'of Americans',
#  'in homes that pose risks to their health and safety',
#  'to their health and safety',
#  'in a growing number of states',
#  'of states',
#  'on renters',
#  'in many of our biggest cities',
#  'of our biggest cities',
#  'in America',
#  'above all',
#  'of their income on housing',
#  'on housing',
#  'for retirement',
#  'of housing, especially affordable housing',
#  'in our housing markets',
#  'to eliminating the racial wealth gap in America',
#  'in America',
#  'of housing owned by land trusts',
#  'of housing available for secure homeownership',
#  'for secure homeownership',
#  'to affordable credit',
#  'to down payment assistance',
#  'of color, low-income families',
#  'for assistance to first-time purchasers and homeowners',
#  'to first-time purchasers and homeowners',
#  'of their homes',
#  'of up to $15,000',
#  'at the time of purchase',
#  'of purchase',
#  'instead of having to wait until they file their taxes',
#  'in the Housing Trust Fund',
#  'of affordable, accessible housing units on the market',
#  'on the market',
#  'of affordable housing',
#  'for millions of low-income households',
#  'of low-income households',
#  'in metropolitan and rural areas',
#  'on their energy bills',
#  'including at USD A',
#  'at USD A',
#  'in rural areas',
#  'from new builds to retrofits',
#  'to retrofits',
#  'for labor standards, accessibility, and civil rights protections',
#  'to ending homelessness in America',
#  'in America',
#  'to providing Section 8 housing support for every eligible family',
#  'for every eligible family',
#  'from discriminating against voucher recipients',
#  'against voucher recipients',
#  'in public housing',
#  'for the first time since the 1990s',
#  'since the 1990s',
#  'for residents',
#  'to ending homelessness',
#  'to helping a person tackle any other challenges they may face, from mental illness to substance use disorders to post-traumatic stress disorder',
#  'from mental illness to substance use disorders to post-traumatic stress disorder',
#  'to substance use disorders',
#  'to post-traumatic stress disorder',
#  'among veterans',
#  'for lesbian, gay, bisexual, transgender, and queer youth, especially Black, Latino, and Native American LGBTQ+ youth, who too often find themselves on the streets',
#  'on the streets',
#  'of Rights',
#  'from abusive lenders and landlords',
#  'by working to establish a national tenant right to organize',
#  'of using public policy and private lending restrictions to close neighborhoods off to Black families and other people of color and strip equity from their communities',
#  'to Black families and other people of color and strip equity',
#  'of color and strip equity',
#  'from their communities',
#  'to this day',
#  'by gutting fair lending and fair housing protections for homeowners',
#  'for discriminatory practices',
#  'against discriminatory lenders',
#  'including exploring targeted rental relief',
#  'from their communities',
#  'in appraisals that contributes to the racial wealth gap',
#  'to the racial wealth gap',
#  'against the American people',
#  'after time',
#  'for people of color',
#  'of color',
#  'on the sidelines',
#  'against the American people',
#  'to their biggest donors',
#  'for shipping American jobs overseas',
#  'on overseas tax havens and close loopholes that are exploited by the wealthiest Americans and biggest corporations',
#  'in taxes',
#  'as workers',
#  'to expensive and unproductive tax loopholes, including the carried interest loophole',
#  'including the carried interest loophole',
#  'to the historical norm',
#  'for working families',
#  'from targeted tax breaks, including the Earned Income Tax Credit and the Child Tax Credit',
#  'including the Earned Income Tax Credit and the Child Tax Credit',
#  ...]

# %% [markdown]
# ### Putting the Pieces Together ###
#
# In "Connotation Frames of Power and Agency in Modern Films" and also in "Birth Stories," we saw how the combination of a particular part of speech--in those cases, verbs--combined with a lexcon (a slightly more content-ful dictionary) can be very illuminating.
#
# Now we're going to see what we can learn about the verbs in each party's platform--in particular, the "power" verbs that indicate power over the person/place/thing that the verb is doing something to.
#
# Reall that we've already learned how to 1) create a list of words that match a specific part of speech in a particular document; 2) lemmatize a particular word so that it is reduced to its root word; and 3) call a function that counts the number of words in a string that match a list of words in a (linguistic) dictionary.
#
# Now we're going to put the pieces together.

# %%
## This code cell creates a list of "power" verbs that we'll use a little later

# read in list of "power" verbs
resp = requests.get('https://raw.githubusercontent.com/laurenfklein/QTM340-Fall22/main/corpora/platforms/power-verbs.txt')
power_verbs = resp.text

# convert the verbs to a spacy object
power_verbs = nlp(power_verbs)

# then we're going to convert it to a list for easy comparisons, 
# and in the process lemmatize the verbs for easy comparison
power_list = []

for verb in power_verbs:
  if "\n" not in verb.text:  
    power_list.append(verb.lemma_)

# now you've got your list of power verbs to work with
# we'll just print out the lenght of the list so you
# get a sense of the numbers

len(power_list)
# Out:
# 1242

# %%
# This code is very similar to code that you saw above. This is how we 
# pull out all of the unique verbs in each of the documents:

rep_verbs = []
dem_verbs = []

for word in repub_plat_doc:
    if word.pos_ == 'VERB':
      rep_verbs.append(word.text)

for word in dem_plat_doc:
    if word.pos_ == 'VERB':
        dem_verbs.append(word.text)

print("Number of unique rep verbs: " + str(len(rep_verbs)))
print("Number of unique dem verbs: " + str(len(dem_verbs)))
# Out:
# Number of unique rep verbs: 4416
# Number of unique dem verbs: 5961

# %% [markdown]
# But if we're going to compare these verbs to a list, we need to lemmatize them first to make sure that we're able to match the one to the other. Which brings us to...
#
# ### **Exercise 3**
#
# Using the code cell above as a guide, write some code such that instead of creating lists of all the unique *verbs* in each platform, we're creating lists of the unique verb *lemmas* in those platforms

# %%
rep_verb_lemmas = []
dem_verb_lemmas = []

for word in repub_plat_doc:
    if word.pos_ == 'VERB':
      rep_verb_lemmas.append(word.lemma_)

for word in dem_plat_doc:
    if word.pos_ == 'VERB':
      dem_verb_lemmas.append(word.lemma_)
    
def remove_dup(a):
  i = 0
  while i < len(a):
    j = i + 1
    while j < len(a):
      if a[i] == a[j]:
        del a[j]
      else:
        j += 1
    i += 1
remove_dup(rep_verb_lemmas)

print("Number of unique rep verb lemmas: " + str(len(rep_verb_lemmas)))
print("Number of unique dem verb lemmas: " + str(len(dem_verb_lemmas)))


#testing
# print("here are the first rep verb lemmas: " + str(rep_verb_lemmas))
# print("here are the first dem verb lemmas: " + str(dem_verb_lemmas))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 4>()
#       1 rep_verb_lemmas = []
#       2 dem_verb_lemmas = []
# ----> 4 for word in repub_plat_doc:
#       5     if word.pos_ == 'VERB':
#       6       rep_verb_lemmas.append(word.lemma_)
#
# NameError: name 'repub_plat_doc' is not defined

# %% [markdown]
# Now that we've got our lemmas, we can use a basic counting function to count the number of power verbs used in each platform:

# %%
dem_count = 0
rep_count = 0

for verb in rep_verb_lemmas:
  if verb in power_list:
      rep_count += 1

for verb in dem_verb_lemmas:
  if verb in power_list:
      dem_count += 1
    
print("Number of power verbs:")
print("Dems: " + str(dem_count))
print("Repubs: " + str(rep_count))

print("\nPercentage of power verbs:")
print("Dems: " + str(dem_count / len(dem_verb_lemmas)))
print("Repubs: " + str(rep_count / len(rep_verb_lemmas)))
# Out:
# Number of power verbs:
# Dems: 3405
# Repubs: 2413
#
# Percentage of power verbs:
# Dems: 0.5712128837443382
# Repubs: 0.5464221014492754

# %% [markdown]
# And one last exercise!
#
# ### **Exercise #4**
#
# In a sentence, what is one thing we can conclude about the power verbs used in the Democratic Party Platform vs. the Republican one?

# %% [markdown]
# **Answer:** The Democratic Party Platform uses more power verbs and has a higher percentage (57%) of power verbs than the Republican Party Platform (54%), suggesting that Democrats communicate their message more strongly and confidently.

# %% [markdown]
# ## Further reading and resources
#
# [A few example programs can be found here.](https://github.com/aparrish/rwet-examples/tree/master/spacy)
#
# We've barely scratched the surface of what it's possible to do with spaCy. [There's a great page of tutorials on the official site](https://spacy.io/docs/usage/tutorials) that you should check out!

# %% [markdown]
# *I wrote version 1.0 of this notebook based off materials by Alison Parrish. Dan Sinykin supplemented the 2020 version with material from Melanie Walsh's chapters [Named Entity Recognition](https://melaniewalsh.github.io/Intro-Cultural-Analytics/features/Text-Analysis/Named-Entity-Recognition.html) and [Part-of-Speech Tagging](https://melaniewalsh.github.io/Intro-Cultural-Analytics/features/Text-Analysis/POS-Keywords.html). For 2021, I've added material adapted from David Bamman's [Applied NLP](https://github.com/dbamman/anlp21) course, and revised the notebook again for 2022.*
